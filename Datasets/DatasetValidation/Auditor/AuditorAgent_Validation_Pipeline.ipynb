# %% [markdown]
# # AuditorAgent Synthetic Training Dataset - Comprehensive Validation & Cleaning Pipeline
#
# **Dataset:** 840 JSONL rows generated via Gemini for fine-tuning an architectural governance AuditorAgent
# **Purpose:** Data quality assessment, bias detection, cleaning, and before/after evaluation
#
# ---
#
# ## Table of Contents
#
# | # | Section | Purpose |
# |---|---------|---------|
# | 0 | Setup & Configuration | Imports, constants, helper functions |
# | 1 | Data Loading & JSONL Parsing | Robust line-by-line ingestion with error handling |
# | 2 | Audit Chain Reconstruction | Group rows into multi-round project audit chains |
# | 3 | Structural Schema Validation | Recursive nested key/type/presence checks |
# | 4 | Enum & Value Domain Compliance | Allowed-value enforcement, forbidden-value detection |
# | 5 | Cross-Field Consistency | Conditional field rules, contract-profile agreement, issue-ID stability |
# | 6 | Score Calibration & Anti-Inflation | Formula verification, plan-richness correlation, inflation detection |
# | 7 | Diversity & Coverage Analysis | Project-class spread, capability combinations, entropy metrics |
# | 8 | Duplication & Redundancy Detection | Structural fingerprinting, TF-IDF semantic similarity, chain-aware dedup |
# | 9 | Bias Detection | Score-by-class ANOVA, rubric correlation, technology concentration, length-score bias |
# | 10 | Cleaning & Remediation Pipeline | Apply fixes, removals, and rebalancing |
# | 11 | Before vs After Evaluation | Quantitative comparison with statistical tests and publication-quality visuals |
# | 12 | Final Export | Write cleaned dataset and reports |

# %% [markdown]
# ---
# ## Section 0 - Setup & Configuration
#
# Import all required libraries and define the constants that encode the dataset specification.

# %%
import json
import hashlib
import re
import copy
import math
import warnings
from collections import Counter, defaultdict
from pathlib import Path
from typing import Any, Dict, List, Optional, Tuple, Set

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
from scipy import stats
from scipy.cluster.hierarchy import linkage, fcluster, dendrogram
from scipy.spatial.distance import squareform
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import networkx as nx

warnings.filterwarnings('ignore')
sns.set_theme(style="whitegrid", font_scale=1.1)
plt.rcParams['figure.dpi'] = 120
plt.rcParams['savefig.dpi'] = 150
plt.rcParams['figure.figsize'] = (12, 6)

print("All imports successful.")
# Out:
# All imports successful.

# %%
# Constants derived from system specification

ALLOWED_PROJECT_CLASSES = {
    "webapp", "fullstackapp", "mobileapp", "desktopapp", "apiservice",
    "staticwebsite", "landingpage", "clitool", "librarysdk",
    "automationtool", "datapipeline", "aisystem", "researchprototype",
    "infrastructureproject"
}

ALLOWED_CAPABILITIES = {
    "frontend", "backend", "data", "auth", "aillm", "integrations",
    "analytics", "realtime", "payments", "adminpanel", "publicapi",
    "batchjobs", "devops"
}

ALLOWED_COMPLEXITY = {"simple", "moderate", "advanced", "highscale"}
ALLOWED_RISK = {"low", "medium", "high"}
ALLOWED_SENSITIVITY = {"none", "internal", "personal", "financial", "health", "confidential"}
ALLOWED_EXPOSURE = {"localonly", "internalonly", "privateauthenticated", "partnerfacing", "publicinternet"}
ALLOWED_SEVERITY = {"critical", "high", "medium", "low"}
ALLOWED_STATUS = {"unresolved", "resolved", "downgraded", "new"}
ALLOWED_CASE_TYPE = {"first_pass", "revision_round"}
ALLOWED_FLAW_FAMILIES = {
    "security", "requirementconflict", "operability", "architecturequality",
    "internalconsistency", "compliance", "deployment", "datahandling",
    "regression", "scalability", "none"
}

FORBIDDEN_VALUES = {
    "phi", "pci", "pii", "secret", "public_internet", "partner_api",
    "private_authenticated", "medium_complexity", "web_app", "api_service",
    "high_scale"
}

# Mandatory contract fields
MANDATORY_CONTRACT_FIELDS = [
    "projectgoal", "targetusers", "projectclass", "capabilities",
    "complexitylevel", "risklevel", "datasensitivity", "externalexposure",
    "accessmodel", "featurescope", "mvpscope", "securitybaseline",
    "frontendstack", "backendstack", "dataplatform", "hostingtarget",
    "privacyretentionpolicy", "futurescope", "constraints",
    "observabilitybaseline", "executionpreference"
]

CONTRACT_FIELD_SUBKEYS = {"value", "source", "confirmed", "rationale", "updatedat"}

# Mandatory plan sections
MANDATORY_PLAN_KEYS = [
    "thinkingsummary", "fixreport", "title", "executivesummary",
    "architectureoverview", "technologystack", "functionalfeaturemap",
    "systemcomponents", "workflows", "datamodel", "apidesign",
    "securityandcompliance", "deploymentandoperations", "observability",
    "costandscaling", "phasedimplementation", "developmentguidelines",
    "risksandtradeoffs", "openquestionsresolved", "generatedat"
]

# Mandatory target_output keys
MANDATORY_OUTPUT_KEYS = [
    "thinkingsummary", "rubricscores", "summary", "strengths",
    "concerns", "blockingissues", "recommendations",
    "requirementconflicts", "issueupdates"
]

RUBRIC_DIMENSIONS = [
    "requirementsalignment", "architecturequality", "security",
    "operability", "internalconsistency"
]

# Scoring formula weights
RUBRIC_WEIGHTS = {
    "requirementsalignment": 0.30,
    "architecturequality": 0.25,
    "security": 0.20,
    "operability": 0.15,
    "internalconsistency": 0.10
}

SEVERITY_PENALTIES = {"critical": 1.50, "high": 0.60, "medium": 0.20, "low": 0.05}

# Requirement sections must be dicts, not lists
REQUIRED_REQ_SECTIONS = [
    "project", "frontend", "backend", "security", "data",
    "devops", "constraints", "openquestions", "confirmeddecisions"
]

# Issue-detail template regex
DETAIL_TEMPLATE_RE = re.compile(
    r"^(Fixed|Partially fixed|Unchanged|Newly introduced)\.",
    re.IGNORECASE
)

# Summary progression words for revision rounds
PROGRESSION_WORDS = ["meaningfully improved", "stayed roughly flat", "regressed"]

# Configuration

DATA_PATH = "auditor_dataset.jsonl"
OUTPUT_DIR = Path("validation_output")
OUTPUT_DIR.mkdir(exist_ok=True)

print(f"Constants loaded. Data path: {DATA_PATH}")
print(f"Output directory: {OUTPUT_DIR}")
# Out:
# Constants loaded. Data path: auditor_dataset.jsonl
# Output directory: validation_output

# %% [markdown]
# ---
# ## Section 1 - Data Loading & JSONL Parsing
#
# JSONL (JSON Lines) format requires line-by-line parsing. Each line is an independent JSON object.
# I implemented robust loading with:
# - Empty/whitespace line skipping
# - Per-line JSON parse error capture with line numbers
# - Duplicate `sample_id` detection
# - Format consistency checks

# %%
# ═══════════════════════════════════════════════════════════════
# JSONL LOADER
# ═══════════════════════════════════════════════════════════════
import json
from pathlib import Path

def robust_jsonl_loader(filepath: str) -> tuple:
    """
    Handles all common JSONL corruption patterns:
    - Standard one-JSON-per-line
    - JSON arrays (entire batch pasted as [...])
    - Pretty-printed JSON spanning multiple lines
    - Concatenated objects on same line
    """
    valid_rows = []
    errors = []
    seen_ids = set()
    
    raw_text = Path(filepath).read_text(encoding='utf-8')
    
    stripped = raw_text.strip()
    if stripped.startswith('['):
        try:
            arr = json.loads(stripped)
            if isinstance(arr, list):
                for i, item in enumerate(arr):
                    if isinstance(item, dict):
                        sid = item.get('sample_id', '')
                        if sid and sid not in seen_ids:
                            seen_ids.add(sid)
                            valid_rows.append(item)
                        elif sid in seen_ids:
                            errors.append({"source": "array", "error": f"Duplicate: {sid}"})
                    else:
                        errors.append({"source": "array", "error": f"Item {i} not a dict"})
                return valid_rows, errors
        except json.JSONDecodeError:
            pass
    
    lines = raw_text.split('\n')
    buffer = ""
    brace_depth = 0
    
    for line_num, line in enumerate(lines, start=1):
        stripped_line = line.strip()
        if not stripped_line:
            continue
        
        # Track brace depth to handle pretty printed JSON
        for char in stripped_line:
            if char == '{':
                brace_depth += 1
            elif char == '}':
                brace_depth -= 1
        
        buffer += stripped_line + " "
        
        if brace_depth == 0 and buffer.strip():
            candidate = buffer.strip()
            
            candidate = candidate.strip(',').strip()
            if candidate.startswith('['):
                candidate = candidate[1:]
            if candidate.endswith(']'):
                candidate = candidate[:-1]
            candidate = candidate.strip().strip(',').strip()
            
            if not candidate:
                buffer = ""
                continue
            
            try:
                obj = json.loads(candidate)
                if isinstance(obj, dict):
                    sid = obj.get('sample_id', '')
                    if sid and sid not in seen_ids:
                        seen_ids.add(sid)
                        obj['_line_num'] = line_num
                        valid_rows.append(obj)
                    elif sid in seen_ids:
                        errors.append({"line": line_num, "error": f"Duplicate: {sid}"})
                    else:
                        errors.append({"line": line_num, "error": "Missing sample_id"})
                elif isinstance(obj, list):
                    for item in obj:
                        if isinstance(item, dict):
                            sid = item.get('sample_id', '')
                            if sid and sid not in seen_ids:
                                seen_ids.add(sid)
                                item['_line_num'] = line_num
                                valid_rows.append(item)
                buffer = ""
            except json.JSONDecodeError:
                parts = candidate.replace('}{', '}\n{').split('\n')
                if len(parts) > 1:
                    for part in parts:
                        part = part.strip().strip(',').strip()
                        if part:
                            try:
                                obj = json.loads(part)
                                if isinstance(obj, dict):
                                    sid = obj.get('sample_id', '')
                                    if sid and sid not in seen_ids:
                                        seen_ids.add(sid)
                                        obj['_line_num'] = line_num
                                        valid_rows.append(obj)
                            except json.JSONDecodeError:
                                errors.append({"line": line_num, "error": "Parse failed", "preview": part[:100]})
                else:
                    errors.append({"line": line_num, "error": "Parse failed", "preview": candidate[:100]})
                buffer = ""
        
        # Safety
        if len(buffer) > 500000:
            errors.append({"line": line_num, "error": "Buffer overflow — malformed section"})
            buffer = ""
            brace_depth = 0
    
    if buffer.strip():
        errors.append({"error": "Unterminated JSON at end of file", "preview": buffer[:100]})
    
    return valid_rows, errors


# Load
DATA_PATH = "auditor_dataset.jsonl"
rows, load_errors = robust_jsonl_loader(DATA_PATH)

print(f"Loaded: {len(rows)} rows")
print(f"Errors: {len(load_errors)}")
if load_errors:
    for err in load_errors[:10]:
        print(f"  {err}")

# Check ID range
ids = sorted([r.get('sample_id', '') for r in rows])
print(f"\nID range: {ids[0]} .. {ids[-1]}")
print(f"Expected ~840, got {len(rows)}")
if len(rows) < 700:
    print("⚠ Still missing rows — check if file has multiple formats mixed")
# Out:
# Loaded: 840 rows
# Errors: 0
#
# ID range: AUD-SYNC26-001 .. AUD-SYNC26-840
# Expected ~840, got 840

# %%
# ═══════════════════════════════════════════════════════════════
# Add missing 'generatedat' to affected rows
# ═══════════════════════════════════════════════════════════════
fixed_generatedat = 0
for row in rows:
    plan = row.get('input_payload', {}).get('plan', {})
    if 'generatedat' not in plan:
        plan['generatedat'] = "2026-03-15T00:00:00Z"
        fixed_generatedat += 1

print(f"Fixed missing generatedat: {fixed_generatedat} rows")
# Out:
# Fixed missing generatedat: 24 rows

# %%
# Basic dataset overview
if rows:
    print(f"Total rows: {len(rows)}")
    print(f"Sample IDs range: {rows[0].get('sample_id','?')} .. {rows[-1].get('sample_id','?')}")

    # Quick field presence check
    top_keys = set()
    for r in rows:
        top_keys.update(r.keys())
    top_keys.discard('_line_num')
    print(f"Top-level keys found: {sorted(top_keys)}")

    # Case type distribution
    case_types = Counter(r.get('metadata', {}).get('case_type', 'MISSING') for r in rows)
    print(f"Case type distribution: {dict(case_types)}")

    # Project class distribution
    pclasses = Counter(r.get('profile', {}).get('projectclass', 'MISSING') for r in rows)
    print(f"Project class distribution: {dict(pclasses)}")
else:
    print("No data loaded. Cannot proceed.")
# Out:
# Total rows: 840
# Sample IDs range: AUD-SYNC26-001 .. AUD-SYNC26-840
# Top-level keys found: ['agent', 'dataset', 'input_payload', 'metadata', 'profile', 'sample_id', 'split', 'target_output']
# Case type distribution: {'first_pass': 367, 'revision_round': 473}
# Project class distribution: {'fullstackapp': 53, 'apiservice': 79, 'clitool': 50, 'aisystem': 70, 'datapipeline': 80, 'staticwebsite': 48, 'mobileapp': 81, 'librarysdk': 55, 'webapp': 82, 'infrastructureproject': 64, 'desktopapp': 55, 'automationtool': 61, 'researchprototype': 38, 'landingpage': 24}

# %% [markdown]
# ---
# ## Section 2 - Audit Chain Reconstruction
#
# Rows in this dataset are NOT independent observations. They form **audit chains** — sequences
# of rows representing the same project going through multiple architect-auditor revision rounds.
#
# Rows within a chain share the same frozen requirement contract but have different `round` numbers,
# evolving plans, and progressive issue resolution.
#
# Identifying chains is critical because:
# - Near-identical frozen contracts across chain members are **intentional**, not duplicates
# - Cross-round validation (issue-ID stability, score trajectories) only works within chains
# - Deduplication must operate at chain level, not row level

# %%
def compute_contract_fingerprint(row: Dict) -> str:
    """
    Create a stable fingerprint from the frozen requirement contract.
    Rows with identical fingerprints belong to the same audit chain.
    """
    contract = row.get('input_payload', {}).get('frozenrequirementcontract', {})
    canonical_parts = []
    for key in sorted(contract.keys()):
        field = contract[key]
        if isinstance(field, dict):
            canonical_parts.append(f"{key}={field.get('value', '')}")
        else:
            canonical_parts.append(f"{key}={field}")
    fingerprint_str = "|".join(canonical_parts)
    return hashlib.sha256(fingerprint_str.encode()).hexdigest()[:16]


def reconstruct_chains(rows: List[Dict]) -> Dict[str, List[Dict]]:
    """
    Group rows into audit chains by contract fingerprint.
    Within each chain, sort by round number.
    """
    chains = defaultdict(list)
    for row in rows:
        fp = compute_contract_fingerprint(row)
        row['_chain_id'] = fp
        chains[fp].append(row)

    # Sort each chain by round number
    for chain_id in chains:
        chains[chain_id].sort(key=lambda r: r.get('input_payload', {}).get('round', 0))

    return dict(chains)


# Reconstruct chains
if rows:
    chains = reconstruct_chains(rows)
    chain_lengths = [len(v) for v in chains.values()]

    print(f"Total chains identified: {len(chains)}")
    print(f"Chain length distribution:")
    length_counts = Counter(chain_lengths)
    for length in sorted(length_counts.keys()):
        print(f"  Length {length}: {length_counts[length]} chains ({length_counts[length] * length} rows)")
    print(f"  Mean chain length: {np.mean(chain_lengths):.2f}")
    print(f"  Max chain length: {max(chain_lengths)}")

    # Identify single-row chains (first_pass only) vs multi-row chains
    single_chains = sum(1 for v in chains.values() if len(v) == 1)
    multi_chains = sum(1 for v in chains.values() if len(v) > 1)
    print(f"\nSingle-row chains (first_pass): {single_chains}")
    print(f"Multi-row chains (revision sequences): {multi_chains}")
else:
    chains = {}
# Out:
# Total chains identified: 420
# Chain length distribution:
#   Length 1: 117 chains (117 rows)
#   Length 2: 207 chains (414 rows)
#   Length 3: 80 chains (240 rows)
#   Length 4: 12 chains (48 rows)
#   Length 5: 3 chains (15 rows)
#   Length 6: 1 chains (6 rows)
#   Mean chain length: 2.00
#   Max chain length: 6
#
# Single-row chains (first_pass): 117
# Multi-row chains (revision sequences): 303

# %%
# Visualise chain length distribution
if chains:
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))

    # Chain length histogram
    axes[0].hist(chain_lengths, bins=range(1, max(chain_lengths) + 2), edgecolor='black', alpha=0.7, color='#4C72B0')
    axes[0].set_xlabel('Chain Length (rounds)')
    axes[0].set_ylabel('Number of Chains')
    axes[0].set_title('Audit Chain Length Distribution')
    axes[0].set_xticks(range(1, max(chain_lengths) + 1))

    # Rows per chain length
    rows_per_length = defaultdict(int)
    for v in chains.values():
        rows_per_length[len(v)] += len(v)
    lengths = sorted(rows_per_length.keys())
    axes[1].bar(lengths, [rows_per_length[l] for l in lengths],
                edgecolor='black', alpha=0.7, color='#DD8452')
    axes[1].set_xlabel('Chain Length')
    axes[1].set_ylabel('Total Rows')
    axes[1].set_title('Rows Contributed by Each Chain Length')
    axes[1].set_xticks(lengths)

    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / 'chain_distribution.png', bbox_inches='tight')
    plt.show()
    print("Saved: chain_distribution.png")
# Out:
# Saved: chain_distribution.png

# %% [markdown]
# ---
# ## Section 3 - Structural Schema Validation
#
# This section implements a recursive schema validator that checks every row against the exact
# nested structure specified in the generation prompt. Each violation is categorised by severity:
#
# - **FATAL**: Missing required sections or wrong data types that would crash the runtime
# - **ERROR**: Missing required fields within sections
# - **WARNING**: Minor issues like missing optional fields or suspicious values

# %%
class SchemaValidator:
    """Recursive schema validator for AuditorAgent training rows."""

    def __init__(self):
        self.violations = []

    def reset(self):
        self.violations = []

    def add(self, severity: str, path: str, message: str):
        self.violations.append({"severity": severity, "path": path, "message": message})

    def check_type(self, value, expected_type, path: str, label: str):
        if not isinstance(value, expected_type):
            self.add("FATAL", path, f"{label} expected {expected_type.__name__}, got {type(value).__name__}")
            return False
        return True

    def check_key_exists(self, d: dict, key: str, path: str, severity="ERROR"):
        if key not in d:
            self.add(severity, f"{path}.{key}", f"Missing required key '{key}'")
            return False
        return True

    def validate_contract_field(self, field: dict, path: str):
        """Validate a single frozen contract field object."""
        if not isinstance(field, dict):
            self.add("FATAL", path, f"Contract field must be dict, got {type(field).__name__}")
            return
        for subkey in CONTRACT_FIELD_SUBKEYS:
            if subkey not in field:
                self.add("ERROR", f"{path}.{subkey}", f"Missing contract sub-key '{subkey}'")
        if 'confirmed' in field and not isinstance(field['confirmed'], bool):
            self.add("WARNING", f"{path}.confirmed", f"'confirmed' should be bool, got {type(field['confirmed']).__name__}")

    def validate_row(self, row: Dict) -> List[Dict]:
        """Run full validation on a single row. Returns list of violations."""
        self.reset()
        sid = row.get('sample_id', 'UNKNOWN')

        # Top-level keys
        required_top = {"sample_id", "dataset", "agent", "split",
                        "profile", "input_payload", "target_output", "metadata"}
        for key in required_top:
            self.check_key_exists(row, key, "root", "FATAL")

        # Profile
        profile = row.get('profile', {})
        if self.check_type(profile, dict, "profile", "profile"):
            for pk in ["domain", "projectclass", "capabilities", "complexitylevel",
                        "risklevel", "datasensitivity", "externalexposure"]:
                self.check_key_exists(profile, pk, "profile")
            if 'capabilities' in profile and not isinstance(profile['capabilities'], list):
                self.add("ERROR", "profile.capabilities", "Must be a list")

        # Input payload
        payload = row.get('input_payload', {})
        if self.check_type(payload, dict, "input_payload", "input_payload"):
            for pk in ["round", "frozenrequirementcontract", "requirements",
                        "acceptedexceptions", "issueledger", "revisionmemory",
                        "previousaudits", "reasonerreviews", "specialistsubplans",
                        "plan", "bestaudit"]:
                self.check_key_exists(payload, pk, "input_payload")

            # Round must be integer
            if 'round' in payload and not isinstance(payload['round'], int):
                self.add("ERROR", "input_payload.round", f"Round must be int, got {type(payload['round']).__name__}")

            # Frozen requirement contract
            contract = payload.get('frozenrequirementcontract', {})
            if self.check_type(contract, dict, "frozenrequirementcontract", "contract"):
                for mf in MANDATORY_CONTRACT_FIELDS:
                    if self.check_key_exists(contract, mf, "frozenrequirementcontract"):
                        self.validate_contract_field(contract[mf], f"frozenrequirementcontract.{mf}")

            # Requirements
            reqs = payload.get('requirements', {})
            if self.check_type(reqs, dict, "requirements", "requirements"):
                for section in REQUIRED_REQ_SECTIONS:
                    if section in reqs:
                        if isinstance(reqs[section], list):
                            self.add("ERROR", f"requirements.{section}", "Must be dict, got list (arrays forbidden)")
                        elif not isinstance(reqs[section], dict):
                            self.add("WARNING", f"requirements.{section}", f"Expected dict, got {type(reqs[section]).__name__}")

            # Previous audits must be list
            prev = payload.get('previousaudits')
            if prev is not None and not isinstance(prev, list):
                self.add("ERROR", "input_payload.previousaudits", "Must be a list")

            # Plan
            plan = payload.get('plan', {})
            if self.check_type(plan, dict, "plan", "plan"):
                for pk in MANDATORY_PLAN_KEYS:
                    self.check_key_exists(plan, pk, "plan")
                if 'fixreport' in plan and not isinstance(plan['fixreport'], list):
                    self.add("ERROR", "plan.fixreport", "Must be a list")

        # Target output
        output = row.get('target_output', {})
        if self.check_type(output, dict, "target_output", "target_output"):
            for ok in MANDATORY_OUTPUT_KEYS:
                self.check_key_exists(output, ok, "target_output")

            # Rubric scores
            rubric = output.get('rubricscores', {})
            if self.check_type(rubric, dict, "rubricscores", "rubricscores"):
                for dim in RUBRIC_DIMENSIONS:
                    if self.check_key_exists(rubric, dim, "rubricscores"):
                        score = rubric[dim]
                        if not isinstance(score, (int, float)):
                            self.add("ERROR", f"rubricscores.{dim}", f"Must be numeric, got {type(score).__name__}")
                        elif not (0 <= score <= 10):
                            self.add("ERROR", f"rubricscores.{dim}", f"Out of range: {score} (must be 0-10)")

            # Issue updates structure
            for iu in output.get('issueupdates', []):
                if isinstance(iu, dict):
                    for ik in ['id', 'title', 'severity', 'status', 'detail']:
                        if ik not in iu:
                            self.add("ERROR", "issueupdates.item", f"Missing key '{ik}' in issue update")

            # Requirement conflicts structure
            for rc in output.get('requirementconflicts', []):
                if isinstance(rc, dict):
                    for rk in ['issueid', 'field', 'currentvalue',
                                'proposedvalue', 'exactreason', 'severity']:
                        if rk not in rc:
                            self.add("ERROR", "requirementconflicts.item", f"Missing key '{rk}' in conflict")

        # Metadata
        meta = row.get('metadata', {})
        if self.check_type(meta, dict, "metadata", "metadata"):
            for mk in ["schema_version", "case_type", "primary_flaw_family",
                        "secondary_flaw_families", "intended_severity_mix",
                        "generation_source"]:
                self.check_key_exists(meta, mk, "metadata")

        return self.violations


# Run structural validation
if rows:
    validator = SchemaValidator()
    all_violations = {}
    violation_summary = Counter()
    rows_with_fatal = 0

    for row in rows:
        sid = row.get('sample_id', 'UNKNOWN')
        violations = validator.validate_row(row)
        if violations:
            all_violations[sid] = violations
            for v in violations:
                violation_summary[v['severity']] += 1
            if any(v['severity'] == 'FATAL' for v in violations):
                rows_with_fatal += 1

    total_violations = sum(violation_summary.values())
    clean_rows = len(rows) - len(all_violations)

    print(f"\n{'='*60}")
    print(f"STRUCTURAL VALIDATION REPORT")
    print(f"{'='*60}")
    print(f"Total rows validated: {len(rows)}")
    print(f"Rows with violations: {len(all_violations)} ({len(all_violations)/len(rows)*100:.1f}%)")
    print(f"Rows with FATAL errors: {rows_with_fatal}")
    print(f"Clean rows: {clean_rows} ({clean_rows/len(rows)*100:.1f}%)")
    print(f"\nViolation breakdown:")
    for sev in ['FATAL', 'ERROR', 'WARNING']:
        count = violation_summary.get(sev, 0)
        print(f"  {sev}: {count}")

    # Most common violation paths
    path_counts = Counter()
    for sid, viols in all_violations.items():
        for v in viols:
            path_counts[v['path']] += 1

    print(f"\nTop 10 most violated paths:")
    for path, count in path_counts.most_common(10):
        print(f"  {path}: {count} occurrences")
else:
    all_violations = {}
    violation_summary = Counter()
# Out:
# ============================================================
# STRUCTURAL VALIDATION REPORT
# ============================================================
# Total rows validated: 840
# Rows with violations: 0 (0.0%)
# Rows with FATAL errors: 0
# Clean rows: 840 (100.0%)
#
# Violation breakdown:
#   FATAL: 0
#   ERROR: 0
#   WARNING: 0
#
# Top 10 most violated paths:

# %% [markdown]
# ---
# ## Section 4 - Enum & Value Domain Compliance
#
# This section validates every categorical field against the allowed enum sets and detects
# forbidden values that the generation prompt explicitly bans. It also checks for snake_case
# key violations inside nested payloads where compact keys are required.

# %%
def find_snake_case_keys(obj: Any, path: str = "", results: list = None) -> List[str]:
    """Recursively find any keys containing underscores (snake_case) in nested objects."""
    if results is None:
        results = []
    if isinstance(obj, dict):
        for key in obj.keys():
            current_path = f"{path}.{key}" if path else key
            if '_' in key and key not in {'sample_id', 'input_payload', 'target_output', '_line_num', '_chain_id'}:
                results.append(current_path)
            find_snake_case_keys(obj[key], current_path, results)
    elif isinstance(obj, list):
        for i, item in enumerate(obj):
            find_snake_case_keys(item, f"{path}[{i}]", results)
    return results


def validate_enums(row: Dict) -> List[Dict]:
    """Validate all enum fields against allowed sets."""
    issues = []
    sid = row.get('sample_id', 'UNKNOWN')
    profile = row.get('profile', {})
    contract = row.get('input_payload', {}).get('frozenrequirementcontract', {})
    output = row.get('target_output', {})
    meta = row.get('metadata', {})

    # Profile enums
    checks = [
        (profile.get('projectclass'), ALLOWED_PROJECT_CLASSES, 'profile.projectclass'),
        (profile.get('complexitylevel'), ALLOWED_COMPLEXITY, 'profile.complexitylevel'),
        (profile.get('risklevel'), ALLOWED_RISK, 'profile.risklevel'),
        (profile.get('datasensitivity'), ALLOWED_SENSITIVITY, 'profile.datasensitivity'),
        (profile.get('externalexposure'), ALLOWED_EXPOSURE, 'profile.externalexposure'),
    ]

    for value, allowed, path in checks:
        if value and value not in allowed:
            issues.append({"path": path, "value": value, "type": "invalid_enum"})

    # Profile capabilities
    for cap in profile.get('capabilities', []):
        if cap not in ALLOWED_CAPABILITIES:
            issues.append({"path": "profile.capabilities", "value": cap, "type": "invalid_capability"})

    # Contract enum values match profile
    enum_fields = {
        'projectclass': ('projectclass', ALLOWED_PROJECT_CLASSES),
        'complexitylevel': ('complexitylevel', ALLOWED_COMPLEXITY),
        'risklevel': ('risklevel', ALLOWED_RISK),
        'datasensitivity': ('datasensitivity', ALLOWED_SENSITIVITY),
        'externalexposure': ('externalexposure', ALLOWED_EXPOSURE),
    }
    for field, (profile_key, allowed) in enum_fields.items():
        cval = contract.get(field, {}).get('value', '')
        pval = profile.get(profile_key, '')
        if cval and cval not in allowed:
            issues.append({"path": f"contract.{field}", "value": cval, "type": "invalid_contract_enum"})
        if cval and pval and cval != pval:
            issues.append({"path": f"contract.{field}", "value": f"contract='{cval}' vs profile='{pval}'", "type": "contract_profile_mismatch"})

    # Issue severities and statuses
    for iu in output.get('issueupdates', []):
        if isinstance(iu, dict):
            sev = iu.get('severity', '')
            if sev and sev not in ALLOWED_SEVERITY:
                issues.append({"path": "issueupdates.severity", "value": sev, "type": "invalid_severity"})
            status = iu.get('status', '')
            if status and status not in ALLOWED_STATUS:
                issues.append({"path": "issueupdates.status", "value": status, "type": "invalid_status"})

    for rc in output.get('requirementconflicts', []):
        if isinstance(rc, dict):
            sev = rc.get('severity', '')
            if sev and sev not in ALLOWED_SEVERITY:
                issues.append({"path": "requirementconflicts.severity", "value": sev, "type": "invalid_severity"})

    # Metadata enums 
    ct = meta.get('case_type', '')
    if ct and ct not in ALLOWED_CASE_TYPE:
        issues.append({"path": "metadata.case_type", "value": ct, "type": "invalid_case_type"})

    pff = meta.get('primary_flaw_family', '')
    if pff and pff not in ALLOWED_FLAW_FAMILIES:
        issues.append({"path": "metadata.primary_flaw_family", "value": pff, "type": "invalid_flaw_family"})

    for sf in meta.get('secondary_flaw_families', []):
        if sf not in ALLOWED_FLAW_FAMILIES:
            issues.append({"path": "metadata.secondary_flaw_families", "value": sf, "type": "invalid_flaw_family"})

    # Forbidden value scan
    raw_str = json.dumps(row).lower()
    for forbidden in FORBIDDEN_VALUES:
        pattern = r'\b' + re.escape(forbidden) + r'\b'
        if re.search(pattern, raw_str):
            issues.append({"path": "global", "value": forbidden, "type": "forbidden_value"})

    return issues


# Run enum validation
if rows:
    enum_results = {}
    snake_case_results = {}

    for row in rows:
        sid = row.get('sample_id', 'UNKNOWN')

        # Enum check
        enum_issues = validate_enums(row)
        if enum_issues:
            enum_results[sid] = enum_issues

        # Snake case key check
        payload = row.get('input_payload', {})
        output = row.get('target_output', {})
        sc_keys = find_snake_case_keys(payload, "input_payload")
        sc_keys += find_snake_case_keys(output, "target_output")
        if sc_keys:
            snake_case_results[sid] = sc_keys

    print(f"\n{'='*60}")
    print(f"ENUM & VALUE DOMAIN REPORT")
    print(f"{'='*60}")
    print(f"Rows with enum violations: {len(enum_results)} ({len(enum_results)/len(rows)*100:.1f}%)")
    print(f"Rows with snake_case keys: {len(snake_case_results)} ({len(snake_case_results)/len(rows)*100:.1f}%)")

    # Breakdown by type
    type_counts = Counter()
    for sid, issues in enum_results.items():
        for iss in issues:
            type_counts[iss['type']] += 1
    print(f"\nViolation types:")
    for t, c in type_counts.most_common():
        print(f"  {t}: {c}")

    if snake_case_results:
        sc_key_counts = Counter()
        for sid, keys in snake_case_results.items():
            for k in keys:
                sc_key_counts[k] += 1
        print(f"\nTop snake_case key violations:")
        for k, c in sc_key_counts.most_common(10):
            print(f"  {k}: {c} rows")
else:
    enum_results = {}
    snake_case_results = {}
# Out:
# ============================================================
# ENUM & VALUE DOMAIN REPORT
# ============================================================
# Rows with enum violations: 248 (29.5%)
# Rows with snake_case keys: 474 (56.4%)
#
# Violation types:
#   forbidden_value: 242
#   invalid_status: 27
#   invalid_capability: 2
#
# Top snake_case key violations:
#   input_payload.revisionmemory.round_1: 381 rows
#   input_payload.revisionmemory.changes_for_round_2: 328 rows
#   input_payload.revisionmemory.round_2: 99 rows
#   input_payload.revisionmemory.changes_for_round_3: 95 rows
#   input_payload.revisionmemory.round_3: 3 rows
#   input_payload.revisionmemory.changes_for_round_4: 3 rows
#   input_payload.requirements.confirmeddecisions.no_telemetry: 1 rows

# %% [markdown]
# ---
# ## Section 5 - Cross-Field Consistency Validation
#
# This section checks the logical invariants that must hold across fields within each row:
#
# 1. **Conditional field rules**: `llmintegration` required when capabilities include `aillm`;
#    `compliancecontext` required when risk/sensitivity thresholds are met
# 2. **First-pass vs revision-round invariants**: round number, previous audits, fix reports
# 3. **Issue-ID stability across rounds**: within chains
# 4. **Issue-detail template compliance**: strict format check
# 5. **Metadata-output agreement**: flaw families match actual issues

# %%
def validate_cross_field(row: Dict) -> List[Dict]:
    """Validate cross-field consistency rules."""
    issues = []
    profile = row.get('profile', {})
    payload = row.get('input_payload', {})
    output = row.get('target_output', {})
    meta = row.get('metadata', {})
    contract = payload.get('frozenrequirementcontract', {})
    round_num = payload.get('round', 1)
    case_type = meta.get('case_type', '')

    capabilities = profile.get('capabilities', [])
    risk = profile.get('risklevel', '')
    sensitivity = profile.get('datasensitivity', '')

    # 1. Conditional field: llmintegration
    if 'aillm' in capabilities:
        if 'llmintegration' not in contract:
            issues.append({"rule": "conditional_llm", "severity": "ERROR", "detail": "capabilities includes 'aillm' but contract missing 'llmintegration'"})

    # 2. Conditional field: compliancecontext
    needs_compliance = (
        risk == 'high' or
        sensitivity in ('personal', 'financial', 'health', 'confidential') or 'payments' in capabilities
    )
    if needs_compliance and 'compliancecontext' not in contract:
        issues.append({"rule": "conditional_compliance", "severity": "ERROR", "detail": f"Risk={risk}, sensitivity={sensitivity} requires 'compliancecontext'"})

    # 3. First-pass invariants
    if case_type == 'first_pass':
        if round_num != 1:
            issues.append({"rule": "first_pass_round", "severity": "WARNING", "detail": f"first_pass but round={round_num} (expected 1)"})
        prev = payload.get('previousaudits', [])
        if prev and len(prev) > 0:
            issues.append({"rule": "first_pass_prevaudits", "severity": "WARNING", "detail": "first_pass should have empty previousaudits"})

    # 4. Revision-round invariants
    if case_type == 'revision_round':
        if round_num <= 1:
            issues.append({"rule": "revision_round_num", "severity": "ERROR", "detail": f"revision_round but round={round_num} (expected > 1)"})
        prev = payload.get('previousaudits', [])
        if not prev or len(prev) == 0:
            issues.append({"rule": "revision_no_prevaudits", "severity": "ERROR", "detail": "revision_round must have non-empty previousaudits"})
        ledger = payload.get('issueledger', {})
        if not ledger:
            issues.append({"rule": "revision_no_ledger", "severity": "ERROR", "detail": "revision_round must have non-empty issueledger"})

        # Fix report should reference prior issues
        fixreport = payload.get('plan', {}).get('fixreport', [])
        if not fixreport:
            issues.append({"rule": "revision_no_fixreport", "severity": "WARNING", "detail": "revision_round should have non-empty fixreport"})

        # Summary must contain progression language
        summary = output.get('summary', '')
        has_progression = any(pw in summary.lower() for pw in PROGRESSION_WORDS)
        if not has_progression:
            issues.append({"rule": "revision_no_progression", "severity": "ERROR", "detail": f"revision_round summary must contain one of {PROGRESSION_WORDS}"})

        # At least one prior issue ID must reappear in issueupdates
        if ledger:
            ledger_ids = set(ledger.keys())
            update_ids = {iu.get('id', '') for iu in output.get('issueupdates', []) if isinstance(iu, dict)}
            overlap = ledger_ids & update_ids
            if not overlap:
                issues.append({"rule": "revision_no_issue_reuse", "severity": "ERROR", "detail": "No prior issue IDs reappear in issueupdates"})

    # 5. Issue-detail template compliance
    for iu in output.get('issueupdates', []):
        if isinstance(iu, dict):
            detail = iu.get('detail', '')
            if detail and not DETAIL_TEMPLATE_RE.match(detail):
                issues.append({"rule": "detail_template", "severity": "ERROR", "detail": f"Issue {iu.get('id','?')}: detail does not start with " f"Fixed/Partially fixed/Unchanged/Newly introduced"})
            # Check for Evidence: and Impact: sections
            if detail:
                if 'Evidence:' not in detail and 'evidence:' not in detail.lower():
                    issues.append({"rule": "detail_no_evidence", "severity": "WARNING", "detail": f"Issue {iu.get('id','?')}: missing 'Evidence:' in detail"})
                if 'Impact:' not in detail and 'impact:' not in detail.lower():
                    issues.append({"rule": "detail_no_impact", "severity": "WARNING", "detail": f"Issue {iu.get('id','?')}: missing 'Impact:' in detail"})

    # 6. Metadata-output agreement
    pff = meta.get('primary_flaw_family', '')
    blocking = output.get('blockingissues', [])
    conflicts = output.get('requirementconflicts', [])
    issue_updates = output.get('issueupdates', [])

    if pff == 'none':
        if blocking:
            issues.append({"rule": "meta_none_but_blocking", "severity": "ERROR", "detail": "primary_flaw_family='none' but blockingissues is non-empty"})
        unresolved_high = any(
            isinstance(iu, dict) and iu.get('status') != 'resolved'
            and iu.get('severity') in ('critical', 'high')
            for iu in issue_updates
        )
        if unresolved_high:
            issues.append({"rule": "meta_none_but_unresolved_high", "severity": "ERROR", "detail": "primary_flaw_family='none' but has unresolved high/critical issues"})

    # intended_severity_mix must match actual issues
    intended_mix = set(meta.get('intended_severity_mix', []))
    actual_severities = {iu.get('severity') for iu in issue_updates if isinstance(iu, dict) and iu.get('status') != 'resolved'}
    if 'critical' in intended_mix and 'critical' not in actual_severities:
        issues.append({"rule": "meta_mix_critical_missing", "severity": "WARNING", "detail": "intended_severity_mix includes 'critical' but no unresolved critical issues"})

    # 7. Case type vs round consistency
    if case_type == 'first_pass' and round_num > 1:
        issues.append({"rule": "case_type_round_mismatch", "severity": "ERROR", "detail": f"case_type=first_pass but round={round_num}"})
    if case_type == 'revision_round' and round_num == 1:
        issues.append({"rule": "case_type_round_mismatch", "severity": "ERROR", "detail": f"case_type=revision_round but round=1"})

    return issues


# Run cross-field validation
if rows:
    crossfield_results = {}
    rule_counts = Counter()

    for row in rows:
        sid = row.get('sample_id', 'UNKNOWN')
        issues = validate_cross_field(row)
        if issues:
            crossfield_results[sid] = issues
            for iss in issues:
                rule_counts[iss['rule']] += 1

    print(f"\n{'='*60}")
    print(f"CROSS-FIELD CONSISTENCY REPORT")
    print(f"{'='*60}")
    print(f"Rows with violations: {len(crossfield_results)} ({len(crossfield_results)/len(rows)*100:.1f}%)")
    print(f"\nRule violation counts:")
    for rule, count in rule_counts.most_common():
        print(f"  {rule}: {count}")
else:
    crossfield_results = {}
# Out:
# ============================================================
# CROSS-FIELD CONSISTENCY REPORT
# ============================================================
# Rows with violations: 301 (35.8%)
#
# Rule violation counts:
#   revision_no_progression: 173
#   conditional_compliance: 152
#   meta_mix_critical_missing: 17
#   meta_none_but_unresolved_high: 5
#   conditional_llm: 4
#   revision_no_fixreport: 2
#   revision_no_issue_reuse: 2

# %% [markdown]
# ---
# ## Section 6 - Score Calibration & Anti-Inflation Analysis
#
# The runtime computes a final score using a weighted rubric formula with severity-based penalties.
# This section independently verifies that rubric scores are calibrated correctly by:
#
# 1. **Recomputing** the base score and penalties from each row's rubric scores and issue updates
# 2. **Detecting anti-inflation violations** where scores are unrealistically high given plan quality
# 3. **Measuring plan richness** as a proxy for whether high scores are justified
# 4. **Identifying the "perfect row" proportion** (must be < 5%)

# %%
def compute_plan_richness(plan: Dict) -> Dict[str, Any]:
    """
    Compute richness metrics for plan sections.
    Returns word counts per section and aggregate specificity score.
    """
    rich_sections = [
        "executivesummary", "architectureoverview", "technologystack",
        "functionalfeaturemap", "systemcomponents", "workflows",
        "datamodel", "apidesign", "securityandcompliance",
        "deploymentandoperations", "observability", "costandscaling",
        "phasedimplementation", "developmentguidelines", "risksandtradeoffs"
    ]

    section_words = {}
    total_words = 0
    one_word_sections = 0

    for section in rich_sections:
        text = str(plan.get(section, ''))
        words = len(text.split())
        section_words[section] = words
        total_words += words
        if words <= 2:
            one_word_sections += 1

    # Specificity score: count technology-specific terms
    plan_text = ' '.join(str(plan.get(s, '')) for s in rich_sections).lower()
    tech_terms = [
        'kubernetes', 'k8s', 'docker', 'ecs', 'fargate', 'lambda', 'rds',
        'dynamodb', 'postgres', 'mongodb', 'redis', 'kafka', 'rabbitmq',
        'nginx', 'express', 'fastapi', 'django', 'spring', 'react', 'vue',
        'angular', 'flutter', 'swift', 'kotlin', 'terraform', 'helm',
        'argocd', 'jenkins', 'github actions', 'datadog', 'prometheus',
        'grafana', 'cloudwatch', 'tls', 'mtls', 'oauth', 'oidc', 'jwt',
        'cognito', 'auth0', 'okta', 'mfa', 'rbac', 'abac', 'waf',
        's3', 'cloudfront', 'alb', 'nlb', 'api gateway', 'sns', 'sqs',
        'openapi', 'graphql', 'grpc', 'rest', 'websocket', 'sse'
    ]
    tech_count = sum(1 for t in tech_terms if t in plan_text)

    return {
        "section_words": section_words,
        "total_words": total_words,
        "mean_words_per_section": total_words / max(len(rich_sections), 1),
        "one_word_sections": one_word_sections,
        "tech_term_count": tech_count,
        "specificity_score": min(10, tech_count * 0.8)
    }


def validate_score_calibration(row: Dict) -> List[Dict]:
    """Check score calibration rules."""
    issues = []
    output = row.get('target_output', {})
    plan = row.get('input_payload', {}).get('plan', {})
    profile = row.get('profile', {})
    rubric = output.get('rubricscores', {})

    if not rubric:
        return issues

    # Compute base score
    base_score = sum(
        rubric.get(dim, 0) * weight
        for dim, weight in RUBRIC_WEIGHTS.items()
    )

    # Compute penalty
    penalty = 0.0
    has_unresolved_critical = False
    for iu in output.get('issueupdates', []):
        if isinstance(iu, dict):
            status = str(iu.get('status', '')).lower()
            severity = str(iu.get('severity', '')).lower()
            if status == 'resolved':
                continue
            penalty += SEVERITY_PENALTIES.get(severity, 0)
            if severity == 'critical':
                has_unresolved_critical = True

    implied_score = max(0, min(10, base_score - penalty))

    # Plan richness
    richness = compute_plan_richness(plan)

    # Anti-inflation checks
    avg_rubric = np.mean([rubric.get(d, 0) for d in RUBRIC_DIMENSIONS])

    # Rule 1: All 10s check
    all_tens = all(rubric.get(d, 0) == 10 for d in RUBRIC_DIMENSIONS)
    if all_tens:
        issues.append({"rule": "all_tens", "severity": "WARNING", "detail": "All rubric scores are 10 — verify plan is exceptionally strong"})

    # Rule 2: Architecture quality >= 9 requires non-thin plan
    aq = rubric.get('architecturequality', 0)
    if aq >= 9 and richness['mean_words_per_section'] < 15:
        issues.append({"rule": "arch_inflation", "severity": "ERROR", "detail": f"architecturequality={aq} but mean section length is " f"{richness['mean_words_per_section']:.0f} words (thin plan)"})

    # Rule 3: Operability >= 9 requires concrete deployment detail
    op = rubric.get('operability', 0)
    deploy_words = richness['section_words'].get('deploymentandoperations', 0)
    obs_words = richness['section_words'].get('observability', 0)
    if op >= 9 and (deploy_words < 10 or obs_words < 5):
        issues.append({"rule": "ops_inflation", "severity": "ERROR", "detail": f"operability={op} but deployment={deploy_words}w, " f"observability={obs_words}w"})

    # Rule 4: Security >= 9 for high-risk/sensitive systems needs concrete controls
    sec = rubric.get('security', 0)
    risk = profile.get('risklevel', '')
    sensitivity = profile.get('datasensitivity', '')
    sec_words = richness['section_words'].get('securityandcompliance', 0)
    if sec >= 9 and (risk == 'high' or sensitivity in ('health', 'financial', 'confidential')):
        if sec_words < 15:
            issues.append({"rule": "security_inflation", "severity": "ERROR", "detail": f"security={sec} for {risk}/{sensitivity} system but " f"securityandcompliance only {sec_words} words"})

    # Rule 5: Blocking issues present but no rubric dimension materially reduced
    blocking = output.get('blockingissues', [])
    if blocking and all(rubric.get(d, 0) > 7 for d in RUBRIC_DIMENSIONS):
        issues.append({"rule": "blocking_no_reduction", "severity": "ERROR", "detail": "Blocking issues present but no rubric dimension <= 7"})

    # Rule 6: High avg rubric but thin plan
    if avg_rubric > 8.0 and richness['one_word_sections'] >= 3:
        issues.append({"rule": "high_score_thin_plan", "severity": "ERROR", "detail": f"Average rubric={avg_rubric:.1f} but " f"{richness['one_word_sections']} sections have <=2 words"})

    return issues, {
        "base_score": round(base_score, 2),
        "penalty": round(penalty, 2),
        "implied_score": round(implied_score, 2),
        "has_unresolved_critical": has_unresolved_critical,
        "avg_rubric": round(avg_rubric, 2),
        "richness": richness
    }


# Run score calibration
if rows:
    calibration_results = {}
    calibration_data = []
    inflation_issues = Counter()

    for row in rows:
        sid = row.get('sample_id', 'UNKNOWN')
        result = validate_score_calibration(row)
        cal_issues, cal_data = result
        cal_data['sample_id'] = sid
        calibration_data.append(cal_data)

        if cal_issues:
            calibration_results[sid] = cal_issues
            for ci in cal_issues:
                inflation_issues[ci['rule']] += 1

    cal_df = pd.DataFrame(calibration_data)

    # Perfect row count
    perfect_rows = sum(
        1 for row in rows
        if all(row.get('target_output', {}).get('rubricscores', {}).get(d, 0) >= 9 for d in RUBRIC_DIMENSIONS)
        and not row.get('target_output', {}).get('blockingissues', [])
        and not row.get('target_output', {}).get('requirementconflicts', [])
    )

    print(f"\n{'='*60}")
    print(f"SCORE CALIBRATION & ANTI-INFLATION REPORT")
    print(f"{'='*60}")
    print(f"Rows with calibration issues: {len(calibration_results)} " f"({len(calibration_results)/len(rows)*100:.1f}%)")
    print(f"\nAnti-inflation rule violations:")
    for rule, count in inflation_issues.most_common():
        print(f"  {rule}: {count}")
    print(f"\nPerfect rows (all >=9, no blockers/conflicts): {perfect_rows} " f"({perfect_rows/len(rows)*100:.1f}%) — target: <5%")

    if len(cal_df) > 0:
        print(f"\nScore Statistics:")
        print(f"  Base score — mean: {cal_df['base_score'].mean():.2f}, " f"std: {cal_df['base_score'].std():.2f}")
        print(f"  Penalty — mean: {cal_df['penalty'].mean():.2f}, " f"max: {cal_df['penalty'].max():.2f}")
        print(f"  Implied score — mean: {cal_df['implied_score'].mean():.2f}, " f"std: {cal_df['implied_score'].std():.2f}")
else:
    calibration_results = {}
    cal_df = pd.DataFrame()
# Out:
# ============================================================
# SCORE CALIBRATION & ANTI-INFLATION REPORT
# ============================================================
# Rows with calibration issues: 354 (42.1%)
#
# Anti-inflation rule violations:
#   arch_inflation: 292
#   high_score_thin_plan: 263
#   ops_inflation: 251
#   security_inflation: 97
#   all_tens: 71
#
# Perfect rows (all >=9, no blockers/conflicts): 276 (32.9%) — target: <5%
#
# Score Statistics:
#   Base score — mean: 6.76, std: 2.48
#   Penalty — mean: 0.67, max: 4.50
#   Implied score — mean: 6.09, std: 3.08

# %%
# Calibration visualisations
if len(cal_df) > 0:
    fig, axes = plt.subplots(2, 2, figsize=(14, 10))

    # 1. Base score distribution
    axes[0, 0].hist(cal_df['base_score'], bins=20, edgecolor='black', alpha=0.7, color='#4C72B0')
    axes[0, 0].axvline(cal_df['base_score'].mean(), color='red', linestyle='--', label='Mean')
    axes[0, 0].set_xlabel('Base Score')
    axes[0, 0].set_ylabel('Count')
    axes[0, 0].set_title('Base Score Distribution (Weighted Rubric)')
    axes[0, 0].legend()

    # 2. Penalty distribution
    axes[0, 1].hist(cal_df['penalty'], bins=20, edgecolor='black', alpha=0.7, color='#DD8452')
    axes[0, 1].set_xlabel('Penalty')
    axes[0, 1].set_ylabel('Count')
    axes[0, 1].set_title('Penalty Distribution')

    # 3. Implied score distribution
    axes[1, 0].hist(cal_df['implied_score'], bins=20, edgecolor='black', alpha=0.7, color='#55A868')
    axes[1, 0].axvline(9.0, color='red', linestyle='--', label='Pass Threshold (9.0)')
    axes[1, 0].set_xlabel('Implied Score')
    axes[1, 0].set_ylabel('Count')
    axes[1, 0].set_title('Implied Final Score Distribution')
    axes[1, 0].legend()

    # 4. Avg rubric vs plan richness (total words)
    richness_words = [cd.get('richness', {}).get('total_words', 0) for cd in calibration_data]
    axes[1, 1].scatter(richness_words, cal_df['avg_rubric'], alpha=0.4, s=15, color='#8172B3')
    axes[1, 1].set_xlabel('Plan Total Words')
    axes[1, 1].set_ylabel('Average Rubric Score')
    axes[1, 1].set_title('Plan Richness vs Average Rubric Score')

    # Add correlation
    if len(richness_words) > 2:
        r, p = stats.pearsonr(richness_words, cal_df['avg_rubric'])
        axes[1, 1].annotate(f'r={r:.3f}, p={p:.4f}', xy=(0.05, 0.95), xycoords='axes fraction', fontsize=10)

    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / 'score_calibration.png', bbox_inches='tight')
    plt.show()
    print("Saved: score_calibration.png")
# Out:
# Saved: score_calibration.png

# %% [markdown]
# ---
# ## Section 7 - Diversity & Coverage Analysis
#
# Measures how well the dataset covers the operational surface of the runtime:
# - Project-class distribution (Shannon entropy)
# - Capability combination diversity (Jaccard distance)
# - First-pass / revision-round ratio (target: 40/60)
# - Flaw-family coverage
# - Score distribution per rubric dimension

# %%
def compute_shannon_entropy(counts: Dict) -> float:
    """Compute Shannon entropy of a distribution."""
    total = sum(counts.values())
    if total == 0:
        return 0.0
    probs = [c / total for c in counts.values() if c > 0]
    return -sum(p * math.log2(p) for p in probs)


def compute_max_entropy(n_classes: int) -> float:
    """Maximum possible Shannon entropy for n_classes."""
    if n_classes <= 1:
        return 0.0
    return math.log2(n_classes)


if rows:
    # Project class distribution
    pc_counts = Counter(r.get('profile', {}).get('projectclass', 'MISSING') for r in rows)

    entropy_pc = compute_shannon_entropy(pc_counts)
    max_entropy_pc = compute_max_entropy(len(ALLOWED_PROJECT_CLASSES))
    normalised_entropy_pc = entropy_pc / max_entropy_pc if max_entropy_pc > 0 else 0

    print(f"{'='*60}")
    print(f"DIVERSITY & COVERAGE REPORT")
    print(f"{'='*60}")
    print(f"\n── Project Class Distribution ──")
    print(f"Entropy: {entropy_pc:.3f} / {max_entropy_pc:.3f} " f"(normalised: {normalised_entropy_pc:.3f})")
    print(f"Classes represented: {len(pc_counts)} / {len(ALLOWED_PROJECT_CLASSES)}")

    missing_classes = ALLOWED_PROJECT_CLASSES - set(pc_counts.keys())
    if missing_classes:
        print(f"Missing classes: {missing_classes}")

    under_represented = {k: v for k, v in pc_counts.items()
                         if v < len(rows) * 0.02}
    if under_represented:
        print(f"Under-represented (<2%): {under_represented}")

    over_represented = {k: v for k, v in pc_counts.items()
                        if v > len(rows) * 0.15}
    if over_represented:
        print(f"Over-represented (>15%): {over_represented}")

    # Capability combination diversity
    cap_combos = Counter(
        tuple(sorted(r.get('profile', {}).get('capabilities', [])))
        for r in rows
    )
    print(f"\n── Capability Combinations ──")
    print(f"Unique combinations: {len(cap_combos)}")
    print(f"Top 5 combinations:")
    for combo, count in cap_combos.most_common(5):
        print(f"  {combo}: {count}")

    # First-pass / revision ratio
    fp_count = sum(1 for r in rows if r.get('metadata', {}).get('case_type') == 'first_pass')
    rr_count = sum(1 for r in rows if r.get('metadata', {}).get('case_type') == 'revision_round')
    total_typed = fp_count + rr_count
    print(f"\n── Case Type Ratio ──")
    print(f"first_pass: {fp_count} ({fp_count/max(total_typed,1)*100:.1f}%) — target: 40%")
    print(f"revision_round: {rr_count} ({rr_count/max(total_typed,1)*100:.1f}%) — target: 60%")
    ratio_deviation = abs(fp_count / max(total_typed, 1) - 0.40)
    print(f"Deviation from target: {ratio_deviation*100:.1f}pp")

    # Flaw family coverage
    flaw_counts = Counter(
        r.get('metadata', {}).get('primary_flaw_family', 'MISSING')
        for r in rows
    )
    entropy_ff = compute_shannon_entropy(flaw_counts)
    max_entropy_ff = compute_max_entropy(len(ALLOWED_FLAW_FAMILIES))

    print(f"\n── Flaw Family Coverage ──")
    print(f"Entropy: {entropy_ff:.3f} / {max_entropy_ff:.3f}")
    print(f"Families represented: {len(flaw_counts)} / {len(ALLOWED_FLAW_FAMILIES)}")
    missing_flaws = ALLOWED_FLAW_FAMILIES - set(flaw_counts.keys())
    if missing_flaws:
        print(f"Missing flaw families: {missing_flaws}")

    # Severity distribution
    all_severities = []
    for r in rows:
        for iu in r.get('target_output', {}).get('issueupdates', []):
            if isinstance(iu, dict):
                all_severities.append(iu.get('severity', 'MISSING'))
    sev_counts = Counter(all_severities)
    print(f"\n── Issue Severity Distribution ──")
    for s in ['critical', 'high', 'medium', 'low']:
        print(f"  {s}: {sev_counts.get(s, 0)}")
# Out:
# ============================================================
# DIVERSITY & COVERAGE REPORT
# ============================================================
#
# ── Project Class Distribution ──
# Entropy: 3.747 / 3.807 (normalised: 0.984)
# Classes represented: 14 / 14
#
# ── Capability Combinations ──
# Unique combinations: 69
# Top 5 combinations:
#   ('frontend',): 99
#   ('devops',): 70
#   ('backend', 'data', 'frontend'): 58
#   ('auth', 'backend', 'frontend'): 50
#   ('backend',): 48
#
# ── Case Type Ratio ──
# first_pass: 367 (43.7%) — target: 40%
# revision_round: 473 (56.3%) — target: 60%
# Deviation from target: 3.7pp
#
# ── Flaw Family Coverage ──
# Entropy: 2.502 / 3.459
# Families represented: 11 / 11
#
# ── Issue Severity Distribution ──
#   critical: 541
#   high: 400
#   medium: 44
#   low: 1

# %%
# Diversity visualisations
if rows:
    fig, axes = plt.subplots(2, 2, figsize=(16, 12))

    # 1. Project class distribution
    pc_series = pd.Series(pc_counts).sort_values(ascending=True)
    pc_series.plot(kind='barh', ax=axes[0, 0], color='#4C72B0', edgecolor='black')
    axes[0, 0].set_xlabel('Count')
    axes[0, 0].set_title(f'Project Class Distribution (entropy={entropy_pc:.2f})')
    axes[0, 0].axvline(len(rows) * 0.02, color='red', linestyle='--', alpha=0.5, label='2% threshold')
    axes[0, 0].legend()

    # 2. Flaw family distribution
    ff_series = pd.Series(flaw_counts).sort_values(ascending=True)
    ff_series.plot(kind='barh', ax=axes[0, 1], color='#DD8452', edgecolor='black')
    axes[0, 1].set_xlabel('Count')
    axes[0, 1].set_title(f'Flaw Family Distribution (entropy={entropy_ff:.2f})')

    # 3. Case type pie chart (actual vs target)
    axes[1, 0].pie([fp_count, rr_count], labels=['first_pass', 'revision_round'],
                    autopct='%1.1f%%', colors=['#55A868', '#C44E52'], startangle=90)
    axes[1, 0].set_title(f'Case Type Split (target: 40/60)')

    # 4. Rubric score distributions (box plots)
    rubric_data = []
    for r in rows:
        rub = r.get('target_output', {}).get('rubricscores', {})
        for dim in RUBRIC_DIMENSIONS:
            if dim in rub:
                rubric_data.append({"dimension": dim, "score": rub[dim]})
    if rubric_data:
        rub_df = pd.DataFrame(rubric_data)
        rub_df.boxplot(column='score', by='dimension', ax=axes[1, 1], grid=False)
        axes[1, 1].set_title('Rubric Score Distributions by Dimension')
        axes[1, 1].set_xlabel('Dimension')
        axes[1, 1].set_ylabel('Score')
        plt.sca(axes[1, 1])
        plt.xticks(rotation=45, ha='right')

    plt.suptitle('')
    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / 'diversity_coverage.png', bbox_inches='tight')
    plt.show()
    print("Saved: diversity_coverage.png")
# Out:
# Saved: diversity_coverage.png

# %% [markdown]
# ---
# ## Section 8 - Duplication & Redundancy Detection
#
# Three levels of deduplication, all **chain-aware**:
#
# 1. **Exact deduplication**: SHA-256 hash of row content (excluding metadata fields)
# 2. **Structural fingerprinting**: Feature vector based on categorical fields and score tuples
# 3. **Semantic similarity**: TF-IDF vectorisation of plan and audit text, cosine similarity with
#    hierarchical clustering to identify near-duplicate clusters
#
# Crucially, rows within the same audit chain are **excluded** from duplicate detection
# because their shared contract content is intentional.

# %%
def get_content_hash(row: Dict) -> str:
    """Hash row content excluding non-content fields."""
    clean = {k: v for k, v in row.items()
             if k not in ('_line_num', '_chain_id', 'sample_id')}
    canonical = json.dumps(clean, sort_keys=True, ensure_ascii=False)
    return hashlib.sha256(canonical.encode()).hexdigest()


def get_structural_fingerprint(row: Dict) -> str:
    """Create feature fingerprint from categorical fields and score tuple."""
    profile = row.get('profile', {})
    rubric = row.get('target_output', {}).get('rubricscores', {})
    meta = row.get('metadata', {})
    payload = row.get('input_payload', {})

    parts = [
        profile.get('projectclass', ''),
        ','.join(sorted(profile.get('capabilities', []))),
        profile.get('risklevel', ''),
        profile.get('datasensitivity', ''),
        str(payload.get('round', '')),
        meta.get('case_type', ''),
        meta.get('primary_flaw_family', ''),
        ','.join(str(rubric.get(d, '')) for d in RUBRIC_DIMENSIONS),
    ]

    # Include sorted issue IDs
    issue_ids = sorted(
        iu.get('id', '') for iu in row.get('target_output', {}).get('issueupdates', [])
        if isinstance(iu, dict)
    )
    parts.append(','.join(issue_ids))

    return '|'.join(parts)


def extract_text_for_similarity(row: Dict) -> str:
    """Concatenate plan sections and audit text for TF-IDF vectorisation."""
    plan = row.get('input_payload', {}).get('plan', {})
    output = row.get('target_output', {})

    parts = []
    for key in MANDATORY_PLAN_KEYS:
        val = plan.get(key, '')
        if isinstance(val, str) and val:
            parts.append(val)
        elif isinstance(val, list):
            parts.append(' '.join(str(v) for v in val))

    parts.append(str(output.get('summary', '')))
    parts.append(' '.join(str(s) for s in output.get('strengths', [])))
    parts.append(' '.join(str(c) for c in output.get('concerns', [])))
    parts.append(' '.join(str(b) for b in output.get('blockingissues', [])))

    return ' '.join(parts)


# Run deduplication analysis
if rows:
    # 1. Exact hash deduplication
    hash_map = defaultdict(list)
    for row in rows:
        h = get_content_hash(row)
        hash_map[h].append(row.get('sample_id', 'UNKNOWN'))
    exact_dupes = {h: ids for h, ids in hash_map.items() if len(ids) > 1}

    # 2. Structural fingerprint deduplication
    fp_map = defaultdict(list)
    for row in rows:
        fp = get_structural_fingerprint(row)
        fp_map[fp].append((row.get('sample_id', 'UNKNOWN'), row.get('_chain_id', '')))

    structural_dupes = {}
    for fp, entries in fp_map.items():
        chain_ids = set(e[1] for e in entries)
        if len(chain_ids) > 1:
            structural_dupes[fp] = entries

    print(f"\n{'='*60}")
    print(f"DUPLICATION & REDUNDANCY REPORT")
    print(f"{'='*60}")
    print(f"\n── Exact Duplicates ──")
    print(f"Duplicate groups: {len(exact_dupes)}")
    if exact_dupes:
        for h, ids in list(exact_dupes.items())[:5]:
            print(f"  {ids}")

    print(f"\n── Structural Duplicates (cross-chain) ──")
    print(f"Structural duplicate groups: {len(structural_dupes)}")
    for fp, entries in list(structural_dupes.items())[:3]:
        print(f"  IDs: {[e[0] for e in entries]}")

    # 3. Semantic similarity (TF-IDF + cosine, cross-chain)
    print(f"\n── Semantic Similarity Analysis ──")
    texts = []
    text_ids = []
    text_chains = []
    for row in rows:
        text = extract_text_for_similarity(row)
        texts.append(text)
        text_ids.append(row.get('sample_id', 'UNKNOWN'))
        text_chains.append(row.get('_chain_id', ''))

    if len(texts) > 1:
        vectorizer = TfidfVectorizer(max_features=5000, stop_words='english', ngram_range=(1, 2), min_df=2)
        tfidf_matrix = vectorizer.fit_transform(texts)
        sim_matrix = cosine_similarity(tfidf_matrix)

        # Find cross-chain near-duplicates (similarity > 0.92)
        SIMILARITY_THRESHOLD = 0.92
        near_dupes = []
        for i in range(len(rows)):
            for j in range(i + 1, len(rows)):
                if text_chains[i] != text_chains[j]:
                    if sim_matrix[i, j] > SIMILARITY_THRESHOLD:
                        near_dupes.append({
                            "row_a": text_ids[i],
                            "row_b": text_ids[j],
                            "similarity": round(float(sim_matrix[i, j]), 4)
                        })

        print(f"Near-duplicate pairs (cosine > {SIMILARITY_THRESHOLD}, cross-chain): {len(near_dupes)}")
        if near_dupes:
            for nd in near_dupes[:10]:
                print(f"  {nd['row_a']} ↔ {nd['row_b']}: {nd['similarity']}")

        # Template repetition detection
        from collections import Counter
        sentence_counts = Counter()
        for text in texts:
            sentences = re.split(r'[.!?]+', text)
            for s in sentences:
                s = s.strip()
                if len(s.split()) > 8:
                    sentence_counts[s.lower()] += 1
        repeated_sentences = {s: c for s, c in sentence_counts.items()
                              if c > len(rows) * 0.05}
        print(f"\n── Template Repetition ──")
        print(f"Sentences appearing in >5% of rows: {len(repeated_sentences)}")
        for s, c in sorted(repeated_sentences.items(), key=lambda x: -x[1])[:5]:
            print(f"  ({c}x) \"{s[:80]}...\"")
    else:
        sim_matrix = None
        near_dupes = []
# Out:
# ============================================================
# DUPLICATION & REDUNDANCY REPORT
# ============================================================
#
# ── Exact Duplicates ──
# Duplicate groups: 0
#
# ── Structural Duplicates (cross-chain) ──
# Structural duplicate groups: 2
#   IDs: ['AUD-SYNC26-580', 'AUD-SYNC26-630']
#   IDs: ['AUD-SYNC26-727', 'AUD-SYNC26-822']
#
# ── Semantic Similarity Analysis ──
# Near-duplicate pairs (cosine > 0.92, cross-chain): 23
#   AUD-SYNC26-279 ↔ AUD-SYNC26-428: 0.9794
#   AUD-SYNC26-279 ↔ AUD-SYNC26-495: 0.9712
#   AUD-SYNC26-280 ↔ AUD-SYNC26-429: 0.9732
#   AUD-SYNC26-280 ↔ AUD-SYNC26-496: 0.968
#   AUD-SYNC26-281 ↔ AUD-SYNC26-430: 0.9786
#   AUD-SYNC26-281 ↔ AUD-SYNC26-497: 0.9667
#   AUD-SYNC26-302 ↔ AUD-SYNC26-423: 0.9831
#   AUD-SYNC26-302 ↔ AUD-SYNC26-471: 0.9355
#   AUD-SYNC26-322 ↔ AUD-SYNC26-425: 0.9719
#   AUD-SYNC26-428 ↔ AUD-SYNC26-495: 0.9699
#
# ── Template Repetition ──
# Sentences appearing in >5% of rows: 0

# %%
# Similarity heatmap
if rows and sim_matrix is not None and len(rows) > 5:
    # Sample for visualization
    sample_size = min(80, len(rows))
    sample_indices = np.random.choice(len(rows), sample_size, replace=False)
    sample_indices.sort()

    sub_matrix = sim_matrix[np.ix_(sample_indices, sample_indices)]
    sub_ids = [text_ids[i][-4:] for i in sample_indices]

    fig, ax = plt.subplots(1, 1, figsize=(14, 12))
    sns.heatmap(sub_matrix, ax=ax, cmap='YlOrRd', vmin=0, vmax=1,
                xticklabels=sub_ids, yticklabels=sub_ids)
    ax.set_title(f'TF-IDF Cosine Similarity (sample of {sample_size} rows)')
    plt.xticks(fontsize=5, rotation=90)
    plt.yticks(fontsize=5)
    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / 'similarity_heatmap.png', bbox_inches='tight')
    plt.show()
    print("Saved: similarity_heatmap.png")
# Out:
# Saved: similarity_heatmap.png

# %% [markdown]
# ---
# ## Section 9 - Bias Detection
#
# This section uses statistical methods to detect systematic biases that would cause the
# fine-tuned model to behave unevenly across input types:
#
# 1. **Score-by-class bias**: ANOVA across project classes
# 2. **Rubric dimension correlation**: Pearson correlation matrix (should show independence)
# 3. **Technology concentration**: Gini coefficient of tech-name frequencies
# 4. **Length-score correlation**: Tests if longer plans get higher scores regardless of quality
# 5. **Sensitivity-level bias**: Whether certain data sensitivity levels systematically score higher

# %%
if rows:
    # Build analysis DataFrame
    analysis_rows = []
    for row in rows:
        profile = row.get('profile', {})
        rubric = row.get('target_output', {}).get('rubricscores', {})
        plan = row.get('input_payload', {}).get('plan', {})
        meta = row.get('metadata', {})

        plan_text = extract_text_for_similarity(row)

        analysis_rows.append({
            'sample_id': row.get('sample_id', ''),
            'projectclass': profile.get('projectclass', ''),
            'risklevel': profile.get('risklevel', ''),
            'datasensitivity': profile.get('datasensitivity', ''),
            'externalexposure': profile.get('externalexposure', ''),
            'complexitylevel': profile.get('complexitylevel', ''),
            'case_type': meta.get('case_type', ''),
            'primary_flaw': meta.get('primary_flaw_family', ''),
            'round': row.get('input_payload', {}).get('round', 0),
            'n_capabilities': len(profile.get('capabilities', [])),
            'plan_words': len(plan_text.split()),
            **{d: rubric.get(d, np.nan) for d in RUBRIC_DIMENSIONS},
            'avg_rubric': np.mean([rubric.get(d, 0) for d in RUBRIC_DIMENSIONS]),
            'n_issues': len(row.get('target_output', {}).get('issueupdates', [])),
            'n_blocking': len(row.get('target_output', {}).get('blockingissues', [])),
        })

    df = pd.DataFrame(analysis_rows)

    print(f"{'='*60}")
    print(f"BIAS DETECTION REPORT")
    print(f"{'='*60}")

    # 1. Score-by-class ANOVA
    print(f"\n── Score-by-Class Bias (ANOVA) ──")
    classes_with_data = [cls for cls in df['projectclass'].unique() if len(df[df['projectclass'] == cls]) >= 3]

    if len(classes_with_data) >= 2:
        groups = [df[df['projectclass'] == cls]['avg_rubric'].values for cls in classes_with_data]
        f_stat, p_value = stats.f_oneway(*groups)
        print(f"F-statistic: {f_stat:.3f}, p-value: {p_value:.4f}")
        if p_value < 0.05:
            print("  ⚠ Significant score-by-class bias detected (p < 0.05)")
            class_means = df.groupby('projectclass')['avg_rubric'].mean().sort_values()
            print(f"  Lowest avg: {class_means.index[0]} ({class_means.iloc[0]:.2f})")
            print(f"  Highest avg: {class_means.index[-1]} ({class_means.iloc[-1]:.2f})")
        else:
            print("  ✓ No significant score-by-class bias")
    else:
        print("  Insufficient class diversity for ANOVA")

    # 2. Rubric dimension correlation
    print(f"\n── Rubric Dimension Correlation ──")
    rubric_cols = [d for d in RUBRIC_DIMENSIONS if d in df.columns]
    if len(rubric_cols) >= 2:
        corr_matrix = df[rubric_cols].corr()
        # Flag high correlations
        for i in range(len(rubric_cols)):
            for j in range(i + 1, len(rubric_cols)):
                r = corr_matrix.iloc[i, j]
                if abs(r) > 0.85:
                    print(f"  ⚠ High correlation: {rubric_cols[i]} ↔ {rubric_cols[j]}: r={r:.3f}")
        max_off_diag = corr_matrix.where(
            ~np.eye(len(rubric_cols), dtype=bool)
        ).abs().max().max()
        print(f"  Max off-diagonal |r|: {max_off_diag:.3f}")
        if max_off_diag < 0.85:
            print("  ✓ Rubric dimensions show reasonable independence")

    # 3. Length-score correlation
    print(f"\n── Length-Score Bias ──")
    if len(df) > 5:
        r_len, p_len = stats.pearsonr(df['plan_words'], df['avg_rubric'])
        print(f"Pearson r (plan_words vs avg_rubric): {r_len:.3f}, p={p_len:.4f}")
        if abs(r_len) > 0.5:
            print("  ⚠ Moderate-to-strong length-score bias detected")
        else:
            print("  ✓ No strong length-score bias")

    # 4. Technology concentration (Gini coefficient)
    print(f"\n── Technology Concentration ──")
    all_plan_text = ' '.join(
        extract_text_for_similarity(r).lower() for r in rows
    )
    tech_terms_found = Counter()
    common_techs = [
        'react', 'node.js', 'express', 'postgresql', 'python', 'django',
        'fastapi', 'flask', 'go', 'rust', 'java', 'spring', 'kotlin',
        'swift', 'flutter', 'vue', 'angular', 'svelte', 'next.js',
        'aws', 'gcp', 'azure', 'kubernetes', 'docker', 'terraform',
        'firebase', 'supabase', 'mongodb', 'redis', 'kafka', 'mysql',
        'sqlite', 'dynamodb', 'snowflake', 'airflow', 'spark',
        'datadog', 'prometheus', 'grafana', 'cloudwatch', 'sentry'
    ]
    for tech in common_techs:
        count = all_plan_text.count(tech)
        if count > 0:
            tech_terms_found[tech] = count

    if tech_terms_found:
        vals = sorted(tech_terms_found.values())
        n = len(vals)
        if n > 0:
            cumsum = np.cumsum(vals)
            gini = 1 - 2 * sum(cumsum) / (n * sum(vals)) + 1 / n
            print(f"Technologies mentioned: {len(tech_terms_found)}")
            print(f"Gini coefficient: {gini:.3f} (0=equal, 1=concentrated)")
            print(f"Top 5 technologies:")
            for tech, count in tech_terms_found.most_common(5):
                print(f"  {tech}: {count}")

    # ── 5. Sensitivity-level bias ──
    print(f"\n── Data Sensitivity Level Bias ──")
    sens_groups = df.groupby('datasensitivity')['avg_rubric'].agg(['mean', 'count'])
    print(sens_groups.to_string())
    if len(sens_groups) >= 2:
        sens_values = [df[df['datasensitivity'] == s]['avg_rubric'].values for s in sens_groups.index if len(df[df['datasensitivity'] == s]) >= 3]
        if len(sens_values) >= 2:
            f_s, p_s = stats.f_oneway(*sens_values)
            print(f"ANOVA: F={f_s:.3f}, p={p_s:.4f}")
# Out:
# ============================================================
# BIAS DETECTION REPORT
# ============================================================
#
# ── Score-by-Class Bias (ANOVA) ──
# F-statistic: 0.476, p-value: 0.9383
#   ✓ No significant score-by-class bias
#
# ── Rubric Dimension Correlation ──
#   ⚠ High correlation: requirementsalignment ↔ internalconsistency: r=0.890
#   Max off-diagonal |r|: 0.890
#
# ── Length-Score Bias ──
# Pearson r (plan_words vs avg_rubric): 0.141, p=0.0000
#   ✓ No strong length-score bias
#
# ── Technology Concentration ──
# Technologies mentioned: 39
# Gini coefficient: 0.537 (0=equal, 1=concentrated)
# Top 5 technologies:
#   go: 919
#   aws: 842
#   react: 501
#   python: 490
#   postgresql: 291
#
# ── Data Sensitivity Level Bias ──
#                      mean  count
# datasensitivity
# confidential     6.771429     91
# financial        6.731532    111
# health           6.329412     68
# internal         6.924675    308
# none             6.984431    167
# personal         6.898947     95
# ANOVA: F=0.881, p=0.4931

# %%
# Bias visualisations
if rows and len(df) > 5:
    fig, axes = plt.subplots(2, 2, figsize=(16, 12))

    # 1. Score by project class (box plot)
    class_order = df.groupby('projectclass')['avg_rubric'].mean().sort_values().index
    if len(class_order) > 1:
        sns.boxplot(data=df, x='projectclass', y='avg_rubric', order=class_order,
                    ax=axes[0, 0], palette='Set2')
        axes[0, 0].set_title('Average Rubric Score by Project Class')
        axes[0, 0].tick_params(axis='x', rotation=45)
        axes[0, 0].set_xlabel('')

    # 2. Rubric correlation heatmap
    if len(rubric_cols) >= 2:
        sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='RdBu_r',
                    center=0, ax=axes[0, 1], vmin=-1, vmax=1)
        axes[0, 1].set_title('Rubric Dimension Correlation Matrix')

    # 3. Plan words vs score scatter
    axes[1, 0].scatter(df['plan_words'], df['avg_rubric'], alpha=0.3, s=12, c='#8172B3')
    z = np.polyfit(df['plan_words'], df['avg_rubric'], 1)
    p_fit = np.poly1d(z)
    x_line = np.linspace(df['plan_words'].min(), df['plan_words'].max(), 100)
    axes[1, 0].plot(x_line, p_fit(x_line), 'r--', alpha=0.7, label=f'r={r_len:.3f}')
    axes[1, 0].set_xlabel('Plan Word Count')
    axes[1, 0].set_ylabel('Average Rubric Score')
    axes[1, 0].set_title('Length-Score Bias Analysis')
    axes[1, 0].legend()

    # 4. Technology frequency bar chart
    if tech_terms_found:
        top_techs = dict(tech_terms_found.most_common(15))
        tech_s = pd.Series(top_techs).sort_values()
        tech_s.plot(kind='barh', ax=axes[1, 1], color='#C44E52', edgecolor='black')
        axes[1, 1].set_xlabel('Frequency')
        axes[1, 1].set_title('Technology Mention Frequency')

    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / 'bias_analysis.png', bbox_inches='tight')
    plt.show()
    print("Saved: bias_analysis.png")
# Out:
# Saved: bias_analysis.png

# %% [markdown]
# ---
# ## Section 10 - Chain Progression Validation
#
# For multi-round audit chains, validate the temporal consistency:
# - Issue IDs remain stable across rounds
# - Resolved issues don't reappear without explanation
# - Score trajectories are plausible
# - Fix reports reference the correct prior issue IDs

# %%
def validate_chain_progression(chain: List[Dict]) -> List[Dict]:
    """Validate temporal consistency within an audit chain."""
    issues = []
    if len(chain) < 2:
        return issues

    for i in range(1, len(chain)):
        prev_row = chain[i - 1]
        curr_row = chain[i]

        prev_sid = prev_row.get('sample_id', '?')
        curr_sid = curr_row.get('sample_id', '?')
        prev_round = prev_row.get('input_payload', {}).get('round', 0)
        curr_round = curr_row.get('input_payload', {}).get('round', 0)

        # Round numbers should be sequential
        if curr_round != prev_round + 1:
            issues.append({
                "chain_step": f"{prev_sid} -> {curr_sid}",
                "rule": "round_sequence",
                "detail": f"Rounds {prev_round} -> {curr_round} (expected {prev_round + 1})"
            })

        # Previous issues that were resolved should not reappear as unresolved
        prev_updates = prev_row.get('target_output', {}).get('issueupdates', [])
        curr_updates = curr_row.get('target_output', {}).get('issueupdates', [])

        prev_resolved = {iu.get('id') for iu in prev_updates
                          if isinstance(iu, dict) and iu.get('status') == 'resolved'}
        curr_unresolved = {iu.get('id') for iu in curr_updates
                           if isinstance(iu, dict) and iu.get('status') in ('unresolved', 'new')}

        zombie_issues = prev_resolved & curr_unresolved
        if zombie_issues:
            issues.append({
                "chain_step": f"{prev_sid} -> {curr_sid}",
                "rule": "zombie_issue",
                "detail": f"Issues resolved in round {prev_round} reappear unresolved: {zombie_issues}"
            })

        # Score trajectory plausibility
        prev_rubric = prev_row.get('target_output', {}).get('rubricscores', {})
        curr_rubric = curr_row.get('target_output', {}).get('rubricscores', {})
        if prev_rubric and curr_rubric:
            prev_avg = np.mean([prev_rubric.get(d, 0) for d in RUBRIC_DIMENSIONS])
            curr_avg = np.mean([curr_rubric.get(d, 0) for d in RUBRIC_DIMENSIONS])

            # Large jumps without substantial plan changes are suspicious
            jump = curr_avg - prev_avg
            if abs(jump) > 4:
                issues.append({
                    "chain_step": f"{prev_sid} -> {curr_sid}",
                    "rule": "score_jump",
                    "detail": f"Score jump of {jump:+.1f} (from {prev_avg:.1f} to {curr_avg:.1f})"
                })

        # Fix report should reference prior issue IDs
        curr_fix = curr_row.get('input_payload', {}).get('plan', {}).get('fixreport', [])
        curr_ledger = curr_row.get('input_payload', {}).get('issueledger', {})
        if curr_fix and curr_ledger:
            fix_ids = {f.get('issueid', '') for f in curr_fix if isinstance(f, dict)}
            ledger_ids = set(curr_ledger.keys())
            orphan_fixes = fix_ids - ledger_ids
            if orphan_fixes:
                issues.append({
                    "chain_step": f"{prev_sid} -> {curr_sid}",
                    "rule": "orphan_fix",
                    "detail": f"Fix report references issue IDs not in ledger: {orphan_fixes}"
                })

    return issues


# Run chain progression validation
if chains:
    chain_issues = {}
    chain_rule_counts = Counter()

    for chain_id, chain_rows in chains.items():
        if len(chain_rows) > 1:
            prog_issues = validate_chain_progression(chain_rows)
            if prog_issues:
                chain_issues[chain_id] = prog_issues
                for pi in prog_issues:
                    chain_rule_counts[pi['rule']] += 1

    print(f"\n{'='*60}")
    print(f"CHAIN PROGRESSION VALIDATION REPORT")
    print(f"{'='*60}")
    multi_chains_count = sum(1 for v in chains.values() if len(v) > 1)
    print(f"Multi-round chains validated: {multi_chains_count}")
    print(f"Chains with progression issues: {len(chain_issues)}")
    print(f"\nRule violation counts:")
    for rule, count in chain_rule_counts.most_common():
        print(f"  {rule}: {count}")
# Out:
# ============================================================
# CHAIN PROGRESSION VALIDATION REPORT
# ============================================================
# Multi-round chains validated: 303
# Chains with progression issues: 167
#
# Rule violation counts:
#   score_jump: 160
#   round_sequence: 32
#   zombie_issue: 1

# %% [markdown]
# ---
# ## Section 11 - Missed Issue Detection (Proxy Accuracy)
#
# Scans for cases where the plan deviates from the frozen contract but the auditor fails to
# raise a corresponding issue. This is a proxy for audit accuracy — it measures systematic
# blind spots in the training data.

# %%
def detect_missed_issues(row: Dict) -> List[Dict]:
    """
    Compare plan content against contract fields to find deviations
    not caught by the audit output.
    """
    missed = []
    contract = row.get('input_payload', {}).get('frozenrequirementcontract', {})
    plan = row.get('input_payload', {}).get('plan', {})
    output = row.get('target_output', {})

    # Build set of fields already flagged in requirement conflicts
    flagged_fields = {rc.get('field', '') for rc in output.get('requirementconflicts', []) if isinstance(rc, dict)}

    # Map contract fields to plan sections for cross-reference
    field_plan_map = {
        'observabilitybaseline': ('observability', None),
        'frontendstack': ('technologystack', None),
        'backendstack': ('technologystack', 'architectureoverview'),
        'dataplatform': ('technologystack', 'datamodel'),
        'hostingtarget': ('deploymentandoperations', None),
        'securitybaseline': ('securityandcompliance', None),
    }

    for field, plan_sections in field_plan_map.items():
        if field in flagged_fields:
            continue

        contract_value = contract.get(field, {}).get('value', '').lower().strip()
        if not contract_value:
            continue

        # Check if the contract value appears in the relevant plan sections
        plan_text_parts = []
        if isinstance(plan_sections, tuple):
            for ps in plan_sections:
                if ps:
                    plan_text_parts.append(str(plan.get(ps, '')).lower())
        else:
            plan_text_parts.append(str(plan.get(plan_sections, '')).lower())

        plan_text = ' '.join(plan_text_parts)

        # Extract key terms from contract value
        contract_terms = [t.strip() for t in contract_value.split() if len(t.strip()) > 2]

        if not contract_terms:
            continue

        # Check if at least one significant contract term appears in plan
        matches = sum(1 for t in contract_terms if t in plan_text)
        match_ratio = matches / len(contract_terms)

        if match_ratio < 0.3:
            missed.append({
                "field": field,
                "contract_value": contract_value,
                "plan_sections_checked": plan_sections,
                "match_ratio": round(match_ratio, 2)
            })

    return missed


# Run missed issue detection
if rows:
    missed_results = {}
    missed_field_counts = Counter()

    for row in rows:
        sid = row.get('sample_id', 'UNKNOWN')
        missed = detect_missed_issues(row)
        if missed:
            missed_results[sid] = missed
            for m in missed:
                missed_field_counts[m['field']] += 1

    print(f"\n{'='*60}")
    print(f"MISSED ISSUE DETECTION REPORT")
    print(f"{'='*60}")
    print(f"Rows with potential missed issues: {len(missed_results)} " f"({len(missed_results)/len(rows)*100:.1f}%)")
    print(f"\nMissed by field:")
    for field, count in missed_field_counts.most_common():
        print(f"  {field}: {count} rows")
# Out:
# ============================================================
# MISSED ISSUE DETECTION REPORT
# ============================================================
# Rows with potential missed issues: 752 (89.5%)
#
# Missed by field:
#   frontendstack: 507 rows
#   hostingtarget: 350 rows
#   securitybaseline: 245 rows
#   backendstack: 182 rows
#   dataplatform: 169 rows
#   observabilitybaseline: 135 rows

# %% [markdown]
# ---
# ## Section 12 - Cleaning & Remediation Pipeline
#
# Applies fixes based on all validation results. Actions are categorised as:
# - **REMOVE**: Rows with fatal structural errors or irreparable inconsistencies
# - **FIX_ENUM**: Correct enum violations using synonym mapping
# - **FIX_KEY**: Rename snake_case keys to compact form
# - **FIX_CONDITIONAL**: Add missing conditional contract fields
# - **FIX_INFLATION**: Reduce inflated rubric scores to match plan richness
# - **FLAG**: Mark rows for manual review without auto-fixing

# %%
# Enum fix mappings
ENUM_FIXES = {
    'web_app': 'webapp',
    'api_service': 'apiservice',
    'full_stack_app': 'fullstackapp',
    'mobile_app': 'mobileapp',
    'desktop_app': 'desktopapp',
    'static_website': 'staticwebsite',
    'landing_page': 'landingpage',
    'cli_tool': 'clitool',
    'library_sdk': 'librarysdk',
    'automation_tool': 'automationtool',
    'data_pipeline': 'datapipeline',
    'ai_system': 'aisystem',
    'research_prototype': 'researchprototype',
    'infrastructure_project': 'infrastructureproject',
    'public_internet': 'publicinternet',
    'private_authenticated': 'privateauthenticated',
    'partner_facing': 'partnerfacing',
    'local_only': 'localonly',
    'internal_only': 'internalonly',
    'high_scale': 'highscale',
    'admin_panel': 'adminpanel',
    'public_api': 'publicapi',
    'batch_jobs': 'batchjobs',
    'ai_llm': 'aillm',
    'pii': 'personal',
    'phi': 'health',
    'pci': 'financial',
}

SNAKE_TO_COMPACT = {
    'project_goal': 'projectgoal',
    'target_users': 'targetusers',
    'project_class': 'projectclass',
    'complexity_level': 'complexitylevel',
    'risk_level': 'risklevel',
    'data_sensitivity': 'datasensitivity',
    'external_exposure': 'externalexposure',
    'access_model': 'accessmodel',
    'feature_scope': 'featurescope',
    'mvp_scope': 'mvpscope',
    'security_baseline': 'securitybaseline',
    'frontend_stack': 'frontendstack',
    'backend_stack': 'backendstack',
    'data_platform': 'dataplatform',
    'hosting_target': 'hostingtarget',
    'privacy_retention_policy': 'privacyretentionpolicy',
    'future_scope': 'futurescope',
    'observability_baseline': 'observabilitybaseline',
    'execution_preference': 'executionpreference',
    'llm_integration': 'llmintegration',
    'compliance_context': 'compliancecontext',
    'thinking_summary': 'thinkingsummary',
    'fix_report': 'fixreport',
    'executive_summary': 'executivesummary',
    'architecture_overview': 'architectureoverview',
    'technology_stack': 'technologystack',
    'functional_feature_map': 'functionalfeaturemap',
    'system_components': 'systemcomponents',
    'data_model': 'datamodel',
    'api_design': 'apidesign',
    'security_and_compliance': 'securityandcompliance',
    'deployment_and_operations': 'deploymentandoperations',
    'cost_and_scaling': 'costandscaling',
    'phased_implementation': 'phasedimplementation',
    'development_guidelines': 'developmentguidelines',
    'risks_and_tradeoffs': 'risksandtradeoffs',
    'open_questions_resolved': 'openquestionsresolved',
    'generated_at': 'generatedat',
    'rubric_scores': 'rubricscores',
    'blocking_issues': 'blockingissues',
    'requirement_conflicts': 'requirementconflicts',
    'issue_updates': 'issueupdates',
    'requirements_alignment': 'requirementsalignment',
    'architecture_quality': 'architecturequality',
    'internal_consistency': 'internalconsistency',
    'accepted_exceptions': 'acceptedexceptions',
    'issue_ledger': 'issueledger',
    'revision_memory': 'revisionmemory',
    'previous_audits': 'previousaudits',
    'reasoner_reviews': 'reasonerreviews',
    'specialist_subplans': 'specialistsubplans',
    'best_audit': 'bestaudit',
    'frozen_requirement_contract': 'frozenrequirementcontract',
    'open_questions': 'openquestions',
    'confirmed_decisions': 'confirmeddecisions',
    'issue_id': 'issueid',
    'action_taken': 'actiontaken',
    'changed_sections': 'changedsections',
    'expected_outcome': 'expectedoutcome',
    'current_value': 'currentvalue',
    'proposed_value': 'proposedvalue',
    'exact_reason': 'exactreason',
    'updated_at': 'updatedat',
    'created_at': 'createdat',
    'user_message': 'usermessage',
    'audit_date': 'auditdate',
    'audit_id': 'auditid',
}


def fix_keys_recursive(obj: Any) -> Any:
    """Recursively rename snake_case keys to compact form."""
    if isinstance(obj, dict):
        new_dict = {}
        for key, value in obj.items():
            new_key = SNAKE_TO_COMPACT.get(key, key)
            new_dict[new_key] = fix_keys_recursive(value)
        return new_dict
    elif isinstance(obj, list):
        return [fix_keys_recursive(item) for item in obj]
    return obj


def fix_enum_value(value: str) -> str:
    """Fix common enum misspellings."""
    if isinstance(value, str):
        lower = value.lower().strip()
        return ENUM_FIXES.get(lower, value)
    return value


def fix_enum_in_profile(profile: Dict) -> Dict:
    """Fix enum values in profile."""
    profile = copy.deepcopy(profile)
    for key in ['projectclass', 'complexitylevel', 'risklevel',
                'datasensitivity', 'externalexposure']:
        if key in profile:
            profile[key] = fix_enum_value(profile[key])
    if 'capabilities' in profile and isinstance(profile['capabilities'], list):
        profile['capabilities'] = [fix_enum_value(c) for c in profile['capabilities']]
    return profile


def fix_enum_in_contract(contract: Dict) -> Dict:
    """Fix enum values in contract fields."""
    contract = copy.deepcopy(contract)
    enum_fields = ['projectclass', 'complexitylevel', 'risklevel', 'datasensitivity', 'externalexposure']
    for field in enum_fields:
        if field in contract and isinstance(contract[field], dict):
            contract[field]['value'] = fix_enum_value(contract[field].get('value', ''))
    return contract


def add_missing_conditional_fields(row: Dict) -> Dict:
    """Add missing conditional contract fields with plausible defaults."""
    row = copy.deepcopy(row)
    profile = row.get('profile', {})
    contract = row.get('input_payload', {}).get('frozenrequirementcontract', {})
    capabilities = profile.get('capabilities', [])
    risk = profile.get('risklevel', '')
    sensitivity = profile.get('datasensitivity', '')

    if 'aillm' in capabilities and 'llmintegration' not in contract:
        contract['llmintegration'] = {
            "value": "Model integration required",
            "source": "Arch",
            "confirmed": True,
            "rationale": "Capabilities include AI/LLM",
            "updatedat": "2026-03-15T00:00:00Z"
        }

    needs_compliance = (
        risk == 'high' or
        sensitivity in ('personal', 'financial', 'health', 'confidential') or
        'payments' in capabilities
    )
    if needs_compliance and 'compliancecontext' not in contract:
        sensitivity_compliance_map = {
            'health': 'HIPAA compliance required',
            'financial': 'PCI-DSS compliance required',
            'personal': 'GDPR/privacy compliance required',
            'confidential': 'Data classification and access controls required',
        }
        default = sensitivity_compliance_map.get(sensitivity, 'Standard compliance baseline')
        contract['compliancecontext'] = {
            "value": default,
            "source": "Sec",
            "confirmed": True,
            "rationale": f"Required due to risk={risk}, sensitivity={sensitivity}",
            "updatedat": "2026-03-15T00:00:00Z"
        }

    row['input_payload']['frozenrequirementcontract'] = contract
    return row


def deflate_scores(row: Dict) -> Dict:
    """
    Reduce inflated rubric scores when plan richness doesn't justify them.
    Uses contextual thresholds based on complexity level.
    """
    row = copy.deepcopy(row)
    rubric = row.get('target_output', {}).get('rubricscores', {})
    plan = row.get('input_payload', {}).get('plan', {})
    profile = row.get('profile', {})

    if not rubric:
        return row

    richness = compute_plan_richness(plan)
    avg_rubric = np.mean([rubric.get(d, 0) for d in RUBRIC_DIMENSIONS])

    modified = False

    # Rule: High avg score but thin plan -> cap dimensions
    if avg_rubric > 8.0 and richness['one_word_sections'] >= 3:
        cap = 7 
        for dim in RUBRIC_DIMENSIONS:
            if rubric.get(dim, 0) > cap:
                rubric[dim] = cap
                modified = True

    # Rule: architecturequality >= 9 with thin plan
    if rubric.get('architecturequality', 0) >= 9 and richness['mean_words_per_section'] < 15:
        rubric['architecturequality'] = min(rubric['architecturequality'], 7)
        modified = True

    # Rule: operability >= 9 with sparse deployment/observability
    deploy_words = richness['section_words'].get('deploymentandoperations', 0)
    obs_words = richness['section_words'].get('observability', 0)
    if rubric.get('operability', 0) >= 9 and (deploy_words < 10 or obs_words < 5):
        rubric['operability'] = min(rubric['operability'], 7)
        modified = True

    # Rule: security >= 9 for sensitive systems with sparse security section
    risk = profile.get('risklevel', '')
    sens = profile.get('datasensitivity', '')
    sec_words = richness['section_words'].get('securityandcompliance', 0)
    if rubric.get('security', 0) >= 9 and (risk == 'high' or sens in ('health', 'financial', 'confidential')):
        if sec_words < 15:
            rubric['security'] = min(rubric['security'], 7)
            modified = True

    if modified:
        row['target_output']['rubricscores'] = rubric

    return row


print("Cleaning functions defined.")
# Out:
# Cleaning functions defined.

# %%
# Apply cleaning pipeline
if rows:
    cleaned_rows = []
    cleaning_log = {
        'removed': [],
        'fixed_keys': 0,
        'fixed_enums': 0,
        'fixed_conditionals': 0,
        'deflated_scores': 0,
        'exact_dupes_removed': 0,
        'near_dupes_removed': 0,
        'total_fixes': 0,
    }

    # Step 1: Identify rows to remove (fatal structural errors)
    fatal_ids = set()
    for sid, viols in all_violations.items():
        if any(v['severity'] == 'FATAL' for v in viols):
            fatal_ids.add(sid)
    cleaning_log['removed'] = list(fatal_ids)

    # Step 2: Identify exact duplicates to remove (keep first)
    exact_dupe_remove = set()
    for h, ids in exact_dupes.items():
        for dup_id in ids[1:]:  # Keep the first, remove rest
            exact_dupe_remove.add(dup_id)
    cleaning_log['exact_dupes_removed'] = len(exact_dupe_remove)

    # Step 3: Identify semantic near-duplicates to remove (keep higher quality)
    near_dupe_remove = set()
    if near_dupes:
        for nd in near_dupes:
            row_a = next((r for r in rows if r.get('sample_id') == nd['row_a']), None)
            row_b = next((r for r in rows if r.get('sample_id') == nd['row_b']), None)
            if row_a and row_b:
                words_a = len(extract_text_for_similarity(row_a).split())
                words_b = len(extract_text_for_similarity(row_b).split())
                remove_id = nd['row_b'] if words_a >= words_b else nd['row_a']
                near_dupe_remove.add(remove_id)
    cleaning_log['near_dupes_removed'] = len(near_dupe_remove)

    remove_ids = fatal_ids | exact_dupe_remove | near_dupe_remove

    # Step 4: Process each row
    for row in rows:
        sid = row.get('sample_id', 'UNKNOWN')

        if sid in remove_ids:
            continue

        cleaned = copy.deepcopy(row)

        # Fix snake_case keys
        original_json = json.dumps(cleaned)
        cleaned['input_payload'] = fix_keys_recursive(cleaned.get('input_payload', {}))
        cleaned['target_output'] = fix_keys_recursive(cleaned.get('target_output', {}))
        if json.dumps(cleaned) != original_json:
            cleaning_log['fixed_keys'] += 1

        # Fix enum values
        original_profile = json.dumps(cleaned.get('profile', {}))
        cleaned['profile'] = fix_enum_in_profile(cleaned.get('profile', {}))
        contract = cleaned.get('input_payload', {}).get('frozenrequirementcontract', {})
        cleaned['input_payload']['frozenrequirementcontract'] = fix_enum_in_contract(contract)
        if json.dumps(cleaned.get('profile', {})) != original_profile:
            cleaning_log['fixed_enums'] += 1

        # Add missing conditional fields
        original_contract = json.dumps(cleaned.get('input_payload', {}).get('frozenrequirementcontract', {}))
        cleaned = add_missing_conditional_fields(cleaned)
        if json.dumps(cleaned.get('input_payload', {}).get('frozenrequirementcontract', {})) != original_contract:
            cleaning_log['fixed_conditionals'] += 1

        # Deflate inflated scores
        original_rubric = json.dumps(cleaned.get('target_output', {}).get('rubricscores', {}))
        cleaned = deflate_scores(cleaned)
        if json.dumps(cleaned.get('target_output', {}).get('rubricscores', {})) != original_rubric:
            cleaning_log['deflated_scores'] += 1

        # Remove internal tracking fields
        cleaned.pop('_line_num', None)
        cleaned.pop('_chain_id', None)

        cleaned_rows.append(cleaned)

    cleaning_log['total_fixes'] = (cleaning_log['fixed_keys'] + cleaning_log['fixed_enums'] + cleaning_log['fixed_conditionals'] + cleaning_log['deflated_scores'])

    print(f"\n{'='*60}")
    print(f"CLEANING PIPELINE REPORT")
    print(f"{'='*60}")
    print(f"Original rows: {len(rows)}")
    print(f"Rows removed: {len(remove_ids)}")
    print(f"  Fatal structural: {len(fatal_ids)}")
    print(f"  Exact duplicates: {cleaning_log['exact_dupes_removed']}")
    print(f"  Near-duplicates: {cleaning_log['near_dupes_removed']}")
    print(f"Cleaned rows: {len(cleaned_rows)}")
    print(f"\nFixes applied:")
    print(f"  Snake_case keys fixed: {cleaning_log['fixed_keys']}")
    print(f"  Enum values fixed: {cleaning_log['fixed_enums']}")
    print(f"  Conditional fields added: {cleaning_log['fixed_conditionals']}")
    print(f"  Scores deflated: {cleaning_log['deflated_scores']}")
    print(f"  Total fixes: {cleaning_log['total_fixes']}")
else:
    cleaned_rows = []
    cleaning_log = {}
# Out:
# ============================================================
# CLEANING PIPELINE REPORT
# ============================================================
# Original rows: 840
# Rows removed: 20
#   Fatal structural: 0
#   Exact duplicates: 0
#   Near-duplicates: 20
# Cleaned rows: 820
#
# Fixes applied:
#   Snake_case keys fixed: 0
#   Enum values fixed: 0
#   Conditional fields added: 152
#   Scores deflated: 347
#   Total fixes: 499

# %%
# Fix 1: Missing generatedat field
generatedat_fixed = 0
for row in cleaned_rows:
    plan = row.get('input_payload', {}).get('plan', {})
    if 'generatedat' not in plan:
        plan['generatedat'] = "2026-03-15T00:00:00Z"
        generatedat_fixed += 1
print(f"Fixed {generatedat_fixed} rows missing 'generatedat'")

# Fix 2: Flaw family mislabelling
mislabelled = 0
for row in cleaned_rows:
    meta = row.get('metadata', {})
    output = row.get('target_output', {})
    blocking = output.get('blockingissues', [])
    conflicts = output.get('requirementconflicts', [])
    issues = output.get('issueupdates', [])

    unresolved = [iu for iu in issues if isinstance(iu, dict) and iu.get('status') != 'resolved']

    if meta.get('primary_flaw_family') == 'none' and (blocking or conflicts or unresolved):
        all_ids = ' '.join(iu.get('id', '') for iu in unresolved).upper()

        if 'SEC' in all_ids:
            meta['primary_flaw_family'] = 'security'
        elif 'OPS' in all_ids or 'HA' in all_ids or 'DEP' in all_ids:
            meta['primary_flaw_family'] = 'operability'
        elif 'DAT' in all_ids:
            meta['primary_flaw_family'] = 'datahandling'
        elif 'ARC' in all_ids or 'DES' in all_ids:
            meta['primary_flaw_family'] = 'architecturequality'
        elif any(isinstance(rc, dict) and rc.get('severity') == 'critical' for rc in conflicts):
            meta['primary_flaw_family'] = 'requirementconflict'
        else:
            meta['primary_flaw_family'] = 'architecturequality'
        mislabelled += 1

print(f"Fixed {mislabelled} mislabelled flaw families")
print(f"Total cleaned rows: {len(cleaned_rows)}")
# Out:
# Fixed 0 rows missing 'generatedat'
# Fixed 5 mislabelled flaw families
# Total cleaned rows: 820

# %% [markdown]
# ---
# ## Section 13 - Before vs After Evaluation
#
# Recompute all validation metrics on the cleaned dataset and produces publication-quality comparison tables and visualisations.

# %%
def compute_all_metrics(data: List[Dict], label: str) -> Dict[str, Any]:
    """Compute comprehensive quality metrics for a dataset."""
    metrics = {'label': label, 'n_rows': len(data)}

    if not data:
        return metrics

    validator = SchemaValidator()

    # Structural compliance
    structural_violations = 0
    for row in data:
        viols = validator.validate_row(row)
        if viols:
            structural_violations += 1
    metrics['structural_compliance_rate'] = 1 - structural_violations / len(data)

    # Enum compliance
    enum_violations = 0
    for row in data:
        if validate_enums(row):
            enum_violations += 1
    metrics['enum_compliance_rate'] = 1 - enum_violations / len(data)

    # Conditional field compliance
    conditional_violations = 0
    for row in data:
        issues = validate_cross_field(row)
        if any(i['rule'].startswith('conditional_') for i in issues):
            conditional_violations += 1
    metrics['conditional_compliance_rate'] = 1 - conditional_violations / len(data)

    # Cross-field consistency
    consistency_violations = 0
    for row in data:
        issues = validate_cross_field(row)
        if issues:
            consistency_violations += 1
    metrics['crossfield_consistency_rate'] = 1 - consistency_violations / len(data)

    # Score calibration
    inflation_count = 0
    for row in data:
        cal_issues, _ = validate_score_calibration(row)
        if cal_issues:
            inflation_count += 1
    metrics['calibration_compliance_rate'] = 1 - inflation_count / len(data)

    # Perfect row proportion
    perfect = sum(
        1 for row in data
        if all(row.get('target_output', {}).get('rubricscores', {}).get(d, 0) >= 9 for d in RUBRIC_DIMENSIONS)
        and not row.get('target_output', {}).get('blockingissues', [])
        and not row.get('target_output', {}).get('requirementconflicts', [])
    )
    metrics['perfect_row_pct'] = perfect / len(data)

    # Diversity metrics
    pc_counts = Counter(r.get('profile', {}).get('projectclass', '') for r in data)
    metrics['pc_entropy'] = compute_shannon_entropy(pc_counts)
    metrics['pc_normalised_entropy'] = (metrics['pc_entropy'] / compute_max_entropy(len(ALLOWED_PROJECT_CLASSES)))
    metrics['pc_classes_covered'] = len(pc_counts)

    ff_counts = Counter(r.get('metadata', {}).get('primary_flaw_family', '') for r in data)
    metrics['ff_entropy'] = compute_shannon_entropy(ff_counts)

    cap_combos = len(set(
        tuple(sorted(r.get('profile', {}).get('capabilities', []))) for r in data
    ))
    metrics['capability_combos'] = cap_combos

    # Case type ratio
    fp = sum(1 for r in data if r.get('metadata', {}).get('case_type') == 'first_pass')
    rr = sum(1 for r in data if r.get('metadata', {}).get('case_type') == 'revision_round')
    total = fp + rr
    metrics['fp_ratio'] = fp / max(total, 1)
    metrics['fp_ratio_deviation'] = abs(metrics['fp_ratio'] - 0.40)

    # Score statistics
    avg_scores = []
    for r in data:
        rubric = r.get('target_output', {}).get('rubricscores', {})
        if rubric:
            avg_scores.append(np.mean([rubric.get(d, 0) for d in RUBRIC_DIMENSIONS]))
    if avg_scores:
        metrics['score_mean'] = np.mean(avg_scores)
        metrics['score_std'] = np.std(avg_scores)
    else:
        metrics['score_mean'] = 0
        metrics['score_std'] = 0

    # Issue detail template compliance
    template_ok = 0
    template_total = 0
    for r in data:
        for iu in r.get('target_output', {}).get('issueupdates', []):
            if isinstance(iu, dict):
                template_total += 1
                detail = iu.get('detail', '')
                if DETAIL_TEMPLATE_RE.match(detail):
                    template_ok += 1
    metrics['detail_template_compliance'] = template_ok / max(template_total, 1)

    return metrics


# Compute before/after metrics
if rows and cleaned_rows:
    before_metrics = compute_all_metrics(rows, "Before Cleaning")
    after_metrics = compute_all_metrics(cleaned_rows, "After Cleaning")

    # Build comparison table
    metric_labels = {
        'n_rows': 'Total Rows',
        'structural_compliance_rate': 'Structural Compliance Rate',
        'enum_compliance_rate': 'Enum Compliance Rate',
        'conditional_compliance_rate': 'Conditional Field Compliance',
        'crossfield_consistency_rate': 'Cross-Field Consistency Rate',
        'calibration_compliance_rate': 'Score Calibration Compliance',
        'perfect_row_pct': 'Perfect Row Proportion (target <5%)',
        'pc_entropy': 'Project Class Entropy',
        'pc_normalised_entropy': 'PC Normalised Entropy',
        'pc_classes_covered': 'Project Classes Covered',
        'ff_entropy': 'Flaw Family Entropy',
        'capability_combos': 'Unique Capability Combos',
        'fp_ratio': 'First-Pass Ratio (target 0.40)',
        'fp_ratio_deviation': 'FP Ratio Deviation from Target',
        'score_mean': 'Mean Rubric Score',
        'score_std': 'Score Std Dev',
        'detail_template_compliance': 'Detail Template Compliance',
    }

    comparison_data = []
    for key, label in metric_labels.items():
        before_val = before_metrics.get(key, 'N/A')
        after_val = after_metrics.get(key, 'N/A')

        if isinstance(before_val, float) and isinstance(after_val, float):
            delta = after_val - before_val
            if key in ('fp_ratio_deviation', 'perfect_row_pct'):
                direction = '↑ improved' if delta < 0 else '↓ worsened' if delta > 0 else '='
            else:
                direction = '↑ improved' if delta > 0 else '↓ worsened' if delta < 0 else '='
        else:
            delta = 'N/A'
            direction = ''

        comparison_data.append({
            'Metric': label,
            'Before': f"{before_val:.4f}" if isinstance(before_val, float) else str(before_val),
            'After': f"{after_val:.4f}" if isinstance(after_val, float) else str(after_val),
            'Delta': f"{delta:+.4f}" if isinstance(delta, float) else str(delta),
            'Direction': direction,
        })

    comparison_df = pd.DataFrame(comparison_data)

    print(f"\n{'='*70}")
    print(f"BEFORE vs AFTER COMPARISON")
    print(f"{'='*70}")
    print(comparison_df.to_string(index=False))
else:
    comparison_df = pd.DataFrame()
    before_metrics = {}
    after_metrics = {}
# Out:
# ======================================================================
# BEFORE vs AFTER COMPARISON
# ======================================================================
#                              Metric Before  After   Delta  Direction
#                          Total Rows    840    820     N/A
#          Structural Compliance Rate 1.0000 1.0000 +0.0000          =
#                Enum Compliance Rate 0.7048 0.6902 -0.0145 ↓ worsened
#        Conditional Field Compliance 0.8190 1.0000 +0.1810 ↑ improved
#        Cross-Field Consistency Rate 0.6417 0.7707 +0.1291 ↑ improved
#        Score Calibration Compliance 0.5786 1.0000 +0.4214 ↑ improved
# Perfect Row Proportion (target <5%) 0.3286 0.0012 -0.3274 ↑ improved
#               Project Class Entropy 3.7468 3.7454 -0.0014 ↓ worsened
#               PC Normalised Entropy 0.9841 0.9837 -0.0004 ↓ worsened
#             Project Classes Covered     14     14     N/A
#                 Flaw Family Entropy 2.5016 2.5048 +0.0032 ↑ improved
#            Unique Capability Combos     69     69     N/A
#      First-Pass Ratio (target 0.40) 0.4369 0.4341 -0.0028 ↓ worsened
#      FP Ratio Deviation from Target 0.0369 0.0341 -0.0028 ↑ improved
#                   Mean Rubric Score 6.8433 5.9734 -0.8699 ↓ worsened
#                       Score Std Dev 2.4024 1.5456 -0.8568 ↓ worsened
#          Detail Template Compliance 1.0000 1.0000 +0.0000          =

# %%
# Publication-quality comparison visualisations
if before_metrics and after_metrics:
    # 1. Quality dimensions radar chart
    quality_dims = [
        'structural_compliance_rate', 'enum_compliance_rate',
        'conditional_compliance_rate', 'crossfield_consistency_rate',
        'calibration_compliance_rate', 'detail_template_compliance'
    ]
    dim_labels = ['Structural', 'Enum', 'Conditional', 'Cross-Field', 'Calibration', 'Detail Template']

    before_vals = [before_metrics.get(d, 0) for d in quality_dims]
    after_vals = [after_metrics.get(d, 0) for d in quality_dims]

    fig, axes = plt.subplots(1, 2, figsize=(16, 7))

    # Grouped bar chart (clearer than radar for papers)
    x = np.arange(len(dim_labels))
    width = 0.35
    axes[0].bar(x - width/2, before_vals, width, label='Before', color='#C44E52', alpha=0.8)
    axes[0].bar(x + width/2, after_vals, width, label='After', color='#55A868', alpha=0.8)
    axes[0].set_ylabel('Compliance Rate')
    axes[0].set_title('Data Quality Dimensions — Before vs After')
    axes[0].set_xticks(x)
    axes[0].set_xticklabels(dim_labels, rotation=30, ha='right')
    axes[0].set_ylim(0, 1.05)
    axes[0].legend()
    axes[0].axhline(y=1.0, color='gray', linestyle='--', alpha=0.3)

    # Score distribution comparison
    before_scores = []
    after_scores = []
    for r in rows:
        rub = r.get('target_output', {}).get('rubricscores', {})
        if rub:
            before_scores.append(np.mean([rub.get(d, 0) for d in RUBRIC_DIMENSIONS]))
    for r in cleaned_rows:
        rub = r.get('target_output', {}).get('rubricscores', {})
        if rub:
            after_scores.append(np.mean([rub.get(d, 0) for d in RUBRIC_DIMENSIONS]))

    if before_scores and after_scores:
        axes[1].hist(before_scores, bins=20, alpha=0.6, label='Before', color='#C44E52', edgecolor='black', density=True)
        axes[1].hist(after_scores, bins=20, alpha=0.6, label='After', color='#55A868', edgecolor='black', density=True)
        axes[1].set_xlabel('Average Rubric Score')
        axes[1].set_ylabel('Density')
        axes[1].set_title('Score Distribution — Before vs After Deflation')
        axes[1].legend()
        axes[1].axvline(9.0, color='red', linestyle='--', alpha=0.5, label='Pass threshold')

    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / 'before_after_quality.png', bbox_inches='tight')
    plt.show()
    print("Saved: before_after_quality.png")
# Out:
# Saved: before_after_quality.png

# %%
# Cleaning summary visualisation
if cleaning_log:
    fig, axes = plt.subplots(1, 2, figsize=(14, 6))

    # Cleaning actions pie chart
    actions = {
        'Kept (no changes)': len(cleaned_rows) - cleaning_log['total_fixes'],
        'Keys Fixed': cleaning_log['fixed_keys'],
        'Enums Fixed': cleaning_log['fixed_enums'],
        'Conditionals Added': cleaning_log['fixed_conditionals'],
        'Scores Deflated': cleaning_log['deflated_scores'],
        'Removed': len(remove_ids),
    }
    actions = {k: v for k, v in actions.items() if v > 0}
    colors = ['#55A868', '#4C72B0', '#DD8452', '#8172B3', '#CCB974', '#C44E52']
    axes[0].pie(actions.values(), labels=actions.keys(), autopct='%1.1f%%',
                colors=colors[:len(actions)], startangle=90)
    axes[0].set_title('Cleaning Actions Applied')

    # Before/after summary metrics bar
    summary_metrics = ['n_rows', 'pc_classes_covered', 'capability_combos']
    summary_labels = ['Total Rows', 'Project Classes', 'Capability Combos']
    before_vals = [before_metrics.get(m, 0) for m in summary_metrics]
    after_vals = [after_metrics.get(m, 0) for m in summary_metrics]

    x = np.arange(len(summary_labels))
    width = 0.35
    axes[1].bar(x - width/2, before_vals, width, label='Before', color='#C44E52', alpha=0.8)
    axes[1].bar(x + width/2, after_vals, width, label='After', color='#55A868', alpha=0.8)
    axes[1].set_ylabel('Count')
    axes[1].set_title('Dataset Size & Coverage Metrics')
    axes[1].set_xticks(x)
    axes[1].set_xticklabels(summary_labels)
    axes[1].legend()

    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / 'cleaning_summary.png', bbox_inches='tight')
    plt.show()
    print("Saved: cleaning_summary.png")
# Out:
# Saved: cleaning_summary.png

# %% [markdown]
# ---
# ## Section 14 - Statistical Significance Tests
#
# Verify that observed improvements are statistically significant
# using appropriate non-parametric tests (Wilcoxon for paired comparisons where applicable,
# Chi-squared for distribution comparisons).

# %%
if rows and cleaned_rows:
    print(f"\n{'='*60}")
    print(f"STATISTICAL SIGNIFICANCE TESTS")
    print(f"{'='*60}")

    # Test 1: Score distribution shift
    before_scores = []
    after_scores = []

    # Match rows by sample_id for paired test
    cleaned_id_map = {r.get('sample_id'): r for r in cleaned_rows}
    paired_before = []
    paired_after = []

    for r in rows:
        sid = r.get('sample_id')
        rub_before = r.get('target_output', {}).get('rubricscores', {})
        if sid in cleaned_id_map:
            rub_after = cleaned_id_map[sid].get('target_output', {}).get('rubricscores', {})
            if rub_before and rub_after:
                avg_b = np.mean([rub_before.get(d, 0) for d in RUBRIC_DIMENSIONS])
                avg_a = np.mean([rub_after.get(d, 0) for d in RUBRIC_DIMENSIONS])
                paired_before.append(avg_b)
                paired_after.append(avg_a)

    if len(paired_before) > 5:
        # Wilcoxon signed-rank test for paired non-parametric data
        diffs = np.array(paired_after) - np.array(paired_before)
        non_zero_diffs = diffs[diffs != 0]

        if len(non_zero_diffs) > 0:
            stat, p_val = stats.wilcoxon(non_zero_diffs)
            print(f"\n1. Score Deflation Effect (Wilcoxon signed-rank test)")
            print(f"   Pairs with changes: {len(non_zero_diffs)}")
            print(f"   Mean change: {np.mean(non_zero_diffs):+.3f}")
            print(f"   Statistic: {stat:.3f}, p-value: {p_val:.6f}")
            if p_val < 0.05:
                print(f"   ✓ Statistically significant (p < 0.05)")
            else:
                print(f"   Score changes not statistically significant")
        else:
            print("\n1. No score changes detected (no deflation applied).")

    # Test 2: Project class distribution improvement
    before_pc = Counter(r.get('profile', {}).get('projectclass', '') for r in rows)
    after_pc = Counter(r.get('profile', {}).get('projectclass', '') for r in cleaned_rows)

    # Chi-squared goodness-of-fit against uniform distribution
    all_classes = sorted(ALLOWED_PROJECT_CLASSES)
    before_observed = [before_pc.get(c, 0) for c in all_classes]
    after_observed = [after_pc.get(c, 0) for c in all_classes]
    expected_uniform = [len(rows) / len(all_classes)] * len(all_classes)
    expected_uniform_after = [len(cleaned_rows) / len(all_classes)] * len(all_classes)

    if sum(before_observed) > 0:
        chi2_before, p_before = stats.chisquare(before_observed, expected_uniform)
        print(f"\n2. Project Class Uniformity (Chi-squared goodness of fit)")
        print(f"   Before: chi2={chi2_before:.2f}, p={p_before:.6f}")

    if sum(after_observed) > 0:
        chi2_after, p_after = stats.chisquare(after_observed, expected_uniform_after)
        print(f"   After:  chi2={chi2_after:.2f}, p={p_after:.6f}")

    # Test 3: Rubric dimension independence improvement
    print(f"\n3. Rubric Dimension Independence")
    before_rubric_data = []
    after_rubric_data = []
    for r in rows:
        rub = r.get('target_output', {}).get('rubricscores', {})
        if all(d in rub for d in RUBRIC_DIMENSIONS):
            before_rubric_data.append([rub[d] for d in RUBRIC_DIMENSIONS])
    for r in cleaned_rows:
        rub = r.get('target_output', {}).get('rubricscores', {})
        if all(d in rub for d in RUBRIC_DIMENSIONS):
            after_rubric_data.append([rub[d] for d in RUBRIC_DIMENSIONS])

    if before_rubric_data:
        before_corr = np.corrcoef(np.array(before_rubric_data).T)
        after_corr = np.corrcoef(np.array(after_rubric_data).T) if after_rubric_data else before_corr
        before_avg_corr = np.mean(np.abs(before_corr[np.triu_indices(5, k=1)]))
        after_avg_corr = np.mean(np.abs(after_corr[np.triu_indices(5, k=1)]))
        print(f"   Mean |correlation| before: {before_avg_corr:.3f}")
        print(f"   Mean |correlation| after:  {after_avg_corr:.3f}")

    print(f"\n{'='*60}")
    print("All statistical tests complete.")
# Out:
# ============================================================
# STATISTICAL SIGNIFICANCE TESTS
# ============================================================
#
# 1. Score Deflation Effect (Wilcoxon signed-rank test)
#    Pairs with changes: 347
#    Mean change: -2.062
#    Statistic: 0.000, p-value: 0.000000
#    ✓ Statistically significant (p < 0.05)
#
# 2. Project Class Uniformity (Chi-squared goodness of fit)
#    Before: chi2=65.43, p=0.000000
#    After:  chi2=65.65, p=0.000000
#
# 3. Rubric Dimension Independence
#    Mean |correlation| before: 0.702
#    Mean |correlation| after:  0.469
#
# ============================================================
# All statistical tests complete.

# %% [markdown]
# ---
# ## Section 15 — Final Export
#
# Export the cleaned dataset and all validation reports.

# %%
if cleaned_rows:
    # Export cleaned JSONL
    output_path = OUTPUT_DIR / 'auditor_dataset_cleaned.jsonl'
    with open(output_path, 'w', encoding='utf-8') as f:
        for row in cleaned_rows:
            f.write(json.dumps(row, ensure_ascii=False) + '\n')
    print(f"✓ Cleaned dataset exported: {output_path} ({len(cleaned_rows)} rows)")

    # Export comparison table
    if len(comparison_df) > 0:
        comparison_df.to_csv(OUTPUT_DIR / 'before_after_comparison.csv', index=False)
        print(f"✓ Comparison table exported: {OUTPUT_DIR / 'before_after_comparison.csv'}")

    # Export cleaning log
    with open(OUTPUT_DIR / 'cleaning_log.json', 'w') as f:
        json.dump(cleaning_log, f, indent=2, default=str)
    print(f"✓ Cleaning log exported: {OUTPUT_DIR / 'cleaning_log.json'}")

    # Export validation reports
    reports = {
        'structural_violations': {k: v for k, v in all_violations.items()},
        'enum_violations': enum_results,
        'crossfield_violations': {k: v for k, v in crossfield_results.items()},
        'calibration_issues': {k: v for k, v in calibration_results.items()},
    }
    for name, data in reports.items():
        report_path = OUTPUT_DIR / f'{name}.json'
        with open(report_path, 'w') as f:
            json.dump(data, f, indent=2, default=str)
        print(f"✓ {name} exported: {report_path}")

    print(f"\n{'='*60}")
    print(f"ALL OUTPUTS SAVED TO: {OUTPUT_DIR}/")
    print(f"{'='*60}")
else:
    print("No cleaned data to export.")
# Out:
# ✓ Cleaned dataset exported: validation_output\auditor_dataset_cleaned.jsonl (820 rows)
# ✓ Comparison table exported: validation_output\before_after_comparison.csv
# ✓ Cleaning log exported: validation_output\cleaning_log.json
# ✓ structural_violations exported: validation_output\structural_violations.json
# ✓ enum_violations exported: validation_output\enum_violations.json
# ✓ crossfield_violations exported: validation_output\crossfield_violations.json
# ✓ calibration_issues exported: validation_output\calibration_issues.json
#
# ============================================================
# ALL OUTPUTS SAVED TO: validation_output/
# ============================================================

# %% [markdown]
# ---
# ## Summary & Conclusions
#
# This notebook implemented a comprehensive, chain-aware validation and cleaning pipeline for the
# AuditorAgent synthetic training dataset. The key contributions are:
#
# 1. **Chain Reconstruction**: Identified audit chains from shared frozen contracts, enabling
#    chain-aware deduplication and progression validation
# 2. **Seven-Dimension Validation**: Structural schema, enum compliance, cross-field consistency,
#    score calibration, diversity, duplication, and bias detection
# 3. **Intelligent Cleaning**: Context-sensitive fixes including conditional field injection,
#    enum normalisation, and score deflation calibrated to plan richness
# 4. **Quantitative Evidence**: Before/after comparison with statistical significance tests
#    demonstrating measurable improvement in dataset quality
#
# ### Key Metrics for Thesis Reporting
#
# | Dimension | Evidence |
# |-----------|----------|
# | Structural Integrity | Schema compliance rate improvement |
# | Score Calibration | Anti-inflation violation reduction, score-plan correlation |
# | Diversity | Shannon entropy, project class coverage |
# | Duplication | Near-duplicate reduction (chain-aware) |
# | Bias | ANOVA F-statistics, correlation independence |
# | Template Compliance | Issue-detail format adherence |

# %%
import json
import time
import os
from pathlib import Path
from openai import AzureOpenAI

# ═══════════════════════════════════════════════════════════════
# CONFIGURATION
# ═══════════════════════════════════════════════════════════════
client = AzureOpenAI(
    api_key=os.getenv("AZURE_OPENAI_API_KEY",""),
    api_version="2024-12-01-preview",
    azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT",""),
)
DEPLOYMENT_NAME = "gpt-5-chat"

INPUT_PATH = "validation_output/auditor_dataset_cleaned.jsonl"
OUTPUT_PATH = "validation_output/llm_as_a_judge/llm_validation_results.jsonl"
RESUME = True

# ═══════════════════════════════════════════════════════════════
# THE EVALUATION PROMPT
# ═══════════════════════════════════════════════════════════════
JUDGE_SYSTEM_PROMPT = """You are a senior AI data quality auditor evaluating synthetic training rows for an architectural governance AuditorAgent.

Each row contains:
- A frozen requirement contract (what was required)
- A plan (the architecture the architect proposed)
- A target_output (the audit the AuditorAgent is supposed to learn to produce)

Your job is to score the QUALITY of this training example across 6 dimensions.
For each dimension, give a score from 1-10 and a brief justification (1-2 sentences).

DIMENSIONS:

1. PLAN_REALISM (1-10): Does the plan read like a real architecture draft? Or is it generic filler with one-word sections like "Standard" or "MVP"? A score of 8+ requires named technologies, concrete data flows, specific deployment shapes, and operational details. One-word plan sections = score 3 or below.

2. AUDIT_REASONING (1-10): Does the target_output (the audit) demonstrate genuine architectural reasoning? Does the thinkingsummary show real analysis? Do the strengths/concerns/recommendations reference specific plan sections with concrete observations? Or is it shallow and formulaic? A good audit says "the plan uses Firebase Firestore but the contract requires PostgreSQL" not just "data platform mismatch."

3. SCORE_CALIBRATION (1-10): Are the rubric scores in target_output justified by the actual plan quality?
    - If the plan has one-word sections but rubric scores are 9-10, score this 1-2.
    - If the plan has genuine flaws but rubric scores are all high, score this low.
    - If the plan is detailed and the scores match the detail level, score this high.
    - If blocking issues exist but no rubric dimension is below 7, score this low.
    Use this formula mentally: base = 0.30*requirementsalignment + 0.25*architecturequality + 0.20*security + 0.15*operability + 0.10*internalconsistency. Penalties: unresolved critical=-1.50, high=-0.60, medium=-0.20, low=-0.05.

4. CONTRACT_PLAN_ALIGNMENT (1-10): Does the audit correctly identify all deviations between the frozen contract and the plan? Check these specifically:
    - Does the contract say one database but the plan uses a different one?
    - Does the contract require specific security (MFA, mTLS, TLS) but the plan omits it?
    - Does the contract specify an observability tool but the plan uses something else?
    - Does the contract specify a hosting target but the plan deploys elsewhere?
    Score 10 if every deviation is caught. Deduct points for each missed deviation.

5. ISSUE_CONSISTENCY (1-10): For revision_round rows: Do the issue updates correctly track what changed from the prior round? Does "Fixed" mean it's actually fixed in the plan text? Does "Unchanged" mean the plan actually didn't change? Does the fix_report match the issue_updates? For first_pass rows: Are newly introduced issues genuinely present in the plan? Score 10 for perfect consistency, deduct for each mismatch.

6. CROSS_FIELD_COHERENCE (1-10): Do all parts of the row agree with each other?
    - Does metadata.case_type match the round number? (first_pass=round 1, revision_round=round >1)
    - Does metadata.primary_flaw_family match the actual issues found?
    - Does metadata.intended_severity_mix match the issue severities?
    - If case_type is revision_round, does the summary say "meaningfully improved" / "stayed roughly flat" / "regressed"?
    - Are previous_audits and issue_ledger non-empty for revision rounds?
    - Does the profile match the contract values?

RESPONSE FORMAT — Return ONLY valid JSON, no markdown, no explanation outside the JSON:
{
    "plan_realism": {"score": <1-10>, "reason": "<1-2 sentences>"},
    "audit_reasoning": {"score": <1-10>, "reason": "<1-2 sentences>"},
    "score_calibration": {"score": <1-10>, "reason": "<1-2 sentences>"},
    "contract_plan_alignment": {"score": <1-10>, "reason": "<1-2 sentences>"},
    "issue_consistency": {"score": <1-10>, "reason": "<1-2 sentences>"},
    "cross_field_coherence": {"score": <1-10>, "reason": "<1-2 sentences>"},
    "overall_quality": <1-10>,
    "verdict": "<KEEP or REMOVE or NEEDS_REPAIR>",
    "critical_problems": ["<problem 1>", "<problem 2>"]
}

VERDICT RULES:
- KEEP: overall_quality >= 7 and no dimension below 4
- NEEDS_REPAIR: overall_quality 4-6, or one dimension below 4 but fixable
- REMOVE: overall_quality < 4, or multiple dimensions below 3, or fundamentally incoherent"""


def build_user_prompt(row: dict) -> str:
    """Build the user message containing the row to evaluate."""
    clean = {k: v for k, v in row.items() if not k.startswith('_')}
    row_json = json.dumps(clean, indent=1, ensure_ascii=False)

    return f"""Evaluate this training row for the AuditorAgent dataset.

ROW DATA:
{row_json}

Score all 6 dimensions and return your JSON verdict."""


def evaluate_row(row: dict, max_retries: int = 3) -> dict:
    """Call Azure OpenAI to evaluate a single row."""
    user_msg = build_user_prompt(row)

    for attempt in range(max_retries):
        try:
            response = client.chat.completions.create(
                model=DEPLOYMENT_NAME,
                messages=[
                    {"role": "system", "content": JUDGE_SYSTEM_PROMPT},
                    {"role": "user", "content": user_msg}
                ],
                max_completion_tokens=800,
            )

            raw_text = response.choices[0].message.content.strip()

            if raw_text.startswith("```"):
                raw_text = raw_text.split("\n", 1)[1] if "\n" in raw_text else raw_text[3:]
                if raw_text.endswith("```"):
                    raw_text = raw_text[:-3]
                raw_text = raw_text.strip()

            result = json.loads(raw_text)
            return result

        except json.JSONDecodeError:
            print(f"    JSON parse error on attempt {attempt+1}, retrying...")
            time.sleep(2)
        except Exception as e:
            error_str = str(e)
            if "429" in error_str or "rate" in error_str.lower():
                wait = 30 * (attempt + 1)
                print(f"    Rate limited, waiting {wait}s...")
                time.sleep(wait)
            else:
                print(f"    API error on attempt {attempt+1}: {error_str[:100]}")
                time.sleep(5)

    # All retries failed
    return {
        "plan_realism": {"score": 0, "reason": "EVALUATION FAILED"},
        "audit_reasoning": {"score": 0, "reason": "EVALUATION FAILED"},
        "score_calibration": {"score": 0, "reason": "EVALUATION FAILED"},
        "contract_plan_alignment": {"score": 0, "reason": "EVALUATION FAILED"},
        "issue_consistency": {"score": 0, "reason": "EVALUATION FAILED"},
        "cross_field_coherence": {"score": 0, "reason": "EVALUATION FAILED"},
        "overall_quality": 0,
        "verdict": "EVAL_FAILED",
        "critical_problems": ["All evaluation attempts failed"]
    }


# ═══════════════════════════════════════════════════════════════
# MAIN LOOP
# ═══════════════════════════════════════════════════════════════

# Load dataset
rows = []
with open(INPUT_PATH, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if line:
            try:
                rows.append(json.loads(line))
            except:
                pass

print(f"Loaded {len(rows)} rows from {INPUT_PATH}")

# Load already-scored rows if resuming
scored_ids = set()
if RESUME and Path(OUTPUT_PATH).exists():
    with open(OUTPUT_PATH, 'r') as f:
        for line in f:
            line = line.strip()
            if line:
                try:
                    r = json.loads(line)
                    scored_ids.add(r.get('sample_id', ''))
                except:
                    pass
    print(f"Resuming: {len(scored_ids)} rows already scored, {len(rows) - len(scored_ids)} remaining")

# Process
start_time = time.time()
processed = 0
errors = 0

with open(OUTPUT_PATH, 'a', encoding='utf-8') as out_f:
    for i, row in enumerate(rows):
        sid = row.get('sample_id', f'UNKNOWN_{i}')

        # Skip if already scored
        if sid in scored_ids:
            continue

        print(f"[{i+1}/{len(rows)}] Evaluating {sid}...", end=" ")

        evaluation = evaluate_row(row)

        # Combine sample_id with evaluation results
        result = {
            "sample_id": sid,
            "case_type": row.get('metadata', {}).get('case_type', ''),
            "projectclass": row.get('profile', {}).get('projectclass', ''),
            "round": row.get('input_payload', {}).get('round', 0),
            **evaluation
        }

        # Write immediately (crash-safe)
        out_f.write(json.dumps(result, ensure_ascii=False) + '\n')
        out_f.flush()

        overall = evaluation.get('overall_quality', 0)
        verdict = evaluation.get('verdict', '?')
        print(f"Score: {overall}/10 | Verdict: {verdict}")

        processed += 1
        if evaluation.get('verdict') == 'EVAL_FAILED':
            errors += 1

        # Rate limiting
        time.sleep(1.5)

        # Progress update every 50 rows
        if processed % 50 == 0:
            elapsed = time.time() - start_time
            rate = processed / elapsed * 60
            remaining = (len(rows) - len(scored_ids) - processed) / rate
            print(f"\n  === Progress: {processed} done, {rate:.1f} rows/min, "f"~{remaining:.0f} min remaining ===\n")

elapsed = time.time() - start_time
print(f"\n{'='*60}")
print(f"EVALUATION COMPLETE")
print(f"{'='*60}")
print(f"Errors: {errors}")
print(f"Time: {elapsed/60:.1f} minutes")
print(f"Results saved to: {OUTPUT_PATH}")
# Out:
# Loaded 820 rows from validation_output/auditor_dataset_cleaned.jsonl
# [1/820] Evaluating AUD-SYNC26-001... Score: 9/10 | Verdict: KEEP
# [2/820] Evaluating AUD-SYNC26-002... Score: 9/10 | Verdict: KEEP
# [3/820] Evaluating AUD-SYNC26-003... Score: 9/10 | Verdict: KEEP
# [4/820] Evaluating AUD-SYNC26-004... Score: 9/10 | Verdict: KEEP
# [5/820] Evaluating AUD-SYNC26-005... Score: 9/10 | Verdict: KEEP
# [6/820] Evaluating AUD-SYNC26-006... Score: 9/10 | Verdict: KEEP
# [7/820] Evaluating AUD-SYNC26-007... Score: 9/10 | Verdict: KEEP
# [8/820] Evaluating AUD-SYNC26-008... Score: 9/10 | Verdict: KEEP
# [9/820] Evaluating AUD-SYNC26-009... Score: 8.5/10 | Verdict: KEEP
# [10/820] Evaluating AUD-SYNC26-010... Score: 9.5/10 | Verdict: KEEP
# [11/820] Evaluating AUD-SYNC26-011... Score: 9.5/10 | Verdict: KEEP
# [12/820] Evaluating AUD-SYNC26-012... Score: 9/10 | Verdict: KEEP
# [13/820] Evaluating AUD-SYNC26-013... Score: 9/10 | Verdict: KEEP
# [14/820] Evaluating AUD-SYNC26-014... Score: 9/10 | Verdict: KEEP
# [15/820] Evaluating AUD-SYNC26-015... Score: 9/10 | Verdict: KEEP
# [16/820] Evaluating AUD-SYNC26-016... Score: 9/10 | Verdict: KEEP
# [17/820] Evaluating AUD-SYNC26-017... Score: 9/10 | Verdict: KEEP
# [18/820] Evaluating AUD-SYNC26-018... Score: 9/10 | Verdict: KEEP
# [19/820] Evaluating AUD-SYNC26-019... Score: 9/10 | Verdict: KEEP
# [20/820] Evaluating AUD-SYNC26-020... Score: 9.7/10 | Verdict: KEEP
# [21/820] Evaluating AUD-SYNC26-021... Score: 9.5/10 | Verdict: KEEP
# [22/820] Evaluating AUD-SYNC26-022... Score: 9/10 | Verdict: KEEP
# [23/820] Evaluating AUD-SYNC26-023... Score: 9/10 | Verdict: KEEP
# [24/820] Evaluating AUD-SYNC26-024... Score: 9/10 | Verdict: KEEP
# [25/820] Evaluating AUD-SYNC26-025... Score: 9/10 | Verdict: KEEP
# [26/820] Evaluating AUD-SYNC26-026... Score: 9.5/10 | Verdict: KEEP
# [27/820] Evaluating AUD-SYNC26-027... Score: 9/10 | Verdict: KEEP
# [28/820] Evaluating AUD-SYNC26-028... Score: 9/10 | Verdict: KEEP
# [29/820] Evaluating AUD-SYNC26-029... Score: 9/10 | Verdict: KEEP
# [30/820] Evaluating AUD-SYNC26-030... Score: 9/10 | Verdict: KEEP
# [31/820] Evaluating AUD-SYNC26-031... Score: 9/10 | Verdict: KEEP
# [32/820] Evaluating AUD-SYNC26-032... Score: 9/10 | Verdict: KEEP
# [33/820] Evaluating AUD-SYNC26-033... Score: 9.7/10 | Verdict: KEEP
# [34/820] Evaluating AUD-SYNC26-034... Score: 9.5/10 | Verdict: KEEP
# [35/820] Evaluating AUD-SYNC26-035... Score: 9/10 | Verdict: KEEP
# [36/820] Evaluating AUD-SYNC26-036... Score: 9/10 | Verdict: KEEP
# [37/820] Evaluating AUD-SYNC26-037... Score: 9/10 | Verdict: KEEP
# [38/820] Evaluating AUD-SYNC26-038... Score: 9/10 | Verdict: KEEP
# [39/820] Evaluating AUD-SYNC26-039... Score: 9/10 | Verdict: KEEP
# [40/820] Evaluating AUD-SYNC26-040... Score: 9/10 | Verdict: KEEP
# [41/820] Evaluating AUD-SYNC26-041... Score: 9/10 | Verdict: KEEP
# [42/820] Evaluating AUD-SYNC26-042... Score: 9/10 | Verdict: KEEP
# [43/820] Evaluating AUD-SYNC26-043... Score: 10/10 | Verdict: KEEP
# [44/820] Evaluating AUD-SYNC26-044... Score: 9/10 | Verdict: KEEP
# [45/820] Evaluating AUD-SYNC26-045... Score: 9/10 | Verdict: KEEP
# [46/820] Evaluating AUD-SYNC26-046... Score: 9/10 | Verdict: KEEP
# [47/820] Evaluating AUD-SYNC26-047... Score: 9/10 | Verdict: KEEP
# [48/820] Evaluating AUD-SYNC26-048... Score: 9/10 | Verdict: KEEP
# [49/820] Evaluating AUD-SYNC26-049... Score: 9/10 | Verdict: KEEP
# [50/820] Evaluating AUD-SYNC26-050... Score: 9.5/10 | Verdict: KEEP
#
#   === Progress: 50 done, 8.0 rows/min, ~96 min remaining ===
#
# [51/820] Evaluating AUD-SYNC26-051... Score: 9/10 | Verdict: KEEP
# [52/820] Evaluating AUD-SYNC26-052... Score: 9.7/10 | Verdict: KEEP
# [53/820] Evaluating AUD-SYNC26-053... Score: 9/10 | Verdict: KEEP
# [54/820] Evaluating AUD-SYNC26-054... Score: 9/10 | Verdict: KEEP
# [55/820] Evaluating AUD-SYNC26-055... Score: 9.7/10 | Verdict: KEEP
# [56/820] Evaluating AUD-SYNC26-056... Score: 9/10 | Verdict: KEEP
# [57/820] Evaluating AUD-SYNC26-057... Score: 9/10 | Verdict: KEEP
# [58/820] Evaluating AUD-SYNC26-058... Score: 9.5/10 | Verdict: KEEP
# [59/820] Evaluating AUD-SYNC26-059... Score: 9/10 | Verdict: KEEP
# [60/820] Evaluating AUD-SYNC26-060... Score: 9/10 | Verdict: KEEP
# [61/820] Evaluating AUD-SYNC26-061... Score: 9/10 | Verdict: KEEP
# [62/820] Evaluating AUD-SYNC26-062... Score: 9.5/10 | Verdict: KEEP
# [63/820] Evaluating AUD-SYNC26-063... Score: 9/10 | Verdict: KEEP
# [64/820] Evaluating AUD-SYNC26-064... Score: 9/10 | Verdict: KEEP
# [65/820] Evaluating AUD-SYNC26-065... Score: 9/10 | Verdict: KEEP
# [66/820] Evaluating AUD-SYNC26-066... Score: 9/10 | Verdict: KEEP
# [67/820] Evaluating AUD-SYNC26-067... Score: 9.7/10 | Verdict: KEEP
# [68/820] Evaluating AUD-SYNC26-068... Score: 9.7/10 | Verdict: KEEP
# [69/820] Evaluating AUD-SYNC26-069... Score: 9/10 | Verdict: KEEP
# [70/820] Evaluating AUD-SYNC26-070... Score: 9.7/10 | Verdict: KEEP
# [71/820] Evaluating AUD-SYNC26-071... Score: 9.7/10 | Verdict: KEEP
# [72/820] Evaluating AUD-SYNC26-072... Score: 9/10 | Verdict: KEEP
# [73/820] Evaluating AUD-SYNC26-073... Score: 9.7/10 | Verdict: KEEP
# [74/820] Evaluating AUD-SYNC26-074... Score: 9/10 | Verdict: KEEP
# [75/820] Evaluating AUD-SYNC26-075... Score: 9/10 | Verdict: KEEP
# [76/820] Evaluating AUD-SYNC26-076... Score: 9/10 | Verdict: KEEP
# [77/820] Evaluating AUD-SYNC26-077... Score: 9/10 | Verdict: KEEP
# [78/820] Evaluating AUD-SYNC26-078... Score: 9.5/10 | Verdict: KEEP
# [79/820] Evaluating AUD-SYNC26-079... Score: 9/10 | Verdict: KEEP
# [80/820] Evaluating AUD-SYNC26-080... Score: 9.5/10 | Verdict: KEEP
# [81/820] Evaluating AUD-SYNC26-081... Score: 9.5/10 | Verdict: KEEP
# [82/820] Evaluating AUD-SYNC26-082... Score: 9/10 | Verdict: KEEP
# [83/820] Evaluating AUD-SYNC26-083... Score: 9/10 | Verdict: KEEP
# [84/820] Evaluating AUD-SYNC26-084... Score: 9/10 | Verdict: KEEP
# [85/820] Evaluating AUD-SYNC26-085... Score: 9/10 | Verdict: KEEP
# [86/820] Evaluating AUD-SYNC26-086... Score: 9.5/10 | Verdict: KEEP
# [87/820] Evaluating AUD-SYNC26-087... Score: 9/10 | Verdict: KEEP
# [88/820] Evaluating AUD-SYNC26-088... Score: 9/10 | Verdict: KEEP
# [89/820] Evaluating AUD-SYNC26-089... Score: 9/10 | Verdict: KEEP
# [90/820] Evaluating AUD-SYNC26-090... Score: 9/10 | Verdict: KEEP
# [91/820] Evaluating AUD-SYNC26-091... Score: 9/10 | Verdict: KEEP
# [92/820] Evaluating AUD-SYNC26-092... Score: 9/10 | Verdict: KEEP
# [93/820] Evaluating AUD-SYNC26-093... Score: 9/10 | Verdict: KEEP
# [94/820] Evaluating AUD-SYNC26-094... Score: 9/10 | Verdict: KEEP
# [95/820] Evaluating AUD-SYNC26-095... Score: 9/10 | Verdict: KEEP
# [96/820] Evaluating AUD-SYNC26-096... Score: 9.7/10 | Verdict: KEEP
# [97/820] Evaluating AUD-SYNC26-097... Score: 10/10 | Verdict: KEEP
# [98/820] Evaluating AUD-SYNC26-098... Score: 9/10 | Verdict: KEEP
# [99/820] Evaluating AUD-SYNC26-099... Score: 9/10 | Verdict: KEEP
# [100/820] Evaluating AUD-SYNC26-100... Score: 9/10 | Verdict: KEEP
#
#   === Progress: 100 done, 7.6 rows/min, ~94 min remaining ===
#
# [101/820] Evaluating AUD-SYNC26-101... Score: 9/10 | Verdict: KEEP
# [102/820] Evaluating AUD-SYNC26-102... Score: 9/10 | Verdict: KEEP
# [103/820] Evaluating AUD-SYNC26-103... Score: 9/10 | Verdict: KEEP
# [104/820] Evaluating AUD-SYNC26-104... Score: 9/10 | Verdict: KEEP
# [105/820] Evaluating AUD-SYNC26-105... Score: 9/10 | Verdict: KEEP
# [106/820] Evaluating AUD-SYNC26-106... Score: 9/10 | Verdict: KEEP
# [107/820] Evaluating AUD-SYNC26-107... Score: 9.5/10 | Verdict: KEEP
# [108/820] Evaluating AUD-SYNC26-108... Score: 9/10 | Verdict: KEEP
# [109/820] Evaluating AUD-SYNC26-109... Score: 9/10 | Verdict: KEEP
# [110/820] Evaluating AUD-SYNC26-110... Score: 9/10 | Verdict: KEEP
# [111/820] Evaluating AUD-SYNC26-111... Score: 9/10 | Verdict: KEEP
# [112/820] Evaluating AUD-SYNC26-112... Score: 9/10 | Verdict: KEEP
# [113/820] Evaluating AUD-SYNC26-113... Score: 9/10 | Verdict: KEEP
# [114/820] Evaluating AUD-SYNC26-114... Score: 9/10 | Verdict: KEEP
# [115/820] Evaluating AUD-SYNC26-115... Score: 9/10 | Verdict: KEEP
# [116/820] Evaluating AUD-SYNC26-116... Score: 9/10 | Verdict: KEEP
# [117/820] Evaluating AUD-SYNC26-117... Score: 9/10 | Verdict: KEEP
# [118/820] Evaluating AUD-SYNC26-118... Score: 9/10 | Verdict: KEEP
# [119/820] Evaluating AUD-SYNC26-119... Score: 9/10 | Verdict: KEEP
# [120/820] Evaluating AUD-SYNC26-120... Score: 9/10 | Verdict: KEEP
# [121/820] Evaluating AUD-SYNC26-121... Score: 9/10 | Verdict: KEEP
# [122/820] Evaluating AUD-SYNC26-122... Score: 9/10 | Verdict: KEEP
# [123/820] Evaluating AUD-SYNC26-123... Score: 9/10 | Verdict: KEEP
# [124/820] Evaluating AUD-SYNC26-124... Score: 9/10 | Verdict: KEEP
# [125/820] Evaluating AUD-SYNC26-125... Score: 8/10 | Verdict: KEEP
# [126/820] Evaluating AUD-SYNC26-126... Score: 9/10 | Verdict: KEEP
# [127/820] Evaluating AUD-SYNC26-127... Score: 9/10 | Verdict: KEEP
# [128/820] Evaluating AUD-SYNC26-128... Score: 9/10 | Verdict: KEEP
# [129/820] Evaluating AUD-SYNC26-129... Score: 9/10 | Verdict: KEEP
# [130/820] Evaluating AUD-SYNC26-130... Score: 9/10 | Verdict: KEEP
# [131/820] Evaluating AUD-SYNC26-131... Score: 9/10 | Verdict: KEEP
# [132/820] Evaluating AUD-SYNC26-132... Score: 9/10 | Verdict: KEEP
# [133/820] Evaluating AUD-SYNC26-133... Score: 9/10 | Verdict: KEEP
# [134/820] Evaluating AUD-SYNC26-134... Score: 9/10 | Verdict: KEEP
# [135/820] Evaluating AUD-SYNC26-135... Score: 8.7/10 | Verdict: KEEP
# [136/820] Evaluating AUD-SYNC26-136... Score: 9/10 | Verdict: KEEP
# [137/820] Evaluating AUD-SYNC26-137... Score: 9/10 | Verdict: KEEP
# [138/820] Evaluating AUD-SYNC26-138... Score: 9/10 | Verdict: KEEP
# [139/820] Evaluating AUD-SYNC26-139... Score: 9/10 | Verdict: KEEP
# [140/820] Evaluating AUD-SYNC26-140... Score: 9/10 | Verdict: KEEP
# [141/820] Evaluating AUD-SYNC26-141... Score: 9/10 | Verdict: KEEP
# [142/820] Evaluating AUD-SYNC26-142... Score: 9/10 | Verdict: KEEP
# [143/820] Evaluating AUD-SYNC26-143... Score: 9/10 | Verdict: KEEP
# [144/820] Evaluating AUD-SYNC26-144... Score: 9/10 | Verdict: KEEP
# [145/820] Evaluating AUD-SYNC26-145... Score: 9/10 | Verdict: KEEP
# [146/820] Evaluating AUD-SYNC26-146... Score: 9/10 | Verdict: KEEP
# [147/820] Evaluating AUD-SYNC26-147... Score: 9/10 | Verdict: KEEP
# [148/820] Evaluating AUD-SYNC26-148... Score: 9/10 | Verdict: KEEP
# [149/820] Evaluating AUD-SYNC26-149... Score: 9/10 | Verdict: KEEP
# [150/820] Evaluating AUD-SYNC26-150... Score: 9/10 | Verdict: KEEP
#
#   === Progress: 150 done, 7.7 rows/min, ~87 min remaining ===
#
# [151/820] Evaluating AUD-SYNC26-151... Score: 9/10 | Verdict: KEEP
# [152/820] Evaluating AUD-SYNC26-152... Score: 9/10 | Verdict: KEEP
# [153/820] Evaluating AUD-SYNC26-153... Score: 9/10 | Verdict: KEEP
# [154/820] Evaluating AUD-SYNC26-154... Score: 9/10 | Verdict: KEEP
# [155/820] Evaluating AUD-SYNC26-155... Score: 9/10 | Verdict: KEEP
# [156/820] Evaluating AUD-SYNC26-156... Score: 9/10 | Verdict: KEEP
# [157/820] Evaluating AUD-SYNC26-157... Score: 8/10 | Verdict: KEEP
# [158/820] Evaluating AUD-SYNC26-158... Score: 9/10 | Verdict: KEEP
# [159/820] Evaluating AUD-SYNC26-159... Score: 9/10 | Verdict: KEEP
# [160/820] Evaluating AUD-SYNC26-160... Score: 9/10 | Verdict: KEEP
# [161/820] Evaluating AUD-SYNC26-161... Score: 9/10 | Verdict: KEEP
# [162/820] Evaluating AUD-SYNC26-162... Score: 9/10 | Verdict: KEEP
# [163/820] Evaluating AUD-SYNC26-163... Score: 9/10 | Verdict: KEEP
# [164/820] Evaluating AUD-SYNC26-164... Score: 9/10 | Verdict: KEEP
# [165/820] Evaluating AUD-SYNC26-165... Score: 8.5/10 | Verdict: KEEP
# [166/820] Evaluating AUD-SYNC26-166... Score: 9/10 | Verdict: KEEP
# [167/820] Evaluating AUD-SYNC26-167... Score: 9/10 | Verdict: KEEP
# [168/820] Evaluating AUD-SYNC26-168... Score: 9/10 | Verdict: KEEP
# [169/820] Evaluating AUD-SYNC26-169... Score: 8.7/10 | Verdict: KEEP
# [170/820] Evaluating AUD-SYNC26-170... Score: 8.8/10 | Verdict: KEEP
# [171/820] Evaluating AUD-SYNC26-171... Score: 9/10 | Verdict: KEEP
# [172/820] Evaluating AUD-SYNC26-172... Score: 9/10 | Verdict: KEEP
# [173/820] Evaluating AUD-SYNC26-173... Score: 9/10 | Verdict: KEEP
# [174/820] Evaluating AUD-SYNC26-174... Score: 9/10 | Verdict: KEEP
# [175/820] Evaluating AUD-SYNC26-175... Score: 9/10 | Verdict: KEEP
# [176/820] Evaluating AUD-SYNC26-176... Score: 9/10 | Verdict: KEEP
# [177/820] Evaluating AUD-SYNC26-177... Score: 9/10 | Verdict: KEEP
# [178/820] Evaluating AUD-SYNC26-178... Score: 9/10 | Verdict: KEEP
# [179/820] Evaluating AUD-SYNC26-179... Score: 9/10 | Verdict: KEEP
# [180/820] Evaluating AUD-SYNC26-180... Score: 9/10 | Verdict: KEEP
# [181/820] Evaluating AUD-SYNC26-181... Score: 9/10 | Verdict: KEEP
# [182/820] Evaluating AUD-SYNC26-182... Score: 9/10 | Verdict: KEEP
# [183/820] Evaluating AUD-SYNC26-183... Score: 9/10 | Verdict: KEEP
# [184/820] Evaluating AUD-SYNC26-184... Score: 8.5/10 | Verdict: KEEP
# [185/820] Evaluating AUD-SYNC26-185... Score: 9/10 | Verdict: KEEP
# [186/820] Evaluating AUD-SYNC26-186... Score: 9/10 | Verdict: KEEP
# [187/820] Evaluating AUD-SYNC26-187... Score: 9/10 | Verdict: KEEP
# [188/820] Evaluating AUD-SYNC26-188... Score: 8.5/10 | Verdict: KEEP
# [189/820] Evaluating AUD-SYNC26-189... Score: 9/10 | Verdict: KEEP
# [190/820] Evaluating AUD-SYNC26-190... Score: 9/10 | Verdict: KEEP
# [191/820] Evaluating AUD-SYNC26-191... Score: 9/10 | Verdict: KEEP
# [192/820] Evaluating AUD-SYNC26-192... Score: 9/10 | Verdict: KEEP
# [193/820] Evaluating AUD-SYNC26-193... Score: 9/10 | Verdict: KEEP
# [194/820] Evaluating AUD-SYNC26-194... Score: 9/10 | Verdict: KEEP
# [195/820] Evaluating AUD-SYNC26-195... Score: 9/10 | Verdict: KEEP
# [196/820] Evaluating AUD-SYNC26-196... Score: 9.3/10 | Verdict: KEEP
# [197/820] Evaluating AUD-SYNC26-197... Score: 9/10 | Verdict: KEEP
# [198/820] Evaluating AUD-SYNC26-198... Score: 9/10 | Verdict: KEEP
# [199/820] Evaluating AUD-SYNC26-199... Score: 9/10 | Verdict: KEEP
# [200/820] Evaluating AUD-SYNC26-200... Score: 9/10 | Verdict: KEEP
#
#   === Progress: 200 done, 7.4 rows/min, ~84 min remaining ===
#
# [201/820] Evaluating AUD-SYNC26-201... Score: 9/10 | Verdict: KEEP
# [202/820] Evaluating AUD-SYNC26-202... Score: 9/10 | Verdict: KEEP
# [203/820] Evaluating AUD-SYNC26-203... Score: 9/10 | Verdict: KEEP
# [204/820] Evaluating AUD-SYNC26-204... Score: 9/10 | Verdict: KEEP
# [205/820] Evaluating AUD-SYNC26-205... Score: 9/10 | Verdict: KEEP
# [206/820] Evaluating AUD-SYNC26-206... Score: 9/10 | Verdict: KEEP
# [207/820] Evaluating AUD-SYNC26-207... Score: 9/10 | Verdict: KEEP
# [208/820] Evaluating AUD-SYNC26-208... Score: 9/10 | Verdict: KEEP
# [209/820] Evaluating AUD-SYNC26-209... Score: 9/10 | Verdict: KEEP
# [210/820] Evaluating AUD-SYNC26-210... Score: 9/10 | Verdict: KEEP
# [211/820] Evaluating AUD-SYNC26-211... Score: 9/10 | Verdict: KEEP
# [212/820] Evaluating AUD-SYNC26-212... Score: 9/10 | Verdict: KEEP
# [213/820] Evaluating AUD-SYNC26-213... Score: 9/10 | Verdict: KEEP
# [214/820] Evaluating AUD-SYNC26-214... Score: 9/10 | Verdict: KEEP
# [215/820] Evaluating AUD-SYNC26-215... Score: 9/10 | Verdict: KEEP
# [216/820] Evaluating AUD-SYNC26-216... Score: 9/10 | Verdict: KEEP
# [217/820] Evaluating AUD-SYNC26-217... Score: 9/10 | Verdict: KEEP
# [218/820] Evaluating AUD-SYNC26-218... Score: 9/10 | Verdict: KEEP
# [219/820] Evaluating AUD-SYNC26-219... Score: 9/10 | Verdict: KEEP
# [220/820] Evaluating AUD-SYNC26-220... Score: 9/10 | Verdict: KEEP
# [221/820] Evaluating AUD-SYNC26-221... Score: 9/10 | Verdict: KEEP
# [222/820] Evaluating AUD-SYNC26-222... Score: 9/10 | Verdict: KEEP
# [223/820] Evaluating AUD-SYNC26-223... Score: 9/10 | Verdict: KEEP
# [224/820] Evaluating AUD-SYNC26-224... Score: 9/10 | Verdict: KEEP
# [225/820] Evaluating AUD-SYNC26-225... Score: 9/10 | Verdict: KEEP
# [226/820] Evaluating AUD-SYNC26-226... Score: 9/10 | Verdict: KEEP
# [227/820] Evaluating AUD-SYNC26-227... Score: 9/10 | Verdict: KEEP
# [228/820] Evaluating AUD-SYNC26-228... Score: 9/10 | Verdict: KEEP
# [229/820] Evaluating AUD-SYNC26-229... Score: 9/10 | Verdict: KEEP
# [230/820] Evaluating AUD-SYNC26-230... Score: 9/10 | Verdict: KEEP
# [231/820] Evaluating AUD-SYNC26-231... Score: 9/10 | Verdict: KEEP
# [232/820] Evaluating AUD-SYNC26-232... Score: 8.5/10 | Verdict: KEEP
# [233/820] Evaluating AUD-SYNC26-233... Score: 9/10 | Verdict: KEEP
# [234/820] Evaluating AUD-SYNC26-234... Score: 9/10 | Verdict: KEEP
# [235/820] Evaluating AUD-SYNC26-235... Score: 9/10 | Verdict: KEEP
# [236/820] Evaluating AUD-SYNC26-236... Score: 9/10 | Verdict: KEEP
# [237/820] Evaluating AUD-SYNC26-237... Score: 9/10 | Verdict: KEEP
# [238/820] Evaluating AUD-SYNC26-238... Score: 9/10 | Verdict: KEEP
# [239/820] Evaluating AUD-SYNC26-239... Score: 9/10 | Verdict: KEEP
# [240/820] Evaluating AUD-SYNC26-240... Score: 9/10 | Verdict: KEEP
# [241/820] Evaluating AUD-SYNC26-241... Score: 9/10 | Verdict: KEEP
# [242/820] Evaluating AUD-SYNC26-242... Score: 8.5/10 | Verdict: KEEP
# [243/820] Evaluating AUD-SYNC26-243... Score: 9/10 | Verdict: KEEP
# [244/820] Evaluating AUD-SYNC26-244... Score: 9/10 | Verdict: KEEP
# [245/820] Evaluating AUD-SYNC26-245... Score: 9/10 | Verdict: KEEP
# [246/820] Evaluating AUD-SYNC26-246... Score: 9/10 | Verdict: KEEP
# [247/820] Evaluating AUD-SYNC26-247... Score: 9/10 | Verdict: KEEP
# [248/820] Evaluating AUD-SYNC26-248... Score: 9/10 | Verdict: KEEP
# [249/820] Evaluating AUD-SYNC26-249... Score: 9/10 | Verdict: KEEP
# [250/820] Evaluating AUD-SYNC26-250... Score: 8.5/10 | Verdict: KEEP
#
#   === Progress: 250 done, 7.1 rows/min, ~80 min remaining ===
#
# [251/820] Evaluating AUD-SYNC26-251... Score: 9/10 | Verdict: KEEP
# [252/820] Evaluating AUD-SYNC26-252... Score: 9/10 | Verdict: KEEP
# [253/820] Evaluating AUD-SYNC26-253... Score: 9/10 | Verdict: KEEP
# [254/820] Evaluating AUD-SYNC26-254... Score: 9.3/10 | Verdict: KEEP
# [255/820] Evaluating AUD-SYNC26-255... Score: 9/10 | Verdict: KEEP
# [256/820] Evaluating AUD-SYNC26-256... Score: 9/10 | Verdict: KEEP
# [257/820] Evaluating AUD-SYNC26-257... Score: 9/10 | Verdict: KEEP
# [258/820] Evaluating AUD-SYNC26-258... Score: 9/10 | Verdict: KEEP
# [259/820] Evaluating AUD-SYNC26-259... Score: 8.8/10 | Verdict: KEEP
# [260/820] Evaluating AUD-SYNC26-260... Score: 9/10 | Verdict: KEEP
# [261/820] Evaluating AUD-SYNC26-261... Score: 9/10 | Verdict: KEEP
# [262/820] Evaluating AUD-SYNC26-262... Score: 9/10 | Verdict: KEEP
# [263/820] Evaluating AUD-SYNC26-263... Score: 9/10 | Verdict: KEEP
# [264/820] Evaluating AUD-SYNC26-264... Score: 9/10 | Verdict: KEEP
# [265/820] Evaluating AUD-SYNC26-265... Score: 8.5/10 | Verdict: KEEP
# [266/820] Evaluating AUD-SYNC26-266... Score: 9/10 | Verdict: KEEP
# [267/820] Evaluating AUD-SYNC26-267... Score: 9/10 | Verdict: KEEP
# [268/820] Evaluating AUD-SYNC26-268... Score: 9/10 | Verdict: KEEP
# [269/820] Evaluating AUD-SYNC26-269... Score: 9/10 | Verdict: KEEP
# [270/820] Evaluating AUD-SYNC26-270... Score: 9/10 | Verdict: KEEP
# [271/820] Evaluating AUD-SYNC26-271... Score: 9/10 | Verdict: KEEP
# [272/820] Evaluating AUD-SYNC26-272... Score: 9/10 | Verdict: KEEP
# [273/820] Evaluating AUD-SYNC26-273... Score: 8/10 | Verdict: KEEP
# [274/820] Evaluating AUD-SYNC26-274... Score: 9/10 | Verdict: KEEP
# [275/820] Evaluating AUD-SYNC26-275... Score: 9/10 | Verdict: KEEP
# [276/820] Evaluating AUD-SYNC26-276... Score: 9/10 | Verdict: KEEP
# [277/820] Evaluating AUD-SYNC26-277... Score: 9/10 | Verdict: KEEP
# [278/820] Evaluating AUD-SYNC26-278... Score: 9/10 | Verdict: KEEP
# [279/820] Evaluating AUD-SYNC26-279... Score: 9/10 | Verdict: KEEP
# [280/820] Evaluating AUD-SYNC26-280... Score: 9/10 | Verdict: KEEP
# [281/820] Evaluating AUD-SYNC26-281... Score: 9/10 | Verdict: KEEP
# [282/820] Evaluating AUD-SYNC26-282... Score: 9/10 | Verdict: KEEP
# [283/820] Evaluating AUD-SYNC26-283... Score: 9/10 | Verdict: KEEP
# [284/820] Evaluating AUD-SYNC26-284... Score: 9/10 | Verdict: KEEP
# [285/820] Evaluating AUD-SYNC26-285... Score: 9/10 | Verdict: KEEP
# [286/820] Evaluating AUD-SYNC26-286... Score: 9/10 | Verdict: KEEP
# [287/820] Evaluating AUD-SYNC26-287... Score: 9/10 | Verdict: KEEP
# [288/820] Evaluating AUD-SYNC26-288... Score: 9/10 | Verdict: KEEP
# [289/820] Evaluating AUD-SYNC26-289... Score: 8/10 | Verdict: KEEP
# [290/820] Evaluating AUD-SYNC26-290... Score: 9/10 | Verdict: KEEP
# [291/820] Evaluating AUD-SYNC26-291... Score: 9/10 | Verdict: KEEP
# [292/820] Evaluating AUD-SYNC26-292... Score: 9/10 | Verdict: KEEP
# [293/820] Evaluating AUD-SYNC26-293... Score: 9/10 | Verdict: KEEP
# [294/820] Evaluating AUD-SYNC26-294... Score: 9/10 | Verdict: KEEP
# [295/820] Evaluating AUD-SYNC26-295... Score: 9/10 | Verdict: KEEP
# [296/820] Evaluating AUD-SYNC26-296... Score: 9.5/10 | Verdict: KEEP
# [297/820] Evaluating AUD-SYNC26-297... Score: 9/10 | Verdict: KEEP
# [298/820] Evaluating AUD-SYNC26-298... Score: 9/10 | Verdict: KEEP
# [299/820] Evaluating AUD-SYNC26-299... Score: 9/10 | Verdict: KEEP
# [300/820] Evaluating AUD-SYNC26-300... Score: 9.7/10 | Verdict: KEEP
#
#   === Progress: 300 done, 7.3 rows/min, ~72 min remaining ===
#
# [301/820] Evaluating AUD-SYNC26-301... Score: 9/10 | Verdict: KEEP
# [302/820] Evaluating AUD-SYNC26-303... Score: 9/10 | Verdict: KEEP
# [303/820] Evaluating AUD-SYNC26-304... Score: 9/10 | Verdict: KEEP
# [304/820] Evaluating AUD-SYNC26-305... Score: 9/10 | Verdict: KEEP
# [305/820] Evaluating AUD-SYNC26-306... Score: 9/10 | Verdict: KEEP
# [306/820] Evaluating AUD-SYNC26-307... Score: 8/10 | Verdict: KEEP
# [307/820] Evaluating AUD-SYNC26-308... Score: 8.7/10 | Verdict: KEEP
# [308/820] Evaluating AUD-SYNC26-309... Score: 8.5/10 | Verdict: KEEP
# [309/820] Evaluating AUD-SYNC26-310... Score: 9/10 | Verdict: KEEP
# [310/820] Evaluating AUD-SYNC26-311... Score: 9/10 | Verdict: KEEP
# [311/820] Evaluating AUD-SYNC26-312... Score: 9/10 | Verdict: KEEP
# [312/820] Evaluating AUD-SYNC26-313... Score: 9/10 | Verdict: KEEP
# [313/820] Evaluating AUD-SYNC26-314... Score: 9/10 | Verdict: KEEP
# [314/820] Evaluating AUD-SYNC26-315... Score: 9/10 | Verdict: KEEP
# [315/820] Evaluating AUD-SYNC26-316... Score: 9/10 | Verdict: KEEP
# [316/820] Evaluating AUD-SYNC26-317... Score: 9/10 | Verdict: KEEP
# [317/820] Evaluating AUD-SYNC26-318... Score: 9/10 | Verdict: KEEP
# [318/820] Evaluating AUD-SYNC26-319... Score: 9/10 | Verdict: KEEP
# [319/820] Evaluating AUD-SYNC26-320... Score: 9/10 | Verdict: KEEP
# [320/820] Evaluating AUD-SYNC26-321... Score: 9/10 | Verdict: KEEP
# [321/820] Evaluating AUD-SYNC26-322... Score: 8.8/10 | Verdict: KEEP
# [322/820] Evaluating AUD-SYNC26-323... Score: 9/10 | Verdict: KEEP
# [323/820] Evaluating AUD-SYNC26-324... Score: 9/10 | Verdict: KEEP
# [324/820] Evaluating AUD-SYNC26-325... Score: 9/10 | Verdict: KEEP
# [325/820] Evaluating AUD-SYNC26-326... Score: 9/10 | Verdict: KEEP
# [326/820] Evaluating AUD-SYNC26-327... Score: 9/10 | Verdict: KEEP
# [327/820] Evaluating AUD-SYNC26-328... Score: 9.7/10 | Verdict: KEEP
# [328/820] Evaluating AUD-SYNC26-329... Score: 9/10 | Verdict: KEEP
# [329/820] Evaluating AUD-SYNC26-330... Score: 9/10 | Verdict: KEEP
# [330/820] Evaluating AUD-SYNC26-331... Score: 9/10 | Verdict: KEEP
# [331/820] Evaluating AUD-SYNC26-332... Score: 9/10 | Verdict: KEEP
# [332/820] Evaluating AUD-SYNC26-333... Score: 9/10 | Verdict: KEEP
# [333/820] Evaluating AUD-SYNC26-334... Score: 9/10 | Verdict: KEEP
# [334/820] Evaluating AUD-SYNC26-335... Score: 9/10 | Verdict: KEEP
# [335/820] Evaluating AUD-SYNC26-336... Score: 9/10 | Verdict: KEEP
# [336/820] Evaluating AUD-SYNC26-337... Score: 9/10 | Verdict: KEEP
# [337/820] Evaluating AUD-SYNC26-338... Score: 9/10 | Verdict: KEEP
# [338/820] Evaluating AUD-SYNC26-339... Score: 9/10 | Verdict: KEEP
# [339/820] Evaluating AUD-SYNC26-340... Score: 9/10 | Verdict: KEEP
# [340/820] Evaluating AUD-SYNC26-341... Score: 9/10 | Verdict: KEEP
# [341/820] Evaluating AUD-SYNC26-342... Score: 9/10 | Verdict: KEEP
# [342/820] Evaluating AUD-SYNC26-343... Score: 9/10 | Verdict: KEEP
# [343/820] Evaluating AUD-SYNC26-344... Score: 9/10 | Verdict: KEEP
# [344/820] Evaluating AUD-SYNC26-345... Score: 9/10 | Verdict: KEEP
# [345/820] Evaluating AUD-SYNC26-346... Score: 9/10 | Verdict: KEEP
# [346/820] Evaluating AUD-SYNC26-347... Score: 8.5/10 | Verdict: KEEP
# [347/820] Evaluating AUD-SYNC26-348... Score: 9/10 | Verdict: KEEP
# [348/820] Evaluating AUD-SYNC26-349... Score: 9/10 | Verdict: KEEP
# [349/820] Evaluating AUD-SYNC26-350... Score: 9/10 | Verdict: KEEP
# [350/820] Evaluating AUD-SYNC26-351... Score: 9.7/10 | Verdict: KEEP
#
#   === Progress: 350 done, 7.4 rows/min, ~64 min remaining ===
#
# [351/820] Evaluating AUD-SYNC26-352... Score: 9/10 | Verdict: KEEP
# [352/820] Evaluating AUD-SYNC26-353... Score: 9/10 | Verdict: KEEP
# [353/820] Evaluating AUD-SYNC26-354... Score: 8.5/10 | Verdict: KEEP
# [354/820] Evaluating AUD-SYNC26-355... Score: 9/10 | Verdict: KEEP
# [355/820] Evaluating AUD-SYNC26-356... Score: 9/10 | Verdict: KEEP
# [356/820] Evaluating AUD-SYNC26-357... Score: 7.5/10 | Verdict: KEEP
# [357/820] Evaluating AUD-SYNC26-358... Score: 9/10 | Verdict: KEEP
# [358/820] Evaluating AUD-SYNC26-359... Score: 9/10 | Verdict: KEEP
# [359/820] Evaluating AUD-SYNC26-360... Score: 9/10 | Verdict: KEEP
# [360/820] Evaluating AUD-SYNC26-361... Score: 9/10 | Verdict: KEEP
# [361/820] Evaluating AUD-SYNC26-362... Score: 9/10 | Verdict: KEEP
# [362/820] Evaluating AUD-SYNC26-363... Score: 8.5/10 | Verdict: KEEP
# [363/820] Evaluating AUD-SYNC26-364... Score: 9/10 | Verdict: KEEP
# [364/820] Evaluating AUD-SYNC26-365... Score: 10/10 | Verdict: KEEP
# [365/820] Evaluating AUD-SYNC26-366... Score: 9/10 | Verdict: KEEP
# [366/820] Evaluating AUD-SYNC26-367... Score: 9/10 | Verdict: KEEP
# [367/820] Evaluating AUD-SYNC26-368... Score: 9/10 | Verdict: KEEP
# [368/820] Evaluating AUD-SYNC26-369... Score: 8.5/10 | Verdict: KEEP
# [369/820] Evaluating AUD-SYNC26-370... Score: 9/10 | Verdict: KEEP
# [370/820] Evaluating AUD-SYNC26-371... Score: 9/10 | Verdict: KEEP
# [371/820] Evaluating AUD-SYNC26-372... Score: 9/10 | Verdict: KEEP
# [372/820] Evaluating AUD-SYNC26-373... Score: 9/10 | Verdict: KEEP
# [373/820] Evaluating AUD-SYNC26-374... Score: 9.7/10 | Verdict: KEEP
# [374/820] Evaluating AUD-SYNC26-375... Score: 9/10 | Verdict: KEEP
# [375/820] Evaluating AUD-SYNC26-376... Score: 9/10 | Verdict: KEEP
# [376/820] Evaluating AUD-SYNC26-377... Score: 9/10 | Verdict: KEEP
# [377/820] Evaluating AUD-SYNC26-378... Score: 9/10 | Verdict: KEEP
# [378/820] Evaluating AUD-SYNC26-379... Score: 8/10 | Verdict: KEEP
# [379/820] Evaluating AUD-SYNC26-380... Score: 9/10 | Verdict: KEEP
# [380/820] Evaluating AUD-SYNC26-381... Score: 9/10 | Verdict: KEEP
# [381/820] Evaluating AUD-SYNC26-382... Score: 8.5/10 | Verdict: KEEP
# [382/820] Evaluating AUD-SYNC26-383... Score: 9/10 | Verdict: KEEP
# [383/820] Evaluating AUD-SYNC26-384... Score: 9/10 | Verdict: KEEP
# [384/820] Evaluating AUD-SYNC26-385... Score: 9/10 | Verdict: KEEP
# [385/820] Evaluating AUD-SYNC26-386... Score: 9/10 | Verdict: KEEP
# [386/820] Evaluating AUD-SYNC26-387... Score: 9/10 | Verdict: KEEP
# [387/820] Evaluating AUD-SYNC26-388... Score: 9/10 | Verdict: KEEP
# [388/820] Evaluating AUD-SYNC26-389... Score: 9/10 | Verdict: KEEP
# [389/820] Evaluating AUD-SYNC26-390... Score: 9/10 | Verdict: KEEP
# [390/820] Evaluating AUD-SYNC26-391... Score: 9/10 | Verdict: KEEP
# [391/820] Evaluating AUD-SYNC26-392... Score: 9/10 | Verdict: KEEP
# [392/820] Evaluating AUD-SYNC26-393... Score: 9/10 | Verdict: KEEP
# [393/820] Evaluating AUD-SYNC26-394... Score: 9/10 | Verdict: KEEP
# [394/820] Evaluating AUD-SYNC26-395... Score: 9/10 | Verdict: KEEP
# [395/820] Evaluating AUD-SYNC26-396... Score: 9/10 | Verdict: KEEP
# [396/820] Evaluating AUD-SYNC26-397... Score: 9/10 | Verdict: KEEP
# [397/820] Evaluating AUD-SYNC26-398... Score: 9/10 | Verdict: KEEP
# [398/820] Evaluating AUD-SYNC26-399... Score: 9/10 | Verdict: KEEP
# [399/820] Evaluating AUD-SYNC26-400... Score: 9/10 | Verdict: KEEP
# [400/820] Evaluating AUD-SYNC26-401... Score: 9.7/10 | Verdict: KEEP
#
#   === Progress: 400 done, 7.2 rows/min, ~58 min remaining ===
#
# [401/820] Evaluating AUD-SYNC26-402... Score: 9/10 | Verdict: KEEP
# [402/820] Evaluating AUD-SYNC26-403... Score: 9/10 | Verdict: KEEP
# [403/820] Evaluating AUD-SYNC26-404... Score: 9/10 | Verdict: KEEP
# [404/820] Evaluating AUD-SYNC26-405... Score: 9/10 | Verdict: KEEP
# [405/820] Evaluating AUD-SYNC26-406... Score: 9/10 | Verdict: KEEP
# [406/820] Evaluating AUD-SYNC26-407... Score: 9/10 | Verdict: KEEP
# [407/820] Evaluating AUD-SYNC26-408... Score: 9/10 | Verdict: KEEP
# [408/820] Evaluating AUD-SYNC26-409... Score: 9/10 | Verdict: KEEP
# [409/820] Evaluating AUD-SYNC26-410... Score: 9/10 | Verdict: KEEP
# [410/820] Evaluating AUD-SYNC26-411... Score: 9/10 | Verdict: KEEP
# [411/820] Evaluating AUD-SYNC26-412... Score: 9/10 | Verdict: KEEP
# [412/820] Evaluating AUD-SYNC26-413... Score: 8.5/10 | Verdict: KEEP
# [413/820] Evaluating AUD-SYNC26-414... Score: 9/10 | Verdict: KEEP
# [414/820] Evaluating AUD-SYNC26-415... Score: 10/10 | Verdict: KEEP
# [415/820] Evaluating AUD-SYNC26-416... Score: 9/10 | Verdict: KEEP
# [416/820] Evaluating AUD-SYNC26-417... Score: 9/10 | Verdict: KEEP
# [417/820] Evaluating AUD-SYNC26-418... Score: 9/10 | Verdict: KEEP
# [418/820] Evaluating AUD-SYNC26-419... Score: 9/10 | Verdict: KEEP
# [419/820] Evaluating AUD-SYNC26-420... Score: 9/10 | Verdict: KEEP
# [420/820] Evaluating AUD-SYNC26-421... Score: 9/10 | Verdict: KEEP
# [421/820] Evaluating AUD-SYNC26-422... Score: 9/10 | Verdict: KEEP
# [422/820] Evaluating AUD-SYNC26-424... Score: 9/10 | Verdict: KEEP
# [423/820] Evaluating AUD-SYNC26-426... Score: 9/10 | Verdict: KEEP
# [424/820] Evaluating AUD-SYNC26-427... Score: 8.5/10 | Verdict: KEEP
# [425/820] Evaluating AUD-SYNC26-431... Score: 9/10 | Verdict: KEEP
# [426/820] Evaluating AUD-SYNC26-432... Score: 10/10 | Verdict: KEEP
# [427/820] Evaluating AUD-SYNC26-433... Score: 8/10 | Verdict: KEEP
# [428/820] Evaluating AUD-SYNC26-434... Score: 9/10 | Verdict: KEEP
# [429/820] Evaluating AUD-SYNC26-435... Score: 9/10 | Verdict: KEEP
# [430/820] Evaluating AUD-SYNC26-436... Score: 9/10 | Verdict: KEEP
# [431/820] Evaluating AUD-SYNC26-437... Score: 9/10 | Verdict: KEEP
# [432/820] Evaluating AUD-SYNC26-438... Score: 9/10 | Verdict: KEEP
# [433/820] Evaluating AUD-SYNC26-439... Score: 9/10 | Verdict: KEEP
# [434/820] Evaluating AUD-SYNC26-440... Score: 9/10 | Verdict: KEEP
# [435/820] Evaluating AUD-SYNC26-441... Score: 9/10 | Verdict: KEEP
# [436/820] Evaluating AUD-SYNC26-442... Score: 9/10 | Verdict: KEEP
# [437/820] Evaluating AUD-SYNC26-443... Score: 9/10 | Verdict: KEEP
# [438/820] Evaluating AUD-SYNC26-444... Score: 9/10 | Verdict: KEEP
# [439/820] Evaluating AUD-SYNC26-445... Score: 9/10 | Verdict: KEEP
# [440/820] Evaluating AUD-SYNC26-446... Score: 9/10 | Verdict: KEEP
# [441/820] Evaluating AUD-SYNC26-447... Score: 9/10 | Verdict: KEEP
# [442/820] Evaluating AUD-SYNC26-448... Score: 9.7/10 | Verdict: KEEP
# [443/820] Evaluating AUD-SYNC26-449... Score: 9.7/10 | Verdict: KEEP
# [444/820] Evaluating AUD-SYNC26-450... Score: 9/10 | Verdict: KEEP
# [445/820] Evaluating AUD-SYNC26-451... Score: 9/10 | Verdict: KEEP
# [446/820] Evaluating AUD-SYNC26-452... Score: 9/10 | Verdict: KEEP
# [447/820] Evaluating AUD-SYNC26-453... Score: 10/10 | Verdict: KEEP
# [448/820] Evaluating AUD-SYNC26-454... Score: 10/10 | Verdict: KEEP
# [449/820] Evaluating AUD-SYNC26-455... Score: 9/10 | Verdict: KEEP
# [450/820] Evaluating AUD-SYNC26-456... Score: 9/10 | Verdict: KEEP
#
#   === Progress: 450 done, 7.1 rows/min, ~52 min remaining ===
#
# [451/820] Evaluating AUD-SYNC26-457... Score: 9/10 | Verdict: KEEP
# [452/820] Evaluating AUD-SYNC26-458... Score: 9/10 | Verdict: KEEP
# [453/820] Evaluating AUD-SYNC26-459... Score: 9/10 | Verdict: KEEP
# [454/820] Evaluating AUD-SYNC26-460... Score: 9/10 | Verdict: KEEP
# [455/820] Evaluating AUD-SYNC26-461... Score: 9/10 | Verdict: KEEP
# [456/820] Evaluating AUD-SYNC26-462... Score: 9/10 | Verdict: KEEP
# [457/820] Evaluating AUD-SYNC26-463... Score: 9/10 | Verdict: KEEP
# [458/820] Evaluating AUD-SYNC26-464... Score: 9/10 | Verdict: KEEP
# [459/820] Evaluating AUD-SYNC26-465... Score: 9/10 | Verdict: KEEP
# [460/820] Evaluating AUD-SYNC26-466... Score: 9/10 | Verdict: KEEP
# [461/820] Evaluating AUD-SYNC26-467... Score: 9/10 | Verdict: KEEP
# [462/820] Evaluating AUD-SYNC26-468... Score: 8.5/10 | Verdict: KEEP
# [463/820] Evaluating AUD-SYNC26-469... Score: 9/10 | Verdict: KEEP
# [464/820] Evaluating AUD-SYNC26-470... Score: 9/10 | Verdict: KEEP
# [465/820] Evaluating AUD-SYNC26-471... Score: 9/10 | Verdict: KEEP
# [466/820] Evaluating AUD-SYNC26-472... Score: 9/10 | Verdict: KEEP
# [467/820] Evaluating AUD-SYNC26-473... Score: 8.5/10 | Verdict: KEEP
# [468/820] Evaluating AUD-SYNC26-474... Score: 9/10 | Verdict: KEEP
# [469/820] Evaluating AUD-SYNC26-475... Score: 9/10 | Verdict: KEEP
# [470/820] Evaluating AUD-SYNC26-476... Score: 9/10 | Verdict: KEEP
# [471/820] Evaluating AUD-SYNC26-477... Score: 9/10 | Verdict: KEEP
# [472/820] Evaluating AUD-SYNC26-478... Score: 9/10 | Verdict: KEEP
# [473/820] Evaluating AUD-SYNC26-479... Score: 9/10 | Verdict: KEEP
# [474/820] Evaluating AUD-SYNC26-480... Score: 9/10 | Verdict: KEEP
# [475/820] Evaluating AUD-SYNC26-481... Score: 9/10 | Verdict: KEEP
# [476/820] Evaluating AUD-SYNC26-482... Score: 9.5/10 | Verdict: KEEP
# [477/820] Evaluating AUD-SYNC26-483... Score: 9/10 | Verdict: KEEP
# [478/820] Evaluating AUD-SYNC26-484... Score: 9/10 | Verdict: KEEP
# [479/820] Evaluating AUD-SYNC26-485... Score: 9/10 | Verdict: KEEP
# [480/820] Evaluating AUD-SYNC26-486... Score: 8.5/10 | Verdict: KEEP
# [481/820] Evaluating AUD-SYNC26-487... Score: 9/10 | Verdict: KEEP
# [482/820] Evaluating AUD-SYNC26-488... Score: 9/10 | Verdict: KEEP
# [483/820] Evaluating AUD-SYNC26-489... Score: 9/10 | Verdict: KEEP
# [484/820] Evaluating AUD-SYNC26-490... Score: 9/10 | Verdict: KEEP
# [485/820] Evaluating AUD-SYNC26-491... Score: 9/10 | Verdict: KEEP
# [486/820] Evaluating AUD-SYNC26-492... Score: 9/10 | Verdict: KEEP
# [487/820] Evaluating AUD-SYNC26-493... Score: 9/10 | Verdict: KEEP
# [488/820] Evaluating AUD-SYNC26-494... Score: 8.5/10 | Verdict: KEEP
# [489/820] Evaluating AUD-SYNC26-498... Score: 9/10 | Verdict: KEEP
# [490/820] Evaluating AUD-SYNC26-499... Score: 9/10 | Verdict: KEEP
# [491/820] Evaluating AUD-SYNC26-500... Score: 9/10 | Verdict: KEEP
# [492/820] Evaluating AUD-SYNC26-501... Score: 9/10 | Verdict: KEEP
# [493/820] Evaluating AUD-SYNC26-502... Score: 9/10 | Verdict: KEEP
# [494/820] Evaluating AUD-SYNC26-503... Score: 9.5/10 | Verdict: KEEP
# [495/820] Evaluating AUD-SYNC26-504... Score: 9/10 | Verdict: KEEP
# [496/820] Evaluating AUD-SYNC26-505... Score: 9/10 | Verdict: KEEP
# [497/820] Evaluating AUD-SYNC26-506... Score: 8/10 | Verdict: KEEP
# [498/820] Evaluating AUD-SYNC26-507... Score: 9/10 | Verdict: KEEP
# [499/820] Evaluating AUD-SYNC26-508... Score: 9/10 | Verdict: KEEP
# [500/820] Evaluating AUD-SYNC26-509... Score: 9/10 | Verdict: KEEP
#
#   === Progress: 500 done, 7.1 rows/min, ~45 min remaining ===
#
# [501/820] Evaluating AUD-SYNC26-510... Score: 9/10 | Verdict: KEEP
# [502/820] Evaluating AUD-SYNC26-511... Score: 9/10 | Verdict: KEEP
# [503/820] Evaluating AUD-SYNC26-512... Score: 9/10 | Verdict: KEEP
# [504/820] Evaluating AUD-SYNC26-513... Score: 8.5/10 | Verdict: KEEP
# [505/820] Evaluating AUD-SYNC26-514... Score: 9/10 | Verdict: KEEP
# [506/820] Evaluating AUD-SYNC26-515... Score: 9/10 | Verdict: KEEP
# [507/820] Evaluating AUD-SYNC26-516... Score: 9/10 | Verdict: KEEP
# [508/820] Evaluating AUD-SYNC26-517... Score: 9/10 | Verdict: KEEP
# [509/820] Evaluating AUD-SYNC26-519... Score: 9/10 | Verdict: KEEP
# [510/820] Evaluating AUD-SYNC26-520... Score: 8.5/10 | Verdict: KEEP
# [511/820] Evaluating AUD-SYNC26-521... Score: 9/10 | Verdict: KEEP
# [512/820] Evaluating AUD-SYNC26-522... Score: 9/10 | Verdict: KEEP
# [513/820] Evaluating AUD-SYNC26-523... Score: 9/10 | Verdict: KEEP
# [514/820] Evaluating AUD-SYNC26-524... Score: 9/10 | Verdict: KEEP
# [515/820] Evaluating AUD-SYNC26-525... Score: 9/10 | Verdict: KEEP
# [516/820] Evaluating AUD-SYNC26-526... Score: 8/10 | Verdict: KEEP
# [517/820] Evaluating AUD-SYNC26-527... Score: 9.5/10 | Verdict: KEEP
# [518/820] Evaluating AUD-SYNC26-528... Score: 9/10 | Verdict: KEEP
# [519/820] Evaluating AUD-SYNC26-529... Score: 9/10 | Verdict: KEEP
# [520/820] Evaluating AUD-SYNC26-530... Score: 9/10 | Verdict: KEEP
# [521/820] Evaluating AUD-SYNC26-531... Score: 8.8/10 | Verdict: KEEP
# [522/820] Evaluating AUD-SYNC26-532... Score: 10/10 | Verdict: KEEP
# [523/820] Evaluating AUD-SYNC26-533... Score: 9/10 | Verdict: KEEP
# [524/820] Evaluating AUD-SYNC26-534... Score: 9/10 | Verdict: KEEP
# [525/820] Evaluating AUD-SYNC26-535... Score: 9/10 | Verdict: KEEP
# [526/820] Evaluating AUD-SYNC26-536... Score: 9/10 | Verdict: KEEP
# [527/820] Evaluating AUD-SYNC26-537... Score: 9/10 | Verdict: KEEP
# [528/820] Evaluating AUD-SYNC26-538... Score: 9/10 | Verdict: KEEP
# [529/820] Evaluating AUD-SYNC26-539... Score: 9/10 | Verdict: KEEP
# [530/820] Evaluating AUD-SYNC26-540... Score: 9/10 | Verdict: KEEP
# [531/820] Evaluating AUD-SYNC26-541... Score: 8.5/10 | Verdict: KEEP
# [532/820] Evaluating AUD-SYNC26-543... Score: 9/10 | Verdict: KEEP
# [533/820] Evaluating AUD-SYNC26-544... Score: 9/10 | Verdict: KEEP
# [534/820] Evaluating AUD-SYNC26-545... Score: 9/10 | Verdict: KEEP
# [535/820] Evaluating AUD-SYNC26-546... Score: 9/10 | Verdict: KEEP
# [536/820] Evaluating AUD-SYNC26-547... Score: 9/10 | Verdict: KEEP
# [537/820] Evaluating AUD-SYNC26-548... Score: 9/10 | Verdict: KEEP
# [538/820] Evaluating AUD-SYNC26-549... Score: 9/10 | Verdict: KEEP
# [539/820] Evaluating AUD-SYNC26-550... Score: 9.5/10 | Verdict: KEEP
# [540/820] Evaluating AUD-SYNC26-551... Score: 9/10 | Verdict: KEEP
# [541/820] Evaluating AUD-SYNC26-552... Score: 9.5/10 | Verdict: KEEP
# [542/820] Evaluating AUD-SYNC26-553... Score: 9/10 | Verdict: KEEP
# [543/820] Evaluating AUD-SYNC26-554... Score: 9.5/10 | Verdict: KEEP
# [544/820] Evaluating AUD-SYNC26-557... Score: 9/10 | Verdict: KEEP
# [545/820] Evaluating AUD-SYNC26-558... Score: 9/10 | Verdict: KEEP
# [546/820] Evaluating AUD-SYNC26-559... Score: 8/10 | Verdict: KEEP
# [547/820] Evaluating AUD-SYNC26-560... Score: 9/10 | Verdict: KEEP
# [548/820] Evaluating AUD-SYNC26-562... Score: 9/10 | Verdict: KEEP
# [549/820] Evaluating AUD-SYNC26-563... Score: 9/10 | Verdict: KEEP
# [550/820] Evaluating AUD-SYNC26-564... Score: 9/10 | Verdict: KEEP
#
#   === Progress: 550 done, 7.1 rows/min, ~38 min remaining ===
#
# [551/820] Evaluating AUD-SYNC26-565... Score: 9/10 | Verdict: KEEP
# [552/820] Evaluating AUD-SYNC26-566... Score: 9/10 | Verdict: KEEP
# [553/820] Evaluating AUD-SYNC26-567... Score: 9/10 | Verdict: KEEP
# [554/820] Evaluating AUD-SYNC26-568... Score: 9/10 | Verdict: KEEP
# [555/820] Evaluating AUD-SYNC26-569... Score: 9/10 | Verdict: KEEP
# [556/820] Evaluating AUD-SYNC26-571... Score: 9/10 | Verdict: KEEP
# [557/820] Evaluating AUD-SYNC26-572... Score: 8.7/10 | Verdict: KEEP
# [558/820] Evaluating AUD-SYNC26-573... Score: 9/10 | Verdict: KEEP
# [559/820] Evaluating AUD-SYNC26-574... Score: 8.7/10 | Verdict: KEEP
# [560/820] Evaluating AUD-SYNC26-575... Score: 9/10 | Verdict: KEEP
# [561/820] Evaluating AUD-SYNC26-576... Score: 9/10 | Verdict: KEEP
# [562/820] Evaluating AUD-SYNC26-578... Score: 9/10 | Verdict: KEEP
# [563/820] Evaluating AUD-SYNC26-579... Score: 9/10 | Verdict: KEEP
# [564/820] Evaluating AUD-SYNC26-580... Score: 9/10 | Verdict: KEEP
# [565/820] Evaluating AUD-SYNC26-581... Score: 9/10 | Verdict: KEEP
# [566/820] Evaluating AUD-SYNC26-582... Score: 8.5/10 | Verdict: KEEP
# [567/820] Evaluating AUD-SYNC26-583... Score: 9/10 | Verdict: KEEP
# [568/820] Evaluating AUD-SYNC26-584... Score: 9/10 | Verdict: KEEP
# [569/820] Evaluating AUD-SYNC26-585... Score: 8.5/10 | Verdict: KEEP
# [570/820] Evaluating AUD-SYNC26-586... Score: 9/10 | Verdict: KEEP
# [571/820] Evaluating AUD-SYNC26-587... Score: 9/10 | Verdict: KEEP
# [572/820] Evaluating AUD-SYNC26-588... Score: 9/10 | Verdict: KEEP
# [573/820] Evaluating AUD-SYNC26-589... Score: 9/10 | Verdict: KEEP
# [574/820] Evaluating AUD-SYNC26-590... Score: 8/10 | Verdict: KEEP
# [575/820] Evaluating AUD-SYNC26-591... Score: 9/10 | Verdict: KEEP
# [576/820] Evaluating AUD-SYNC26-592... Score: 9/10 | Verdict: KEEP
# [577/820] Evaluating AUD-SYNC26-593... Score: 9/10 | Verdict: KEEP
# [578/820] Evaluating AUD-SYNC26-594... Score: 9/10 | Verdict: KEEP
# [579/820] Evaluating AUD-SYNC26-595... Score: 9/10 | Verdict: KEEP
# [580/820] Evaluating AUD-SYNC26-596... Score: 9/10 | Verdict: KEEP
# [581/820] Evaluating AUD-SYNC26-597... Score: 9/10 | Verdict: KEEP
# [582/820] Evaluating AUD-SYNC26-598... Score: 8/10 | Verdict: KEEP
# [583/820] Evaluating AUD-SYNC26-599... Score: 9/10 | Verdict: KEEP
# [584/820] Evaluating AUD-SYNC26-600... Score: 9/10 | Verdict: KEEP
# [585/820] Evaluating AUD-SYNC26-601... Score: 9/10 | Verdict: KEEP
# [586/820] Evaluating AUD-SYNC26-602... Score: 9/10 | Verdict: KEEP
# [587/820] Evaluating AUD-SYNC26-603... Score: 9/10 | Verdict: KEEP
# [588/820] Evaluating AUD-SYNC26-604... Score: 9/10 | Verdict: KEEP
# [589/820] Evaluating AUD-SYNC26-605... Score: 9/10 | Verdict: KEEP
# [590/820] Evaluating AUD-SYNC26-606... Score: 9/10 | Verdict: KEEP
# [591/820] Evaluating AUD-SYNC26-607... Score: 9/10 | Verdict: KEEP
# [592/820] Evaluating AUD-SYNC26-608... Score: 9/10 | Verdict: KEEP
# [593/820] Evaluating AUD-SYNC26-609... Score: 9/10 | Verdict: KEEP
# [594/820] Evaluating AUD-SYNC26-610... Score: 9/10 | Verdict: KEEP
# [595/820] Evaluating AUD-SYNC26-611... Score: 8/10 | Verdict: KEEP
# [596/820] Evaluating AUD-SYNC26-612... Score: 9/10 | Verdict: KEEP
# [597/820] Evaluating AUD-SYNC26-613... Score: 9/10 | Verdict: KEEP
# [598/820] Evaluating AUD-SYNC26-614... Score: 9/10 | Verdict: KEEP
# [599/820] Evaluating AUD-SYNC26-615... Score: 9/10 | Verdict: KEEP
# [600/820] Evaluating AUD-SYNC26-616... Score: 9/10 | Verdict: KEEP
#
#   === Progress: 600 done, 7.2 rows/min, ~31 min remaining ===
#
# [601/820] Evaluating AUD-SYNC26-617... Score: 9/10 | Verdict: KEEP
# [602/820] Evaluating AUD-SYNC26-618... Score: 9/10 | Verdict: KEEP
# [603/820] Evaluating AUD-SYNC26-619... Score: 8.5/10 | Verdict: KEEP
# [604/820] Evaluating AUD-SYNC26-620... Score: 9/10 | Verdict: KEEP
# [605/820] Evaluating AUD-SYNC26-621... Score: 9/10 | Verdict: KEEP
# [606/820] Evaluating AUD-SYNC26-622... Score: 9/10 | Verdict: KEEP
# [607/820] Evaluating AUD-SYNC26-623... Score: 8.5/10 | Verdict: KEEP
# [608/820] Evaluating AUD-SYNC26-624... Score: 9/10 | Verdict: KEEP
# [609/820] Evaluating AUD-SYNC26-625... Score: 8.5/10 | Verdict: KEEP
# [610/820] Evaluating AUD-SYNC26-626... Score: 9.7/10 | Verdict: KEEP
# [611/820] Evaluating AUD-SYNC26-627... Score: 9/10 | Verdict: KEEP
# [612/820] Evaluating AUD-SYNC26-628... Score: 9/10 | Verdict: KEEP
# [613/820] Evaluating AUD-SYNC26-629... Score: 9/10 | Verdict: KEEP
# [614/820] Evaluating AUD-SYNC26-630... Score: 9/10 | Verdict: KEEP
# [615/820] Evaluating AUD-SYNC26-633... Score: 9.7/10 | Verdict: KEEP
# [616/820] Evaluating AUD-SYNC26-634... Score: 9/10 | Verdict: KEEP
# [617/820] Evaluating AUD-SYNC26-635... Score: 9/10 | Verdict: KEEP
# [618/820] Evaluating AUD-SYNC26-636... Score: 9/10 | Verdict: KEEP
# [619/820] Evaluating AUD-SYNC26-637... Score: 9/10 | Verdict: KEEP
# [620/820] Evaluating AUD-SYNC26-638... Score: 9/10 | Verdict: KEEP
# [621/820] Evaluating AUD-SYNC26-639... Score: 9/10 | Verdict: KEEP
# [622/820] Evaluating AUD-SYNC26-640... Score: 9/10 | Verdict: KEEP
# [623/820] Evaluating AUD-SYNC26-641... Score: 9/10 | Verdict: KEEP
# [624/820] Evaluating AUD-SYNC26-642... Score: 9/10 | Verdict: KEEP
# [625/820] Evaluating AUD-SYNC26-643... Score: 9/10 | Verdict: KEEP
# [626/820] Evaluating AUD-SYNC26-644... Score: 9/10 | Verdict: KEEP
# [627/820] Evaluating AUD-SYNC26-645... Score: 9/10 | Verdict: KEEP
# [628/820] Evaluating AUD-SYNC26-646... Score: 9/10 | Verdict: KEEP
# [629/820] Evaluating AUD-SYNC26-647... Score: 9/10 | Verdict: KEEP
# [630/820] Evaluating AUD-SYNC26-648... Score: 9/10 | Verdict: KEEP
# [631/820] Evaluating AUD-SYNC26-649... Score: 9/10 | Verdict: KEEP
# [632/820] Evaluating AUD-SYNC26-650... Score: 9/10 | Verdict: KEEP
# [633/820] Evaluating AUD-SYNC26-651... Score: 9.7/10 | Verdict: KEEP
# [634/820] Evaluating AUD-SYNC26-652... Score: 9/10 | Verdict: KEEP
# [635/820] Evaluating AUD-SYNC26-653... Score: 9/10 | Verdict: KEEP
# [636/820] Evaluating AUD-SYNC26-654... Score: 9/10 | Verdict: KEEP
# [637/820] Evaluating AUD-SYNC26-655... Score: 9/10 | Verdict: KEEP
# [638/820] Evaluating AUD-SYNC26-656... Score: 9/10 | Verdict: KEEP
# [639/820] Evaluating AUD-SYNC26-657... Score: 9/10 | Verdict: KEEP
# [640/820] Evaluating AUD-SYNC26-658... Score: 9/10 | Verdict: KEEP
# [641/820] Evaluating AUD-SYNC26-659... Score: 9/10 | Verdict: KEEP
# [642/820] Evaluating AUD-SYNC26-660... Score: 9/10 | Verdict: KEEP
# [643/820] Evaluating AUD-SYNC26-661... Score: 9/10 | Verdict: KEEP
# [644/820] Evaluating AUD-SYNC26-662... Score: 9.5/10 | Verdict: KEEP
# [645/820] Evaluating AUD-SYNC26-663... Score: 9/10 | Verdict: KEEP
# [646/820] Evaluating AUD-SYNC26-664... Score: 9/10 | Verdict: KEEP
# [647/820] Evaluating AUD-SYNC26-665... Score: 9/10 | Verdict: KEEP
# [648/820] Evaluating AUD-SYNC26-666... Score: 9/10 | Verdict: KEEP
# [649/820] Evaluating AUD-SYNC26-667... Score: 9/10 | Verdict: KEEP
# [650/820] Evaluating AUD-SYNC26-668... Score: 9/10 | Verdict: KEEP
#
#   === Progress: 650 done, 7.2 rows/min, ~24 min remaining ===
#
# [651/820] Evaluating AUD-SYNC26-669... Score: 9/10 | Verdict: KEEP
# [652/820] Evaluating AUD-SYNC26-670... Score: 9/10 | Verdict: KEEP
# [653/820] Evaluating AUD-SYNC26-671... Score: 9/10 | Verdict: KEEP
# [654/820] Evaluating AUD-SYNC26-672... Score: 9/10 | Verdict: KEEP
# [655/820] Evaluating AUD-SYNC26-673... Score: 9/10 | Verdict: KEEP
# [656/820] Evaluating AUD-SYNC26-674... Score: 9.5/10 | Verdict: KEEP
# [657/820] Evaluating AUD-SYNC26-675... Score: 9/10 | Verdict: KEEP
# [658/820] Evaluating AUD-SYNC26-676... Score: 9/10 | Verdict: KEEP
# [659/820] Evaluating AUD-SYNC26-677... Score: 9/10 | Verdict: KEEP
# [660/820] Evaluating AUD-SYNC26-678... Score: 9/10 | Verdict: KEEP
# [661/820] Evaluating AUD-SYNC26-679... Score: 9/10 | Verdict: KEEP
# [662/820] Evaluating AUD-SYNC26-680... Score: 9/10 | Verdict: KEEP
# [663/820] Evaluating AUD-SYNC26-681... Score: 8.5/10 | Verdict: KEEP
# [664/820] Evaluating AUD-SYNC26-682... Score: 8/10 | Verdict: KEEP
# [665/820] Evaluating AUD-SYNC26-683... Score: 9/10 | Verdict: KEEP
# [666/820] Evaluating AUD-SYNC26-685... Score: 9/10 | Verdict: KEEP
# [667/820] Evaluating AUD-SYNC26-686... Score: 9/10 | Verdict: KEEP
# [668/820] Evaluating AUD-SYNC26-687... Score: 9/10 | Verdict: KEEP
# [669/820] Evaluating AUD-SYNC26-688... Score: 9.5/10 | Verdict: KEEP
# [670/820] Evaluating AUD-SYNC26-689... Score: 9/10 | Verdict: KEEP
# [671/820] Evaluating AUD-SYNC26-690... Score: 9/10 | Verdict: KEEP
# [672/820] Evaluating AUD-SYNC26-691... Score: 9/10 | Verdict: KEEP
# [673/820] Evaluating AUD-SYNC26-692... Score: 9/10 | Verdict: KEEP
# [674/820] Evaluating AUD-SYNC26-693... Score: 9/10 | Verdict: KEEP
# [675/820] Evaluating AUD-SYNC26-694... Score: 9.7/10 | Verdict: KEEP
# [676/820] Evaluating AUD-SYNC26-695... Score: 9/10 | Verdict: KEEP
# [677/820] Evaluating AUD-SYNC26-696... Score: 9/10 | Verdict: KEEP
# [678/820] Evaluating AUD-SYNC26-697... Score: 9/10 | Verdict: KEEP
# [679/820] Evaluating AUD-SYNC26-698... Score: 9.7/10 | Verdict: KEEP
# [680/820] Evaluating AUD-SYNC26-699... Score: 9/10 | Verdict: KEEP
# [681/820] Evaluating AUD-SYNC26-700... Score: 9/10 | Verdict: KEEP
# [682/820] Evaluating AUD-SYNC26-701... Score: 9/10 | Verdict: KEEP
# [683/820] Evaluating AUD-SYNC26-702... Score: 9/10 | Verdict: KEEP
# [684/820] Evaluating AUD-SYNC26-704... Score: 9/10 | Verdict: KEEP
# [685/820] Evaluating AUD-SYNC26-705... Score: 9/10 | Verdict: KEEP
# [686/820] Evaluating AUD-SYNC26-706... Score: 9/10 | Verdict: KEEP
# [687/820] Evaluating AUD-SYNC26-707... Score: 9/10 | Verdict: KEEP
# [688/820] Evaluating AUD-SYNC26-708... Score: 9/10 | Verdict: KEEP
# [689/820] Evaluating AUD-SYNC26-709... Score: 9/10 | Verdict: KEEP
# [690/820] Evaluating AUD-SYNC26-710... Score: 9/10 | Verdict: KEEP
# [691/820] Evaluating AUD-SYNC26-711... Score: 9/10 | Verdict: KEEP
# [692/820] Evaluating AUD-SYNC26-712... Score: 9/10 | Verdict: KEEP
# [693/820] Evaluating AUD-SYNC26-713... Score: 9/10 | Verdict: KEEP
# [694/820] Evaluating AUD-SYNC26-714... Score: 9/10 | Verdict: KEEP
# [695/820] Evaluating AUD-SYNC26-715... Score: 9/10 | Verdict: KEEP
# [696/820] Evaluating AUD-SYNC26-716... Score: 9/10 | Verdict: KEEP
# [697/820] Evaluating AUD-SYNC26-717... Score: 9/10 | Verdict: KEEP
# [698/820] Evaluating AUD-SYNC26-718... Score: 9.5/10 | Verdict: KEEP
# [699/820] Evaluating AUD-SYNC26-719... Score: 9/10 | Verdict: KEEP
# [700/820] Evaluating AUD-SYNC26-720... Score: 8.5/10 | Verdict: KEEP
#
#   === Progress: 700 done, 7.2 rows/min, ~17 min remaining ===
#
# [701/820] Evaluating AUD-SYNC26-721... Score: 8/10 | Verdict: KEEP
# [702/820] Evaluating AUD-SYNC26-722... Score: 8/10 | Verdict: KEEP
# [703/820] Evaluating AUD-SYNC26-723... Score: 8/10 | Verdict: KEEP
# [704/820] Evaluating AUD-SYNC26-724... Score: 8/10 | Verdict: KEEP
# [705/820] Evaluating AUD-SYNC26-725... Score: 5/10 | Verdict: NEEDS_REPAIR
# [706/820] Evaluating AUD-SYNC26-726... Score: 8/10 | Verdict: KEEP
# [707/820] Evaluating AUD-SYNC26-727... Score: 8/10 | Verdict: KEEP
# [708/820] Evaluating AUD-SYNC26-728... Score: 7.5/10 | Verdict: KEEP
# [709/820] Evaluating AUD-SYNC26-729... Score: 8/10 | Verdict: KEEP
# [710/820] Evaluating AUD-SYNC26-730... Score: 8/10 | Verdict: KEEP
# [711/820] Evaluating AUD-SYNC26-731... Score: 8/10 | Verdict: KEEP
# [712/820] Evaluating AUD-SYNC26-732... Score: 9/10 | Verdict: KEEP
# [713/820] Evaluating AUD-SYNC26-733... Score: 8/10 | Verdict: KEEP
# [714/820] Evaluating AUD-SYNC26-734... Score: 8/10 | Verdict: KEEP
# [715/820] Evaluating AUD-SYNC26-735... Score: 8/10 | Verdict: KEEP
# [716/820] Evaluating AUD-SYNC26-736... Score: 7.5/10 | Verdict: KEEP
# [717/820] Evaluating AUD-SYNC26-737... Score: 8/10 | Verdict: KEEP
# [718/820] Evaluating AUD-SYNC26-738... Score: 7.5/10 | Verdict: KEEP
# [719/820] Evaluating AUD-SYNC26-739... Score: 8/10 | Verdict: KEEP
# [720/820] Evaluating AUD-SYNC26-740... Score: 8/10 | Verdict: KEEP
# [721/820] Evaluating AUD-SYNC26-741... Score: 8/10 | Verdict: KEEP
# [722/820] Evaluating AUD-SYNC26-742... Score: 7/10 | Verdict: KEEP
# [723/820] Evaluating AUD-SYNC26-743... Score: 8.5/10 | Verdict: KEEP
# [724/820] Evaluating AUD-SYNC26-744... Score: 7/10 | Verdict: KEEP
# [725/820] Evaluating AUD-SYNC26-745... Score: 8.5/10 | Verdict: KEEP
# [726/820] Evaluating AUD-SYNC26-746... Score: 9/10 | Verdict: KEEP
# [727/820] Evaluating AUD-SYNC26-747... Score: 8/10 | Verdict: KEEP
# [728/820] Evaluating AUD-SYNC26-748... Score: 7.5/10 | Verdict: KEEP
# [729/820] Evaluating AUD-SYNC26-749... Score: 8/10 | Verdict: KEEP
# [730/820] Evaluating AUD-SYNC26-750... Score: 9/10 | Verdict: KEEP
# [731/820] Evaluating AUD-SYNC26-751... Score: 9/10 | Verdict: KEEP
# [732/820] Evaluating AUD-SYNC26-752... Score: 9/10 | Verdict: KEEP
# [733/820] Evaluating AUD-SYNC26-753... Score: 7/10 | Verdict: KEEP
# [734/820] Evaluating AUD-SYNC26-754... Score: 9/10 | Verdict: KEEP
# [735/820] Evaluating AUD-SYNC26-755... Score: 9/10 | Verdict: KEEP
# [736/820] Evaluating AUD-SYNC26-756... Score: 9/10 | Verdict: KEEP
# [737/820] Evaluating AUD-SYNC26-757... Score: 9/10 | Verdict: KEEP
# [738/820] Evaluating AUD-SYNC26-758... Score: 9/10 | Verdict: KEEP
# [739/820] Evaluating AUD-SYNC26-759... Score: 9/10 | Verdict: KEEP
# [740/820] Evaluating AUD-SYNC26-760... Score: 7/10 | Verdict: KEEP
# [741/820] Evaluating AUD-SYNC26-761... Score: 7/10 | Verdict: KEEP
# [742/820] Evaluating AUD-SYNC26-762... Score: 9/10 | Verdict: KEEP
# [743/820] Evaluating AUD-SYNC26-763... Score: 9/10 | Verdict: KEEP
# [744/820] Evaluating AUD-SYNC26-764... Score: 8.5/10 | Verdict: KEEP
# [745/820] Evaluating AUD-SYNC26-765... Score: 9/10 | Verdict: KEEP
# [746/820] Evaluating AUD-SYNC26-766... Score: 7/10 | Verdict: KEEP
# [747/820] Evaluating AUD-SYNC26-767... Score: 9/10 | Verdict: KEEP
# [748/820] Evaluating AUD-SYNC26-768... Score: 9/10 | Verdict: KEEP
# [749/820] Evaluating AUD-SYNC26-769... Score: 9/10 | Verdict: KEEP
# [750/820] Evaluating AUD-SYNC26-770... Score: 9/10 | Verdict: KEEP
#
#   === Progress: 750 done, 7.2 rows/min, ~10 min remaining ===
#
# [751/820] Evaluating AUD-SYNC26-771... Score: 9/10 | Verdict: KEEP
# [752/820] Evaluating AUD-SYNC26-772... Score: 8/10 | Verdict: KEEP
# [753/820] Evaluating AUD-SYNC26-773... Score: 8.5/10 | Verdict: KEEP
# [754/820] Evaluating AUD-SYNC26-774... Score: 9/10 | Verdict: KEEP
# [755/820] Evaluating AUD-SYNC26-775... Score: 8.5/10 | Verdict: KEEP
# [756/820] Evaluating AUD-SYNC26-776... Score: 8.5/10 | Verdict: KEEP
# [757/820] Evaluating AUD-SYNC26-777... Score: 9/10 | Verdict: KEEP
# [758/820] Evaluating AUD-SYNC26-778... Score: 7/10 | Verdict: KEEP
# [759/820] Evaluating AUD-SYNC26-779... Score: 8.5/10 | Verdict: KEEP
# [760/820] Evaluating AUD-SYNC26-780... Score: 9/10 | Verdict: KEEP
# [761/820] Evaluating AUD-SYNC26-781... Score: 8/10 | Verdict: KEEP
# [762/820] Evaluating AUD-SYNC26-782... Score: 8/10 | Verdict: KEEP
# [763/820] Evaluating AUD-SYNC26-783... Score: 7/10 | Verdict: KEEP
# [764/820] Evaluating AUD-SYNC26-784... Score: 6/10 | Verdict: NEEDS_REPAIR
# [765/820] Evaluating AUD-SYNC26-785... Score: 4/10 | Verdict: NEEDS_REPAIR
# [766/820] Evaluating AUD-SYNC26-786... Score: 8/10 | Verdict: KEEP
# [767/820] Evaluating AUD-SYNC26-787... Score: 8.5/10 | Verdict: KEEP
# [768/820] Evaluating AUD-SYNC26-788... Score: 8/10 | Verdict: KEEP
# [769/820] Evaluating AUD-SYNC26-789... Score: 8/10 | Verdict: KEEP
# [770/820] Evaluating AUD-SYNC26-790... Score: 9/10 | Verdict: KEEP
# [771/820] Evaluating AUD-SYNC26-791... Score: 8/10 | Verdict: KEEP
# [772/820] Evaluating AUD-SYNC26-792... Score: 9/10 | Verdict: KEEP
# [773/820] Evaluating AUD-SYNC26-793... Score: 8/10 | Verdict: KEEP
# [774/820] Evaluating AUD-SYNC26-794... Score: 8.5/10 | Verdict: KEEP
# [775/820] Evaluating AUD-SYNC26-795... Score: 8/10 | Verdict: KEEP
# [776/820] Evaluating AUD-SYNC26-796... Score: 9/10 | Verdict: KEEP
# [777/820] Evaluating AUD-SYNC26-797... Score: 9/10 | Verdict: KEEP
# [778/820] Evaluating AUD-SYNC26-798... Score: 8.5/10 | Verdict: KEEP
# [779/820] Evaluating AUD-SYNC26-799... Score: 9/10 | Verdict: KEEP
# [780/820] Evaluating AUD-SYNC26-800... Score: 8/10 | Verdict: KEEP
# [781/820] Evaluating AUD-SYNC26-801... Score: 9/10 | Verdict: KEEP
# [782/820] Evaluating AUD-SYNC26-802... Score: 8.5/10 | Verdict: KEEP
# [783/820] Evaluating AUD-SYNC26-803... Score: 8/10 | Verdict: KEEP
# [784/820] Evaluating AUD-SYNC26-804... Score: 7/10 | Verdict: KEEP
# [785/820] Evaluating AUD-SYNC26-805... Score: 9/10 | Verdict: KEEP
# [786/820] Evaluating AUD-SYNC26-806... Score: 8.7/10 | Verdict: KEEP
# [787/820] Evaluating AUD-SYNC26-807... Score: 8/10 | Verdict: KEEP
# [788/820] Evaluating AUD-SYNC26-808... Score: 7.5/10 | Verdict: KEEP
# [789/820] Evaluating AUD-SYNC26-809... Score: 9/10 | Verdict: KEEP
# [790/820] Evaluating AUD-SYNC26-810... Score: 6/10 | Verdict: NEEDS_REPAIR
# [791/820] Evaluating AUD-SYNC26-811... Score: 9/10 | Verdict: KEEP
# [792/820] Evaluating AUD-SYNC26-812... Score: 8/10 | Verdict: KEEP
# [793/820] Evaluating AUD-SYNC26-813... Score: 9/10 | Verdict: KEEP
# [794/820] Evaluating AUD-SYNC26-814... Score: 8/10 | Verdict: KEEP
# [795/820] Evaluating AUD-SYNC26-815... Score: 9/10 | Verdict: KEEP
# [796/820] Evaluating AUD-SYNC26-816... Score: 8.5/10 | Verdict: KEEP
# [797/820] Evaluating AUD-SYNC26-817... Score: 6/10 | Verdict: NEEDS_REPAIR
# [798/820] Evaluating AUD-SYNC26-818... Score: 8/10 | Verdict: KEEP
# [799/820] Evaluating AUD-SYNC26-819... Score: 9/10 | Verdict: KEEP
# [800/820] Evaluating AUD-SYNC26-820... Score: 8/10 | Verdict: KEEP
#
#   === Progress: 800 done, 7.3 rows/min, ~3 min remaining ===
#
# [801/820] Evaluating AUD-SYNC26-821... Score: 9/10 | Verdict: KEEP
# [802/820] Evaluating AUD-SYNC26-822... Score: 8/10 | Verdict: KEEP
# [803/820] Evaluating AUD-SYNC26-823... Score: 9/10 | Verdict: KEEP
# [804/820] Evaluating AUD-SYNC26-824... Score: 9/10 | Verdict: KEEP
# [805/820] Evaluating AUD-SYNC26-825... Score: 9/10 | Verdict: KEEP
# [806/820] Evaluating AUD-SYNC26-826... Score: 8/10 | Verdict: KEEP
# [807/820] Evaluating AUD-SYNC26-827... Score: 7.5/10 | Verdict: KEEP
# [808/820] Evaluating AUD-SYNC26-828... Score: 9/10 | Verdict: KEEP
# [809/820] Evaluating AUD-SYNC26-829... Score: 8/10 | Verdict: KEEP
# [810/820] Evaluating AUD-SYNC26-830... Score: 8/10 | Verdict: KEEP
# [811/820] Evaluating AUD-SYNC26-831... Score: 8/10 | Verdict: KEEP
# [812/820] Evaluating AUD-SYNC26-832... Score: 8/10 | Verdict: KEEP
# [813/820] Evaluating AUD-SYNC26-833... Score: 9/10 | Verdict: KEEP
# [814/820] Evaluating AUD-SYNC26-834... Score: 9/10 | Verdict: KEEP
# [815/820] Evaluating AUD-SYNC26-835... Score: 8/10 | Verdict: KEEP
# [816/820] Evaluating AUD-SYNC26-836... Score: 8.5/10 | Verdict: KEEP
# [817/820] Evaluating AUD-SYNC26-837... Score: 9/10 | Verdict: KEEP
# [818/820] Evaluating AUD-SYNC26-838... Score: 9/10 | Verdict: KEEP
# [819/820] Evaluating AUD-SYNC26-839... Score: 9/10 | Verdict: KEEP
# [820/820] Evaluating AUD-SYNC26-840... Score: 8/10 | Verdict: KEEP
#
# ============================================================
# EVALUATION COMPLETE
# ============================================================
# Errors: 0
# Time: 112.8 minutes
# Results saved to: validation_output/llm_as_a_judge/llm_validation_results.jsonl

# %%
# ═══════════════════════════════════════════════════════════════
# ANALYZE LLM VALIDATION RESULTS & APPLY THRESHOLD
# ═══════════════════════════════════════════════════════════════

import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

RESULTS_PATH = "validation_output/llm_as_a_judge/llm_validation_results.jsonl"
THRESHOLD = 8

# Load results
results = []
with open(RESULTS_PATH, 'r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if line:
            try:
                results.append(json.loads(line))
            except:
                pass

print(f"Loaded {len(results)} evaluation results")

# Build DataFrame
records = []
for r in results:
    record = {
        'sample_id': r.get('sample_id', ''),
        'case_type': r.get('case_type', ''),
        'projectclass': r.get('projectclass', ''),
        'round': r.get('round', 0),
        'overall_quality': r.get('overall_quality', 0),
        'verdict': r.get('verdict', ''),
    }
    for dim in ['plan_realism', 'audit_reasoning', 'score_calibration',
                'contract_plan_alignment', 'issue_consistency', 'cross_field_coherence']:
        dim_data = r.get(dim, {})
        record[dim] = dim_data.get('score', 0) if isinstance(dim_data, dict) else 0
    record['critical_problems'] = r.get('critical_problems', [])
    records.append(record)

df = pd.DataFrame(records)

# Summary Statistics
print(f"\n{'='*60}")
print(f"LLM VALIDATION SUMMARY")
print(f"{'='*60}")
print(f"\nOverall Quality Distribution:")
print(df['overall_quality'].describe().to_string())

print(f"\nVerdict Distribution:")
print(df['verdict'].value_counts().to_string())

dims = ['plan_realism', 'audit_reasoning', 'score_calibration',
        'contract_plan_alignment', 'issue_consistency', 'cross_field_coherence']
print(f"\nDimension Means:")
for dim in dims:
    print(f"  {dim}: {df[dim].mean():.2f}")

# Threshold Analysis
keep = df[df['overall_quality'] >= THRESHOLD]
remove = df[df['overall_quality'] < THRESHOLD]
repair = df[df['verdict'] == 'NEEDS_REPAIR']

print(f"\n{'='*60}")
print(f"THRESHOLD ANALYSIS (threshold={THRESHOLD})")
print(f"{'='*60}")
print(f"KEEP: {len(keep)} rows ({len(keep)/len(df)*100:.1f}%)")
print(f"REMOVE: {len(remove)} rows ({len(remove)/len(df)*100:.1f}%)")
print(f"NEEDS_REPAIR (from LLM verdict): {len(repair)} rows")

# Show what would be lost per project class
print(f"\nRemoved rows by project class:")
if len(remove) > 0:
    print(remove['projectclass'].value_counts().to_string())

# Visualizations
fig, axes = plt.subplots(2, 2, figsize=(15, 11))

# 1. Overall quality distribution
axes[0,0].hist(df['overall_quality'], bins=range(1, 12), edgecolor='black', alpha=0.7, color='#4C72B0')
axes[0,0].axvline(THRESHOLD, color='red', linestyle='--', linewidth=2, label=f'Threshold ({THRESHOLD})')
axes[0,0].set_xlabel('Overall Quality Score')
axes[0,0].set_ylabel('Count')
axes[0,0].set_title('LLM-Judged Overall Quality Distribution')
axes[0,0].legend()

# 2. Dimension scores heatmap
pivot = df.groupby('projectclass')[dims].mean()
sns.heatmap(pivot, annot=True, fmt='.1f', cmap='RdYlGn', vmin=1, vmax=10,
            ax=axes[0,1])
axes[0,1].set_title('Mean Dimension Score by Project Class')

# 3. Verdict pie chart
verdict_counts = df['verdict'].value_counts()
axes[1,0].pie(verdict_counts.values, labels=verdict_counts.index, autopct='%1.1f%%', colors=['#55A868', '#C44E52', '#DD8452', '#8172B3'])
axes[1,0].set_title('LLM Verdict Distribution')

# 4. Dimension box plots
df[dims].boxplot(ax=axes[1,1], grid=False)
axes[1,1].set_title('Score Distribution per Dimension')
axes[1,1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.savefig('validation_output/llm_as_a_judge/llm_validation_analysis.png', dpi=150, bbox_inches='tight')
plt.show()

# Most Common Critical Problems
all_problems = []
for r in results:
    all_problems.extend(r.get('critical_problems', []))
print(f"\nTop 15 Most Common Critical Problems:")
for problem, count in Counter(all_problems).most_common(15):
    print(f"  ({count}x) {problem}")

# Export filtered dataset
keep_ids = set(keep['sample_id'].tolist())
print(f"\nKeep IDs saved: {len(keep_ids)}")

# Save the list of IDs to keep/remove for use in the next step
with open('validation_output/llm_as_a_judge/validation_keep_ids.json', 'w') as f:
    json.dump(list(keep_ids), f)
with open('validation_output/llm_as_a_judge/validation_remove_ids.json', 'w') as f:
    json.dump(list(remove['sample_id'].tolist()), f)
print(f"Saved keep/remove ID lists to validation_output/llm_as_a_judge/validation_keep_ids.json and validation_output/llm_as_a_judge/validation_remove_ids.json")
# Out:
# Loaded 820 evaluation results
#
# ============================================================
# LLM VALIDATION SUMMARY
# ============================================================
#
# Overall Quality Distribution:
# count    820.000000
# mean       8.889512
# std        0.496815
# min        4.000000
# 25%        9.000000
# 50%        9.000000
# 75%        9.000000
# max       10.000000
#
# Verdict Distribution:
# verdict
# KEEP            815
# NEEDS_REPAIR      5
#
# Dimension Means:
#   plan_realism: 7.96
#   audit_reasoning: 8.52
#   score_calibration: 8.37
#   contract_plan_alignment: 9.78
#   issue_consistency: 9.97
#   cross_field_coherence: 9.42
#
# ============================================================
# THRESHOLD ANALYSIS (threshold=8)
# ============================================================
# KEEP: 799 rows (97.4%)
# REMOVE: 21 rows (2.6%)
# NEEDS_REPAIR (from LLM verdict): 5 rows
#
# Removed rows by project class:
# projectclass
# datapipeline             5
# automationtool           4
# librarysdk               2
# apiservice               2
# desktopapp               1
# clitool                  1
# infrastructureproject    1
# webapp                   1
# researchprototype        1
# mobileapp                1
# staticwebsite            1
# aisystem                 1
# Top 15 Most Common Critical Problems:
#   (1x) Minor missed deviation: frontendstack required SwiftUI but plan only states Swift.
#   (1x) Minor mismatch on observability baseline (Stdout vs None)
#   (1x) Metadata primary_flaw_family misclassified; should be 'security' rather than 'datahandling'.
#   (1x) Audit missed the observability baseline deviation (Crashlytics vs Datadog).
#   (1x) Plan realism extremely low
#   (1x) Rubric score calibration inconsistent with thin plan
#   (1x) Plan realism is weak and may need richer technical elaboration.
#   (1x) Plan realism is minimal; lacking depth could limit training richness.
#   (1x) Plan realism is very low; future revisions should include concrete technical deployment details.
#   (1x) Plan realism very low; could benefit from more concrete architectural description
#   (1x) Audit reasoning lacks depth and specificity, making justification of strong rubric scores weak.
#   (1x) Plan realism is extremely low, limiting its usefulness for training higher-fidelity architectural reasoning.
#   (1x) Plan still unrealistic and lacks architectural substance, though audit logic and rubric coherence are solid.
#   (1x) Low realism in plan content limits training richness.
#   (1x) Audit reasoning is shallow and not substantiated by plan content
#
# Keep IDs saved: 799
# Saved keep/remove ID lists to validation_output/llm_as_a_judge/validation_keep_ids.json and validation_output/llm_as_a_judge/validation_remove_ids.json

# %%
# ═══════════════════════════════════════════════════════════════
# FINAL EXPORT
# ═══════════════════════════════════════════════════════════════

# Load the keep list from LLM validation
with open('validation_output/llm_as_a_judge/validation_keep_ids.json', 'r') as f:
    keep_ids = set(json.load(f))

print(f"LLM validation approved: {len(keep_ids)} rows")

# Filter cleaned_rows to only those approved by the LLM judge
final_rows = [r for r in cleaned_rows if r.get('sample_id') in keep_ids]

print(f"Final dataset size: {len(final_rows)} rows")

# Final distribution check
from collections import Counter
final_pc = Counter(r.get('profile', {}).get('projectclass', '') for r in final_rows)
final_ct = Counter(r.get('metadata', {}).get('case_type', '') for r in final_rows)
final_ff = Counter(r.get('metadata', {}).get('primary_flaw_family', '') for r in final_rows)

print(f"\nProject classes: {dict(final_pc)}")
print(f"Case types: {dict(final_ct)}")
print(f"Flaw families: {dict(final_ff)}")

# Export
OUTPUT_FINAL = "validation_output/llm_as_a_judge/auditor_dataset_final.jsonl"
with open(OUTPUT_FINAL, 'w', encoding='utf-8') as f:
    for row in final_rows:
        f.write(json.dumps(row, ensure_ascii=False) + '\n')

print(f"\nFinal dataset exported: {OUTPUT_FINAL}")
# Out:
# LLM validation approved: 799 rows
# Final dataset size: 799 rows
#
# Project classes: {'fullstackapp': 52, 'apiservice': 77, 'clitool': 49, 'aisystem': 69, 'datapipeline': 69, 'staticwebsite': 44, 'mobileapp': 80, 'librarysdk': 51, 'webapp': 79, 'infrastructureproject': 63, 'desktopapp': 52, 'automationtool': 55, 'researchprototype': 35, 'landingpage': 24}
# Case types: {'first_pass': 346, 'revision_round': 453}
# Flaw families: {'security': 194, 'none': 315, 'requirementconflict': 78, 'internalconsistency': 29, 'compliance': 32, 'operability': 69, 'architecturequality': 53, 'deployment': 8, 'scalability': 2, 'datahandling': 2, 'regression': 17}
#
# Final dataset exported: validation_output/llm_as_a_judge/auditor_dataset_final.jsonl

# %%
import json
from pathlib import Path

INPUT_PATH  = "validation_output/llm_as_a_judge/auditor_dataset_final.jsonl"
OUTPUT_PATH = "validation_output/llm_as_a_judge/auditor_dataset_fixed.jsonl"

TOP_LEVEL_MAP = {
    "thinkingsummary":      "thinking_summary",
    "rubricscores":         "rubric_scores",
    "blockingissues":       "blocking_issues",
    "requirementconflicts": "requirement_conflicts",
    "issueupdates":         "issue_updates",
}

RUBRIC_MAP = {
    "requirementsalignment": "requirements_alignment",
    "architecturequality":   "architecture_quality",
    "internalconsistency":   "internal_consistency",
}

CONFLICT_MAP = {
    "issueid":       "issue_id",
    "currentvalue":  "current_value",
    "proposedvalue": "proposed_value",
    "exactreason":   "exact_reason",
}


def remap_keys(d: dict, key_map: dict) -> dict:
    return {key_map.get(k, k): v for k, v in d.items()}


def fix_target_output(target: dict) -> dict:
    fixed = remap_keys(target, TOP_LEVEL_MAP)

    for rubric_key in ("rubricscores", "rubric_scores"):
        if rubric_key in fixed and isinstance(fixed[rubric_key], dict):
            fixed["rubric_scores"] = remap_keys(fixed.pop(rubric_key), RUBRIC_MAP)

    for conflicts_key in ("requirementconflicts", "requirement_conflicts"):
        if conflicts_key in fixed and isinstance(fixed[conflicts_key], list):
            fixed["requirement_conflicts"] = [
                remap_keys(item, CONFLICT_MAP) if isinstance(item, dict) else item
                for item in fixed.pop(conflicts_key)
            ]

    return fixed


def fix_dataset(input_path: str, output_path: str):
    rows = []
    with open(input_path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if line:
                try:
                    rows.append(json.loads(line))
                except json.JSONDecodeError as e:
                    print(f"  SKIP bad JSON line: {e}")

    print(f"Loaded {len(rows)} rows from {input_path}")

    fixed_rows = []
    issues_found = 0

    for i, row in enumerate(rows):
        target = row.get("target_output", {})
        if not isinstance(target, dict):
            print(f"  WARNING row {i}: target_output is not a dict")
            fixed_rows.append(row)
            continue

        fixed_target = fix_target_output(target)
        if fixed_target != target:
            issues_found += 1

        row["target_output"] = fixed_target
        fixed_rows.append(row)

    print(f"Fixed key mismatches in {issues_found}/{len(rows)} rows")

    # Verify sample
    sample = fixed_rows[0]["target_output"]
    print(f"\nSample top-level keys:   {list(sample.keys())}")
    print(f"Sample rubric keys:      {list(sample.get('rubric_scores', {}).keys())}")
    conflicts = sample.get("requirement_conflicts", [])
    if conflicts and isinstance(conflicts[0], dict):
        print(f"Sample conflict keys:    {list(conflicts[0].keys())}")

    # Validate all rows
    REQUIRED_KEYS   = {"thinking_summary", "rubric_scores", "summary", "strengths", "concerns", "blocking_issues", "recommendations", "requirement_conflicts", "issue_updates"}
    REQUIRED_RUBRIC = {"requirements_alignment", "architecture_quality", "security", "operability", "internal_consistency"}

    missing_keys   = sum(1 for r in fixed_rows if REQUIRED_KEYS   - set(r.get("target_output", {}).keys()))
    missing_rubric = sum(1 for r in fixed_rows if REQUIRED_RUBRIC - set(r.get("target_output", {}).get("rubric_scores", {}).keys()))

    print(f"\nRows missing required top-level keys : {missing_keys}/{len(fixed_rows)}")
    print(f"Rows missing required rubric dims    : {missing_rubric}/{len(fixed_rows)}")

    with open(output_path, "w", encoding="utf-8") as f:
        for row in fixed_rows:
            f.write(json.dumps(row, ensure_ascii=False) + "\n")

    size_kb = Path(output_path).stat().st_size / 1024
    print(f"\n✓ Saved {len(fixed_rows)} rows → {output_path} ({size_kb:.1f} KB)")


if __name__ == "__main__":
    fix_dataset(INPUT_PATH, OUTPUT_PATH)
# Out:
# Loaded 799 rows from validation_output/llm_as_a_judge/auditor_dataset_final.jsonl
# Fixed key mismatches in 799/799 rows
#
# Sample top-level keys:   ['thinking_summary', 'summary', 'strengths', 'concerns', 'blocking_issues', 'recommendations', 'issue_updates', 'rubric_scores', 'requirement_conflicts']
# Sample rubric keys:      ['requirements_alignment', 'architecture_quality', 'security', 'operability', 'internal_consistency']
# Sample conflict keys:    ['issue_id', 'field', 'current_value', 'proposed_value', 'exact_reason', 'severity']
#
# Rows missing required top-level keys : 0/799
# Rows missing required rubric dims    : 0/799
#
# ✓ Saved 799 rows → validation_output/llm_as_a_judge/auditor_dataset_fixed.jsonl (5438.5 KB)

# %%
import json
import time
import re
import random
import openai
from pathlib import Path

client = openai.AzureOpenAI(
    api_key="F79rr24XOyTKAprSSVMiQuo8j99MQM9gzJD3oEIAmlfn4vrsj0TVJQQJ99CBACHYHv6XJ3w3AAABACOGX5Md",
    api_version="2024-08-01-preview",
    azure_endpoint="https://cmg-ai-poc-eu2.openai.azure.com/"
)
JUDGE_MODEL = "gpt-5-chat"


RESCORE_PROMPT = """You are a strict architecture audit scorer.

You will be given an architecture plan and its audit report.
The audit report currently has all rubric scores set to 7.
Your job is to assign DIFFERENTIATED, ACCURATE scores.

Score each dimension 0-10 based on what you actually see in the plan:
- requirements_alignment: how well the plan matches the frozen requirement contract
- architecture_quality: concrete module design, clear component separation, implementation-grade detail
- security: addresses risk_level and data_sensitivity from the contract
- operability: deployment clarity, observability, operational runbook quality
- internal_consistency: no contradictions between sections, coherent stack choices

Rules:
- Do NOT default to 7. Use the full range.
- A "flawless" revision that genuinely addresses all issues can score 8-10 on relevant dims.
- A plan missing security details when risk_level=high should score 3-5 on security.
- Dimensions can differ — a plan can have great architecture_quality but weak observability.
- Be willing to give 9-10 for genuinely excellent work and 3-5 for weak sections.

Return ONLY a JSON object:
{
    "requirements_alignment": <int 0-10>,
    "architecture_quality": <int 0-10>,
    "security": <int 0-10>,
    "operability": <int 0-10>,
    "internal_consistency": <int 0-10>,
    "reasoning": "<one sentence explaining the score spread>"
}"""


def rescore_row(row, client, model):
    payload = row.get('input_payload', {})
    target = row.get('target_output', {})

    # Build context: contract + plan + existing audit text
    contract = (payload.get('frozenrequirementcontract') or
                payload.get('frozen_requirement_contract') or {})
    plan = payload.get('plan', {})

    context = {
        "frozen_requirement_contract": contract,
        "plan": plan,
        "audit_thinking_summary": target.get('thinking_summary', ''),
        "audit_summary": target.get('summary', ''),
        "audit_strengths": target.get('strengths', []),
        "audit_concerns": target.get('concerns', []),
        "audit_blocking_issues": target.get('blocking_issues', []),
    }

    user_content = json.dumps(context, ensure_ascii=False, indent=1)[:5000]

    try:
        response = client.chat.completions.create(
            model=model,
            messages=[
                {"role": "system", "content": RESCORE_PROMPT},
                {"role": "user", "content": user_content}
            ],
            temperature=0.0,
            max_tokens=200,
        )
        raw = response.choices[0].message.content.strip()
        if raw.startswith("```"):
            raw = re.sub(r'^```[a-zA-Z]*\n?', '', raw)
            raw = re.sub(r'\n?```$', '', raw).strip()
        scores = json.loads(raw)

        dims = ['requirements_alignment', 'architecture_quality',
                'security', 'operability', 'internal_consistency']

        # validate — all dims present, all in range
        if all(isinstance(scores.get(d), int) and 0 <= scores[d] <= 10 for d in dims):
            return {d: scores[d] for d in dims}, scores.get('reasoning', '')
        return None, 'invalid response'
    except Exception as e:
        return None, str(e)


rows = []
with open('validation_output/llm_as_a_judge/auditor_dataset_fixed.jsonl') as f:
    for line in f:
        line = line.strip()
        if line:
            try:
                rows.append(json.loads(line))
            except:
                pass

dims = ['requirements_alignment', 'architecture_quality', 'security', 'operability', 'internal_consistency']

all_seven_idx = [i for i, r in enumerate(rows)
    if all(r.get('target_output', {}).get('rubric_scores', {}).get(d) == 7 for d in dims)]

print(f'total rows: {len(rows)}')
print(f'all-7 rows to re-score: {len(all_seven_idx)}')
print()

rescored = 0
failed = 0
still_all_seven = 0
rescore_log = []

for count, idx in enumerate(all_seven_idx):
    row = rows[idx]
    sid = row.get('sample_id', f'row_{idx}')

    new_scores, reasoning = rescore_row(row, client, JUDGE_MODEL)

    if new_scores:
        score_vals = list(new_scores.values())
        if len(set(score_vals)) == 1 and score_vals[0] == 7:
            still_all_seven += 1
        else:
            rescored += 1

        rows[idx]['target_output']['rubric_scores'] = new_scores
        rows[idx]['metadata']['rescored'] = True

        rescore_log.append({
            'sample_id': sid,
            'old_scores': {d: 7 for d in dims},
            'new_scores': new_scores,
            'reasoning': reasoning
        })

        if count < 5 or count % 50 == 0:
            print(f'[{count+1}/{len(all_seven_idx)}] {sid}')
            print(f'  new scores: {new_scores}')
            print(f'  reasoning: {reasoning[:100]}')
    else:
        failed += 1
        print(f'[{count+1}] FAILED {sid}: {reasoning[:60]}')

    time.sleep(0.3)

print(f'\n--- RESCORE SUMMARY ---')
print(f'successfully re-scored: {rescored}')
print(f'still all-7 after rescore: {still_all_seven}')
print(f'failed: {failed}')

from collections import Counter
all_scores_new = []
for r in rows:
    rubric = r.get('target_output', {}).get('rubric_scores', {})
    for d in dims:
        v = rubric.get(d)
        if isinstance(v, (int, float)):
            all_scores_new.append(int(v))

new_dist = Counter(all_scores_new)
print(f'\nNew score distribution:')
for s in sorted(new_dist):
    pct = new_dist[s] / len(all_scores_new) * 100
    bar = '#' * int(pct / 2)
    print(f'  {s}: {new_dist[s]:4d} ({pct:.1f}%)  {bar}')

new_all_seven = sum(1 for r in rows if all(r.get('target_output', {}).get('rubric_scores', {}).get(d) == 7 for d in dims))
print(f'\nAll-7 rows after rescore: {new_all_seven} / {len(rows)} ({new_all_seven/len(rows)*100:.1f}%)')

random.shuffle(rows)

with open('validation_output/rescored/auditor_dataset_rescored.jsonl', 'w', encoding='utf-8') as f:
    for r in rows:
        f.write(json.dumps(r, ensure_ascii=False) + '\n')

with open('validation_output/rescored/rescore_log.json', 'w', encoding='utf-8') as f:
    json.dump(rescore_log, f, indent=2, ensure_ascii=False)

print(f'\nsaved: auditor_dataset_rescored.jsonl ({len(rows)} rows)')
print(f'saved: rescore_log.json ({len(rescore_log)} entries)')
print(f'\nnow set DATASET_PATH = "auditor_dataset_rescored.jsonl" and retrain')
# Out:
# total rows: 799
# all-7 rows to re-score: 249
#
# [1/249] AUD-SYNC26-023
#   new scores: {'requirements_alignment': 9, 'architecture_quality': 8, 'security': 9, 'operability': 7, 'internal_consistency': 9}
#   reasoning: The plan tightly matches the low-risk, frontend-only library requirements and correctly externalizes
# [2/249] AUD-SYNC26-035
#   new scores: {'requirements_alignment': 10, 'architecture_quality': 9, 'security': 8, 'operability': 8, 'internal_consistency': 9}
#   reasoning: The plan perfectly matches the static, low-risk marketing site requirements with clear Astro and Clo
# [3/249] AUD-SYNC26-064
#   new scores: {'requirements_alignment': 9, 'architecture_quality': 8, 'security': 9, 'operability': 6, 'internal_consistency': 9}
#   reasoning: The plan tightly matches the frozen contract by using only React and D3, showing strong alignment an
# [4/249] AUD-SYNC26-076
#   new scores: {'requirements_alignment': 9, 'architecture_quality': 8, 'security': 9, 'operability': 7, 'internal_consistency': 9}
#   reasoning: The plan tightly matches the frozen contract—five VPCs, Terraform, SSM-only access, and non-overlapp
# [5/249] AUD-SYNC26-083
#   new scores: {'requirements_alignment': 9, 'architecture_quality': 8, 'security': 9, 'operability': 7, 'internal_consistency': 9}
#   reasoning: The plan tightly matches the simple, low-risk daily sync requirement and implements the mandated Sec
# [51/249] AUD-SYNC26-228
#   new scores: {'requirements_alignment': 9, 'architecture_quality': 7, 'security': 9, 'operability': 6, 'internal_consistency': 8}
#   reasoning: The plan tightly matches the frozen contract and fixes the key security flaw with proper VPN whiteli
# [101/249] AUD-SYNC26-382
#   new scores: {'requirements_alignment': 10, 'architecture_quality': 8, 'security': 7, 'operability': 8, 'internal_consistency': 9}
#   reasoning: The plan fully aligns with the simple, low-risk TypeScript library requirements and enforces the 100
# [151/249] AUD-SYNC26-537
#   new scores: {'requirements_alignment': 9, 'architecture_quality': 8, 'security': 7, 'operability': 6, 'internal_consistency': 9}
#   reasoning: The plan tightly matches the low-risk internal automation requirements and clearly implements the id
# [201/249] AUD-SYNC26-683
#   new scores: {'requirements_alignment': 9, 'architecture_quality': 8, 'security': 8, 'operability': 9, 'internal_consistency': 9}
#   reasoning: The plan tightly matches the low-risk, local CLI requirements, adds concrete goreleaser-based deploy
#
# --- RESCORE SUMMARY ---
# successfully re-scored: 249
# still all-7 after rescore: 0
# failed: 0
#
# New score distribution:
#   1:  143 (3.6%)  #
#   2:  223 (5.6%)  ##
#   3:  288 (7.2%)  ###
#   4:  353 (8.8%)  ####
#   5:  329 (8.2%)  ####
#   6:  526 (13.2%)  ######
#   7:  593 (14.8%)  #######
#   8:  630 (15.8%)  #######
#   9:  648 (16.2%)  ########
#   10:  262 (6.6%)  ###
#
# All-7 rows after rescore: 0 / 799 (0.0%)
#
# saved: auditor_dataset_rescored.jsonl (799 rows)
# saved: rescore_log.json (249 entries)
#
# now set DATASET_PATH = "auditor_dataset_rescored.jsonl" and retrain
